# %% [markdown]
# ## References

# %%
# https://medium.com/mlreview/topic-modeling-with-scikit-learn-e80d33668730
# http://scikit-learn.org/stable/auto_examples/applications/plot_topics_extraction_with_nmf_lda.html
# https://github.com/derekgreene/topic-model-tutorial/blob/master/3%20-%20Parameter%20Selection%20for%20NMF.ipynb

# %% [markdown]
# ## Prepare Notebook

# %%
# import packages
from sklearn.decomposition import NMF
import os
from gensim import corpora
from sklearn.feature_extraction.text import TfidfVectorizer
import pickle
import gensim.models
import numpy as np
from gensim.models import Word2Vec
from sklearn import decomposition
import gensim.models
from itertools import combinations
import matplotlib
import matplotlib.pyplot as plt
# Out:
# C:\Users\Sebastian Birk\Anaconda3\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# display graphs in jupyter
# %matplotlib inline

# %% [markdown]
# ## Load Vectorized Corpora and Dictionaries

# %%
# load no pooling corpus
if (os.path.exists("tourism_no_pooling.dict")):
   dictionary_no_pooling = corpora.Dictionary.load('tourism_no_pooling.dict')
   corpus_no_pooling = corpora.MmCorpus('tourism_no_pooling.mm')
   print("Vectorized no pooling corpus loaded!")
else:
   print("Please run preprocessing script first!")
# Out:
# Vectorized no pooling corpus loaded!

# %% [markdown]
# ## Load Documents and Unpreprocessed Tokenized Documents

# %%
# load no pooling documents
with open ('nmf_documents_no_pooling.p', 'rb') as fp:
    documents_no_pooling = pickle.load(fp)

# load no pooling unpreprocessed tokenized documents
with open ('tokenized_documents_no_pooling_unpp.p', 'rb') as fp:
    tokenized_documents_no_pooling = pickle.load(fp)

# %% [markdown]
# ## Apply TFIDF

# %%
# tfidf is usually used before running NMF
tfidf_vectorizer = TfidfVectorizer(max_df=0.5, min_df=2, stop_words='english')
tfidf_no_pooling = tfidf_vectorizer.fit_transform(documents_no_pooling)
tfidf_feature_names_no_pooling = tfidf_vectorizer.get_feature_names()

# %% [markdown]
# ## Run NMF Model and Determine Number of Topics

# %%
# define range of possible topic numbers
kmin, kmax = 4, 8

# %%
# run NMF model for different number of topics
topic_models = []
# try each value of k
for k in range(kmin,kmax+1):
    print("Applying NMF for k=%d ..." % k)
    # run NMF
    model = decomposition.NMF( init="nndsvd", n_components=k) 
    W = model.fit_transform(tfidf_no_pooling)
    H = model.components_    
    # store for later
    topic_models.append((k,W,H))
# Out:
# Applying NMF for k=4 ...
# Applying NMF for k=5 ...
# Applying NMF for k=6 ...
# Applying NMF for k=7 ...
# Applying NMF for k=8 ...

# %%
# prepare tokenized documents
tokenized_documents_no_pooling = [[item.replace("#","") for item in document] for document in tokenized_documents_no_pooling]

# %%
# display tokenized documents
tokenized_documents_no_pooling
# Out:
# [['brew',
#   'pub',
#   'to',
#   'try',
#   'a',
#   'few',
#   'of',
#   'the',
#   'beers',
#   'on',
#   'offer',
#   'olgodbarcelona',
#   'ølgod',
#   'triathlontraining'],
#  ['art',
#   'is',
#   'coming',
#   'face',
#   'to',
#   'face',
#   'with',
#   'yourself',
#   'parc',
#   'de',
#   'les',
#   'tres',
#   'xemeneies'],
#  ["today's", 'quickie', 'parc', 'de', 'les', 'tres', 'xemeneies'],
#  ['all',
#   'hail',
#   'the',
#   'freshest',
#   'seafood',
#   'in',
#   'town',
#   "let's",
#   'feast',
#   'hadthemostmusselsinmylife',
#   'tripoftheyear'],
#  ['dance',
#   'to',
#   'the',
#   'beat',
#   'of',
#   'your',
#   'own',
#   'drum',
#   'urban',
#   'music',
#   'live',
#   'stage',
#   'graffiti',
#   'streetart'],
#  ['i',
#   'just',
#   'finished',
#   'walking',
#   'km',
#   'in',
#   'h',
#   'm',
#   's',
#   'with',
#   'endomondo',
#   'endorphins'],
#  ['blackfriday',
#   'shopping',
#   'friends',
#   'then',
#   'bday',
#   'party',
#   'for',
#   'mallan',
#   'great',
#   'food',
#   'margaritas',
#   'and',
#   'more'],
#  ['another', 'why', 'not', 'la', 'pastisseria', 'barcelona'],
#  ['yesterday',
#   'i',
#   'got',
#   'a',
#   'new',
#   'hairstyle',
#   'with',
#   'the',
#   'best',
#   'hair',
#   'artist',
#   'in',
#   'the',
#   'city',
#   'i',
#   'cut',
#   'by',
#   'mychell'],
#  ['good',
#   'night',
#   'tienes',
#   'un',
#   'don',
#   'jesusisnard',
#   'ootd',
#   'en',
#   'margot',
#   'house',
#   'barcelona'],
#  ['stay',
#   'warm',
#   'pic',
#   'x',
#   'jesusisnard',
#   'sunday',
#   'en',
#   'margot',
#   'house',
#   'barcelona'],
#  ['there',
#   'is',
#   'nothing',
#   'better',
#   'than',
#   'waking',
#   'up',
#   'like',
#   'this',
#   'on',
#   'saturdays',
#   'at',
#   'margothousebarcelona',
#   'wearing'],
#  ['drinking', 'a', 'pumpkin', 'by', 'catalanbrewery', 'at', 'cocovailbh'],
#  ['drinking', 'a', 'leyenda', 'by', 'cervezadougalls', 'at', 'cocovailbh'],
#  ['barcelonas',
#   'night',
#   'clinicasden',
#   'event',
#   'night',
#   'bcn',
#   'barcelona',
#   'night',
#   'clinicasden',
#   'sonrisas'],
#  ['brama', 'at', 'crosmaslounge', 'in', 'barcelona', 'w', 'terraferma'],
#  ['trying',
#   'new',
#   'jobs',
#   'and',
#   'perspectives',
#   'telenoticies',
#   'tv',
#   'tvnews',
#   'tn',
#   'tvset',
#   'television'],
#  ['from',
#   'the',
#   'minute',
#   'we',
#   'emet',
#   'bri',
#   'and',
#   'nick',
#   'we',
#   'were',
#   'bowled',
#   'over',
#   'by',
#   'how',
#   'friendly',
#   'easygoing',
#   'and'],
#  ['saturday',
#   "it's",
#   'time',
#   'for',
#   'ride',
#   'the',
#   'bike',
#   'bhbikes',
#   'dhbsport',
#   'cold',
#   'weather',
#   "let's",
#   'face'],
#  ['just', 'posted', 'a', 'photo', 'barri', 'de', 'gracia', 'barcelona'],
#  ['testing',
#   'some',
#   'light',
#   'shadow',
#   'effect',
#   '',
#   'minutes',
#   'sketch',
#   'thumbnail',
#   'caricature',
#   'drawing'],
#  ['atreveixte',
#   'i',
#   'sigues',
#   'feliç',
#   'just',
#   'paint',
#   'and',
#   'be',
#   'happy',
#   'contigomismo',
#   'contigo'],
#  ['quick',
#   'one',
#   'to',
#   'start',
#   'saturday',
#   'inspired',
#   'this',
#   'time',
#   'by',
#   'the',
#   'beautiful',
#   'barbarapalvin',
#   'girl'],
#  ['dinner',
#   'at',
#   'a',
#   'dinerstyle',
#   'pizza',
#   'joint',
#   'with',
#   'steppenwolf',
#   'borntobewild',
#   'playing',
#   'in',
#   'the',
#   'background'],
#  ['improzilla',
#   'el',
#   'ataque',
#   'del',
#   'monstruo',
#   'cuqui',
#   'en',
#   'horario',
#   'laboral',
#   'movimiento',
#   'del',
#   'monstruo'],
#  ['i',
#   'love',
#   'my',
#   'school',
#   'is',
#   'on',
#   'fire',
#   'fuego',
#   'mantenlo',
#   'prendido',
#   'fuego',
#   'y',
#   'no',
#   'lo',
#   'dejes',
#   'apagar',
#   'y',
#   'grita'],
#  ['wish',
#   'i',
#   'was',
#   'still',
#   'on',
#   'my',
#   'holidays',
#   'basílica',
#   'de',
#   'la',
#   'sagrada',
#   'família'],
#  ["i'm",
#   'blessed',
#   'with',
#   'everything',
#   'i',
#   'need',
#   'i',
#   'am',
#   'working',
#   'hard',
#   'towards',
#   'everythibg',
#   'i',
#   'want',
#   'and',
#   'most',
#   'of'],
#  ['one',
#   'of',
#   'the',
#   'most',
#   'astonishing',
#   'modern',
#   'architectural',
#   'wonders',
#   'of',
#   'the',
#   'world',
#   'love',
#   'barcelona'],
#  ['lejos',
#   'cerca',
#   'salvadoreñosenelmundo',
#   'igersbcn',
#   'igersbarcelona',
#   'igersworld'],
#  ['sagrada',
#   'familia',
#   'weekendaway',
#   'barcelona',
#   'basílica',
#   'de',
#   'la',
#   'sagrada',
#   'família'],
#  ['what',
#   'sundays',
#   'are',
#   'all',
#   'about',
#   'barcelona',
#   'sagradafamilia',
#   'sundayvibes',
#   'basilica',
#   'basílica',
#   'de'],
#  ['the',
#   'sagrada',
#   'familia',
#   'in',
#   'barcelona',
#   'is',
#   'hands',
#   'down',
#   'the',
#   'most',
#   'beautiful',
#   'building',
#   'i',
#   'have',
#   'ever',
#   'been',
#   'in'],
#  ['i',
#   "don't",
#   'know',
#   'want',
#   'i',
#   'want',
#   'i',
#   'only',
#   'know',
#   'what',
#   'i',
#   "don't",
#   'want',
#   'juan'],
#  ['shootting',
#   'sagradafamilia',
#   'photography',
#   'photographer',
#   'details',
#   'barcelona',
#   'happiness'],
#  ['the',
#   'other',
#   'side',
#   'of',
#   'the',
#   'sagrada',
#   'familia',
#   'basilica',
#   'which',
#   'was',
#   'from',
#   'the'],
#  ["gaudí's",
#   'creation',
#   'the',
#   'sagrada',
#   'familia',
#   'basílica',
#   'ly',
#   'is',
#   'a',
#   'large'],
#  ['speechless',
#   'sagradafamilia',
#   'antonigaudi',
#   'gaudi',
#   'barcelona',
#   'vacations',
#   'blessed',
#   'basílica',
#   'de',
#   'la'],
#  ['this',
#   'was',
#   'the',
#   'most',
#   'spectacular',
#   'place',
#   'i',
#   'have',
#   'visited',
#   'in',
#   'a',
#   'long',
#   'time'],
#  ['the',
#   'amazing',
#   'and',
#   'unfinished',
#   'sagrada',
#   'familia',
#   'by',
#   'catalan',
#   'teacher',
#   'antoni',
#   'gaudí',
#   'barcelonatales'],
#  ['barcelona',
#   'tourist',
#   'stuff',
#   'and',
#   'all',
#   'that',
#   'basílica',
#   'de',
#   'la',
#   'sagrada',
#   'família'],
#  ['barcelona',
#   'spain',
#   'espana',
#   'sagradafamilia',
#   'europetrip',
#   'backpacking',
#   'em',
#   'basílica',
#   'de',
#   'la',
#   'sagrada'],
#  ['the',
#   'light',
#   'hit',
#   'the',
#   'stained',
#   'glass',
#   'windows',
#   'perfectly',
#   'sagradafamília',
#   'antonigaudí',
#   'barcelona'],
#  ['take',
#   'me',
#   'back',
#   'to',
#   'this',
#   'beautiful',
#   'place',
#   'barcelona',
#   'basilicadelasagradafamilia'],
#  ['gaudi', 'awesomeness', 'basílica', 'de', 'la', 'sagrada', 'família'],
#  ['had',
#   'to',
#   'make',
#   'a',
#   'quick',
#   'detour',
#   'to',
#   'lasagradafamilia',
#   'before',
#   'leaving',
#   'barcelona',
#   'spain',
#   'travel'],
#  ['one',
#   'of',
#   'my',
#   'favorite',
#   'places',
#   'on',
#   'earth',
#   'sagrada',
#   'familia',
#   'basílica',
#   'de',
#   'la',
#   'sagrada',
#   'família'],
#  ['too', 'broke', 'for', 'basílica', 'de', 'la', 'sagrada', 'família'],
#  ['a',
#   'kaleidoscope',
#   'of',
#   'colors',
#   'inside',
#   'basílica',
#   'de',
#   'la',
#   'sagrada',
#   'família',
#   'colors',
#   'art'],
#  ['visit',
#   'the',
#   'incredible',
#   'la',
#   'sagrada',
#   'familia',
#   'and',
#   'capture',
#   'moments',
#   'like',
#   'these',
#   'students',
#   'during',
#   'our'],
#  ['bcn',
#   'cataluña',
#   'friendsaroundtheworld',
#   'en',
#   'basílica',
#   'de',
#   'la',
#   'sagrada',
#   'família'],
#  ['sagradafamilia',
#   'barcelona',
#   'amazing',
#   'wonderful',
#   'colored',
#   'rainbow',
#   'gaudí',
#   'church',
#   'iglesia',
#   'chiesa'],
#  ['nah',
#   'just',
#   'on',
#   'top',
#   'of',
#   'la',
#   'sagrada',
#   'familia',
#   'basílica',
#   'de',
#   'la'],
#  ['sagrada',
#   'familia',
#   'closeup',
#   'barcelona',
#   'españa',
#   'spain',
#   'catalunya',
#   'photography',
#   'fotografia'],
#  ['all',
#   'of',
#   'a',
#   'suddenwhilst',
#   'his',
#   'eyes',
#   'were',
#   'all',
#   'smearshe',
#   'decided',
#   'to'],
#  ['we',
#   'apmen',
#   'multimedia',
#   'are',
#   'happy',
#   'to',
#   'partner',
#   'with',
#   'dommia',
#   'design',
#   'studio'],
#  ['view',
#   'from',
#   'the',
#   'passion',
#   'tower',
#   'eurogiving',
#   'barcelona',
#   'basílica',
#   'de',
#   'la',
#   'sagrada',
#   'família'],
#  ['the',
#   'sagrada',
#   'familia',
#   'is',
#   'an',
#   'exceptional',
#   'place',
#   'for',
#   'worship',
#   'five',
#   'generations',
#   'have',
#   'already',
#   'witnessed'],
#  ['i',
#   'had',
#   'an',
#   'outstanding',
#   'time',
#   'in',
#   'barcelona',
#   'takemeback',
#   'eurotrip',
#   'newfriends',
#   'basílica',
#   'de',
#   'la'],
#  ['i',
#   'think',
#   "it's",
#   'an',
#   'ugly',
#   'building',
#   'on',
#   'photo',
#   'but',
#   'after',
#   'i',
#   'saw',
#   'it',
#   'in',
#   'person',
#   "it's",
#   'magnificent',
#   '%',
#   'of'],
#  ['constructed',
#   'between',
#   'and',
#   'the',
#   'nativity',
#   'façade',
#   'of',
#   'the',
#   'basilica',
#   'was',
#   'the',
#   'first',
#   'façade',
#   'to'],
#  ['wonderful',
#   'natural',
#   'colors',
#   'during',
#   'this',
#   'time',
#   'of',
#   'the',
#   'year',
#   'basílica',
#   'de',
#   'la',
#   'sagrada',
#   'família'],
#  ['bastelstation',
#   'la',
#   'sagrada',
#   'familia',
#   'sagrada',
#   'família',
#   'sagradafamilia',
#   'in',
#   'barcelona'],
#  ['happy',
#   'sunday',
#   'barcelona',
#   'we',
#   'have',
#   'a',
#   'sunny',
#   'and',
#   'blue',
#   'sky',
#   'day',
#   'kelmibilbao',
#   'photographer'],
#  ['view',
#   'of',
#   'barcelona',
#   'from',
#   'one',
#   'of',
#   'the',
#   'towers',
#   'of',
#   'la',
#   'sagrada',
#   'familia',
#   'spain',
#   'gaudi',
#   'view',
#   'blessed'],
#  ['fantastic',
#   'final',
#   'day',
#   'in',
#   'barcelona',
#   'headed',
#   'home',
#   'sagradafamilia',
#   'barcelona',
#   'spain',
#   'basílica',
#   'de'],
#  ['sagradafamilia',
#   'barcelona',
#   'spain',
#   'chill',
#   'latergram',
#   'igersspain',
#   'igersbarcelona',
#   'à',
#   'basílica',
#   'de',
#   'la'],
#  ['none',
#   'of',
#   'the',
#   'interior',
#   'surfaces',
#   'of',
#   'the',
#   'basilica',
#   'are',
#   'flat',
#   'the',
#   'ornamentation',
#   'is',
#   'comprehensive',
#   'and'],
#  ['one',
#   'of',
#   'the',
#   'most',
#   'impressive',
#   'structures',
#   'built',
#   'by',
#   'man',
#   'thanks',
#   'to',
#   'the',
#   'creative',
#   'and',
#   'genius',
#   'design',
#   'by'],
#  ['anything',
#   'created',
#   'by',
#   'human',
#   'beings',
#   'is',
#   'already',
#   'in',
#   'the',
#   'great',
#   'book',
#   'of'],
#  ['on',
#   'saturdays',
#   'we',
#   'wear',
#   'tokiohotel',
#   'tshirts',
#   'en',
#   'basílica',
#   'de',
#   'la',
#   'sagrada',
#   'família'],
#  ['the',
#   'columns',
#   'of',
#   'the',
#   'interior',
#   'are',
#   'a',
#   'unique',
#   'gaudí',
#   'design',
#   'besides',
#   'branching',
#   'to',
#   'support',
#   'their',
#   'load'],
#  ['the',
#   'only',
#   'thing',
#   'more',
#   'beautiful',
#   'than',
#   "barcelona's",
#   'sagrada',
#   'familia',
#   'is',
#   'the',
#   'familia',
#   'in',
#   'barcelona'],
#  ['bego',
#   'through',
#   'the',
#   'looking',
#   'glasss',
#   'en',
#   'basílica',
#   'de',
#   'la',
#   'sagrada',
#   'família'],
#  ['jump',
#   'for',
#   'joy',
#   'as',
#   'we',
#   'accomplish',
#   'the',
#   'dreams',
#   'we',
#   'adore',
#   'basílica',
#   'de',
#   'la',
#   'sagrada',
#   'família'],
#  ['attended',
#   'a',
#   'coffee',
#   'morning',
#   'at',
#   'the',
#   'local',
#   'parish',
#   'unfortunately',
#   'they',
#   'had',
#   'no',
#   'orange',
#   'cordial',
#   'left',
#   'or'],
#  ['relying',
#   'solely',
#   'on',
#   'private',
#   'donations',
#   'sagrada',
#   "familia's",
#   'construction',
#   'progressed',
#   'slowly',
#   'and',
#   'was'],
#  ['women',
#   'color',
#   'vintage',
#   'colors',
#   'hair',
#   'hairofinstagram',
#   'autum',
#   'colors',
#   'hairstyle',
#   'hairstyles'],
#  ['women',
#   'hair',
#   'hairofinstagram',
#   'hairstreet',
#   'style',
#   'hairporn',
#   'curly',
#   'balayage',
#   'ginger',
#   'pelirroja'],
#  ['women',
#   'strong',
#   'mujer',
#   'female',
#   'girl',
#   'kids',
#   'motivacion',
#   'everyday',
#   'goodmorningworld',
#   'hairstreet'],
#  ['gaudihouse',
#   'gaudimuseum',
#   'parqueguell',
#   'simpleliving',
#   'inspiration',
#   'nature'],
#  ['you',
#   'ease',
#   'my',
#   'mind',
#   'you',
#   'make',
#   'everything',
#   'feel',
#   'finevilaviniteca',
#   'flordepingus',
#   'flor'],
#  ['i',
#   'just',
#   'finished',
#   'running',
#   'km',
#   'in',
#   'm',
#   's',
#   'with',
#   'endomondo',
#   'endorphins'],
#  ['when',
#   'i',
#   'was',
#   'in',
#   'tenth',
#   'grade',
#   'i',
#   'took',
#   'both',
#   'french',
#   'and',
#   'spanish',
#   'classes',
#   'my',
#   'spanish',
#   'teacher',
#   'señorita'],
#  ['dinner',
#   'service',
#   'complete',
#   'in',
#   'cornwall',
#   'skipped',
#   'a',
#   'nights',
#   'sleep',
#   'to',
#   'make',
#   'it',
#   'for',
#   'brunch',
#   'in',
#   'barcelona'],
#  ['fitness',
#   'yogi',
#   'love',
#   'namaste',
#   'yogalove',
#   'fit',
#   'meditation',
#   'workout',
#   'fitfam',
#   'gym',
#   'healthy',
#   'health'],
#  ['i',
#   'ivblacknwhiteperfection',
#   'blackandwhite',
#   'blackandwhitephotography',
#   'blancoynegro',
#   'blancinegre'],
#  ['what',
#   'a',
#   'beautiful',
#   'place',
#   'i',
#   'want',
#   'to',
#   'shoot',
#   'there',
#   'again',
#   'anyonefitness',
#   'yogaeverydamnday',
#   'yogi'],
#  ['weekend',
#   'strolls',
#   'among',
#   'palm',
#   'trees',
#   'and',
#   'cacti',
#   'what',
#   'were',
#   'you',
#   'up',
#   'to',
#   'mossèn',
#   'costa',
#   'i',
#   'llobera',
#   'gardens'],
#  ['aerofarms',
#   'tiene',
#   'como',
#   'inversor',
#   'a',
#   'ikea',
#   'futuro',
#   'comida',
#   'food',
#   'mornings'],
#  ['la', 'marisma', 'libre', 'y', 'tropical'],
#  ['inpiring', 'day', 'in', 'culthuntingday', 'great', 'ideas', 'about'],
#  ['every',
#   'time',
#   'argentina',
#   'scores',
#   'a',
#   'try',
#   'i',
#   'get',
#   'a',
#   'free',
#   'shot',
#   'rugby',
#   'argentinavsireland',
#   'shots',
#   'tequila'],
#  ['i',
#   'feel',
#   'as',
#   'lonely',
#   'as',
#   'ever',
#   'but',
#   "i'm",
#   'making',
#   'myself',
#   'brunch',
#   'alone'],
#  ['getting', 'on', 'the', 'leaf', 'citizen', 'café'],
#  ['traveling',
#   'with',
#   'your',
#   'kids',
#   'is',
#   'definitely',
#   'something',
#   'special',
#   'while',
#   "it's",
#   'not',
#   'always',
#   'relaxing',
#   'to'],
#  ['karaoke', 'night', 'the', 'george', 'payne', 'in', 'barcelona'],
#  ['volvemos',
#   'bbf',
#   'picoftheday',
#   'photooftheday',
#   'instagood',
#   'me',
#   'boy',
#   'girl',
#   'happy',
#   'selfie'],
#  ['is',
#   'it',
#   'cold',
#   'this',
#   'morning',
#   'barbara',
#   'naah',
#   'we',
#   'are',
#   'just',
#   'chilling',
#   'in',
#   'the',
#   'sun',
#   'lara',
#   'garnier',
#   'en'],
#  ['a',
#   'remar',
#   'sun',
#   'clouds',
#   'barcelona',
#   'en',
#   'barcelona',
#   'international',
#   'sailing',
#   'center'],
#  ['morning',
#   'session',
#   'done',
#   'now',
#   'we',
#   'wait',
#   'for',
#   'the',
#   'afternoon',
#   'wind',
#   'en',
#   'barcelona',
#   'international'],
#  ['eeee',
#   'eae',
#   'aeao',
#   'tbt',
#   'bbf',
#   'arminvanbuuren',
#   'greatspirit',
#   'wildstylez',
#   'hardstyle',
#   'bbfbarcelona',
#   'en'],
#  ['lo',
#   'que',
#   'va',
#   'de',
#   'no',
#   'ha',
#   'podido',
#   'ser',
#   'tan',
#   'terrible',
#   'si',
#   'he',
#   'visto',
#   'a',
#   'bon',
#   'iver',
#   'en',
#   'primavera',
#   'sound'],
#  ['i',
#   'just',
#   'finished',
#   'running',
#   'km',
#   'in',
#   'm',
#   's',
#   'with',
#   'endomondo',
#   'endorphins'],
#  ['wish',
#   'i',
#   'had',
#   'a',
#   'day',
#   'like',
#   'this',
#   'today',
#   'but',
#   'instead',
#   'i',
#   'had',
#   'one',
#   'of',
#   'those',
#   'days',
#   'where',
#   'i',
#   'woke',
#   'up',
#   'at',
#   'the'],
#  ['afterwork',
#   'music',
#   'beer',
#   'at',
#   'milkandcoworking',
#   'afterwork',
#   'dj',
#   'bcn',
#   'people',
#   'barcelona',
#   'music',
#   'beer',
#   'en'],
#  ['getting',
#   'in',
#   'a',
#   'couple',
#   'x',
#   's',
#   'deadlift',
#   'as',
#   'well',
#   'pay',
#   'no',
#   'attention',
#   'to',
#   'the',
#   'low',
#   'weight',
#   'my',
#   'back',
#   "isn't"],
#  ['lamasalacafe',
#   "miquistepsthere's",
#   'something',
#   'in',
#   'the',
#   'air',
#   'that',
#   'makes',
#   'this',
#   'rather',
#   'hipclonic'],
#  ['casalolea',
#   'miquistepshere',
#   'comes',
#   'the',
#   'spotty',
#   'sangria',
#   'right',
#   'size',
#   'pleasant',
#   'pretty',
#   'venue'],
#  ['portrait',
#   'by',
#   'beatrizjaner',
#   'for',
#   'yurbban',
#   'businessportrait',
#   'liveasanative',
#   'yurbban',
#   'the',
#   'net',
#   'revenue'],
#  ['mondays',
#   'at',
#   'design',
#   'socialmedia',
#   'branding',
#   'sales',
#   'entrepreneurship',
#   'brand',
#   'design',
#   'tech'],
#  ['meeting', 'time', 'carpe', 'diem', 'com', 'new', 'hq'],
#  ['thank',
#   'you',
#   'for',
#   'a',
#   'well',
#   'planned',
#   'birthday',
#   'weekend',
#   'baby',
#   'girl'],
#  ['a',
#   'bit',
#   'of',
#   'everything',
#   'in',
#   'there',
#   'lool',
#   'vodka',
#   'gin',
#   'rum',
#   'whiskey'],
#  ['she',
#   'was',
#   'just',
#   'one',
#   'night',
#   'baby',
#   'you',
#   'were',
#   'my',
#   'whole',
#   'lifeso',
#   'tired',
#   'and',
#   'sick',
#   'have',
#   'a',
#   'nice',
#   'week',
#   'end',
#   'en'],
#  ['do',
#   'you',
#   'now',
#   'what',
#   'is',
#   'thatmanodebuda',
#   'has',
#   'mascarospirit',
#   'paco',
#   'gin',
#   'ginpremium'],
#  ['te',
#   'extraño',
#   'mucho',
#   'barcelona',
#   'slide',
#   'into',
#   'my',
#   'dms',
#   'if',
#   "you're",
#   'tryna',
#   'session',
#   'and',
#   'have',
#   'someone',
#   'take',
#   'pix'],
#  ['well',
#   'the',
#   'toilets',
#   'were',
#   'certainly',
#   'not',
#   'heaven',
#   'and',
#   'they',
#   'played',
#   'coldplay',
#   'but',
#   'the',
#   'cocktails',
#   'were',
#   'delicious',
#   'heaven'],
#  ['ruthlorenzo', 'ggdl', 'goodgirlsdontlie', 'pop', 'rock'],
#  ['continuing',
#   'my',
#   'tapas',
#   'tour',
#   'in',
#   'barcelona',
#   'for',
#   'tapantoni',
#   'awesome',
#   'pulpo',
#   'a',
#   'la',
#   'brasafood'],
#  ['los',
#   'amo',
#   'togetherforever',
#   'amolanavidad',
#   'arbolitodenavidad',
#   'navidad',
#   'en',
#   'i',
#   'love',
#   'barcelona'],
#  ['el',
#   'agente',
#   'peña',
#   'no',
#   'pero',
#   'con',
#   'años',
#   'menos',
#   'gray',
#   'shoot',
#   'by',
#   'the',
#   'only',
#   'one'],
#  ['buenos',
#   'días',
#   'bcn',
#   'barcelona',
#   'spain',
#   'españa',
#   'trip',
#   'travel',
#   'sightseeing',
#   'igdaily',
#   'igmood'],
#  ['another',
#   'amazing',
#   'action',
#   'packed',
#   'full',
#   'day',
#   'in',
#   'this',
#   'amazing',
#   'city',
#   'i',
#   'barcelona'],
#  ['just',
#   'skateboarding',
#   'videographers',
#   'knows',
#   "what's",
#   'this',
#   'picture',
#   'meansfilmingalldays',
#   'great',
#   'shoot'],
#  ['peeking',
#   'into',
#   'the',
#   'beautiful',
#   'city',
#   'of',
#   'barcelona',
#   'from',
#   "gaudí's",
#   'masterpiece'],
#  ['thankful',
#   'for',
#   'them',
#   'mommy',
#   'and',
#   'brother',
#   'come',
#   'to',
#   'spain',
#   'happythanksgiving',
#   'basílica',
#   'de',
#   'la'],
#  ['breathtaking', 'basílica', 'de', 'la', 'sagrada', 'família'],
#  ["let's",
#   'all',
#   'take',
#   'a',
#   'moment',
#   'to',
#   'realize',
#   'that',
#   'this',
#   'building',
#   'actually',
#   'exists',
#   'in',
#   'the',
#   'real',
#   'world',
#   'not'],
#  ['sagrada',
#   'familia',
#   'at',
#   'night',
#   'sagradafamilia',
#   'journey',
#   'trip',
#   'traveling',
#   'spain',
#   'barcelona',
#   'basílica'],
#  ['fent',
#   'mandra',
#   '',
#   'november',
#   'gatets',
#   'sirventfamily',
#   'sagradafamília',
#   'sagradafamilia',
#   'bcn'],
#  ['sometimes',
#   'just',
#   'be',
#   'thankful',
#   'to',
#   'know',
#   'that',
#   'trouble',
#   "don't",
#   'last',
#   'forever',
#   'as',
#   'said',
#   'by',
#   'jstlbby'],
#  ['nofilter',
#   'fruitless',
#   'to',
#   'capture',
#   'sagrada',
#   'familia',
#   'with',
#   'an',
#   'iphone',
#   'but',
#   'i',
#   'was',
#   'obsessed',
#   'with',
#   'the'],
#  ['details',
#   'barcelona',
#   'sagradafamilia',
#   'spain',
#   'espana',
#   'europe',
#   'details',
#   'basílica',
#   'de',
#   'la',
#   'sagrada',
#   'família'],
#  ['the',
#   'basilica',
#   'temple',
#   'de',
#   'sagradafamilia',
#   'is',
#   'a',
#   'large',
#   'unfinished',
#   'roman',
#   'catholic',
#   'church',
#   'in',
#   'barcelona'],
#  ['lasagradafamilia',
#   'w',
#   'the',
#   'family',
#   'basílica',
#   'de',
#   'la',
#   'sagrada',
#   'família'],
#  ['this',
#   'was',
#   'one',
#   'of',
#   'the',
#   'most',
#   'beautiful',
#   'places',
#   'i',
#   'have',
#   'ever',
#   'been',
#   'bjeurovaca',
#   'lasagradafamilia'],
#  ['completely',
#   'mesmerized',
#   'by',
#   'la',
#   'basílica',
#   'de',
#   'la',
#   'sagrada',
#   'família',
#   'the',
#   'chances',
#   'of',
#   'running',
#   'across'],
#  ['awesome',
#   'simply',
#   'awesome',
#   'basílica',
#   'de',
#   'la',
#   'sagrada',
#   'família'],
#  ['stunning',
#   'light',
#   'inside',
#   'sagrada',
#   'família',
#   'sagradafamilia',
#   'in',
#   'barcelona'],
#  ['my',
#   'mother',
#   'taught',
#   'me',
#   'to',
#   'be',
#   'grateful',
#   'my',
#   'father',
#   'taught',
#   'me',
#   'to',
#   'be',
#   'humble',
#   'together',
#   'they',
#   'showed',
#   'me'],
#  ['an',
#   'absolutely',
#   'captivating',
#   'masterpiece',
#   'by',
#   'itself',
#   'probably',
#   'the',
#   'most',
#   'iconic',
#   'landmark',
#   'in',
#   'the'],
#  ['barcelona',
#   'sight',
#   'seeing',
#   'with',
#   'briansamek',
#   'travel',
#   'gaudi',
#   'spain',
#   'vacation',
#   'wanderlust',
#   'basílica',
#   'de'],
#  ["i'm",
#   'just',
#   'going',
#   'to',
#   'say',
#   'it',
#   'the',
#   'sagrada',
#   'familia',
#   'is',
#   'the',
#   'most',
#   'beautiful',
#   'church',
#   "i've",
#   'ever',
#   'stepped'],
#  ['two',
#   'years',
#   'in',
#   'a',
#   'row',
#   'and',
#   'three',
#   'times',
#   'sagradafamilia',
#   'basílica',
#   'de',
#   'la',
#   'sagrada',
#   'família'],
#  ['fighting',
#   'over',
#   'a',
#   'horde',
#   'of',
#   'tourists',
#   'for',
#   'a',
#   'perfect',
#   'shot',
#   'like',
#   'this',
#   'is',
#   'no',
#   'easy',
#   'job',
#   'imhereatlast'],
#  ['amazing', 'structure', 'basílica', 'de', 'la', 'sagrada', 'família'],
#  ['first',
#   'stop',
#   'la',
#   'sagrada',
#   'wowser',
#   'basílica',
#   'de',
#   'la',
#   'sagrada'],
#  ['art',
#   'sano',
#   'arte',
#   'urbano',
#   'barcelona',
#   'digerible',
#   'arteurbano',
#   'streetart',
#   'arteenlacalle',
#   'graffiti'],
#  ['last',
#   'look',
#   'of',
#   'lasagradafamilia',
#   'in',
#   'barcelona',
#   'spain',
#   'basílica',
#   'de',
#   'la',
#   'sagrada',
#   'família'],
#  ['gaudi',
#   'gaudisagradafamilia',
#   'sagradafamilia',
#   'amazing',
#   'cathedral',
#   'barcelona',
#   'stainedglass'],
#  ["gaudí's",
#   'forest',
#   'broke',
#   'my',
#   'brain',
#   'architecturalwonder',
#   'mostbeautifulbuilding',
#   'tears',
#   'basílica'],
#  ['gaudí',
#   'made',
#   'me',
#   'cry',
#   'architecturalwonder',
#   'mostbeautifulbuilding',
#   'light',
#   'stoneforest',
#   'basílica',
#   'de'],
#  ['la',
#   'sagrada',
#   'familia',
#   'was',
#   'incredible',
#   'the',
#   'colors',
#   'alone',
#   'could',
#   'knock',
#   'you',
#   'out',
#   'barcelona',
#   'basílica'],
#  ['gratas',
#   'visitas',
#   'en',
#   'black',
#   'friday',
#   'sorpresa',
#   'en',
#   'annexia',
#   'tshirts'],
#  ['finally',
#   'you',
#   'are',
#   'free',
#   'destroy',
#   'the',
#   'planet',
#   'if',
#   'you',
#   'have',
#   'any'],
#  ['poblenou',
#   'barcelona',
#   'gentrification',
#   'gentrificacion',
#   'graffiti',
#   'people',
#   'poligono',
#   'industrial'],
#  ['just', 'posted', 'a', 'photo', 'poblenou'],
#  ['lluc',
#   'kissing',
#   'lluc',
#   'brooch',
#   'by',
#   'ligstars',
#   'thank',
#   'you',
#   'we',
#   'love',
#   'it',
#   'sharpei',
#   'dogsofinstagram'],
#  ['drinking', 'a', 'denali', 'by', 'vibrantforest', 'cal', 'cuc', 'photo'],
#  ['chan',
#   'chuu',
#   'larb',
#   'khaaaaaaa',
#   'drinking',
#   'a',
#   'castanea',
#   'by',
#   'vibrantforest',
#   'cal',
#   'cuc',
#   'photo'],
#  ['al',
#   'cau',
#   'ens',
#   'volem',
#   'vives',
#   'n',
#   'stoptheviolence',
#   'ensvolemvives'],
#  ['bdaphotography',
#   'nikonnikonloveshotonnikonnikond',
#   'nikoneurope',
#   'nikonforever'],
#  ['rollerblade',
#   'catalogue',
#   'with',
#   'soficarrerass',
#   'motivation',
#   'fit',
#   'sport',
#   'skating',
#   'woman',
#   'xfit'],
#  ['carrer',
#   'de',
#   'vidal',
#   'i',
#   'de',
#   'valenciano',
#   'graffitiart',
#   'graffiti',
#   'safariartstreetbcn',
#   'en',
#   'poblenou'],
#  ['poblenou',
#   'barcelona',
#   'chicken',
#   'pollo',
#   'gallina',
#   'hen',
#   'chickenman',
#   'hombrepollo',
#   'random',
#   'surrealism'],
#  ['i',
#   'just',
#   'finished',
#   'walking',
#   'km',
#   'in',
#   'h',
#   'm',
#   's',
#   'with',
#   'endomondo',
#   'endorphins'],
#  ['via',
#   'laietana',
#   'canon',
#   'g',
#   'x',
#   'holiday',
#   'throwback',
#   'randomshoot',
#   'spain'],
#  ['well',
#   'that',
#   'was',
#   'one',
#   'helluva',
#   'show',
#   'any',
#   'new',
#   'series',
#   'you',
#   'guys',
#   'can',
#   'recommend',
#   'gothic',
#   'quarter',
#   'barcelona'],
#  ['trip',
#   'to',
#   'barkelona',
#   'continues',
#   'barcelona',
#   'barkelona',
#   'bark',
#   'vacation',
#   'gothic',
#   'quarter',
#   'barcelona'],
#  ['we', 'be', 'out', 'here', 'gothic', 'quarter', 'barcelona'],
#  ['the',
#   'only',
#   'day',
#   "i'll",
#   'wear',
#   'all',
#   'black',
#   'and',
#   'perch',
#   'on',
#   'a',
#   'leopard',
#   'is',
#   'blackfriday',
#   'otherwise',
#   'i',
#   'have',
#   'a'],
#  ['catalan',
#   'lessons',
#   'for',
#   'a',
#   'cheesedick',
#   'gothic',
#   'quarter',
#   'barcelona'],
#  ['in',
#   'through',
#   'the',
#   'outhouse',
#   'door',
#   'still',
#   'a',
#   'few',
#   'tix',
#   'for',
#   'our',
#   'show',
#   'at',
#   'sidecarbcn',
#   'lets',
#   'pack',
#   'this',
#   'cute'],
#  ['gorgeous',
#   'day',
#   'at',
#   'the',
#   'new',
#   'base',
#   'for',
#   'months',
#   'barcelona',
#   'lasramblas',
#   'yachtstew',
#   'gothic'],
#  ['you',
#   'can',
#   'find',
#   'happiness',
#   'in',
#   'the',
#   'simplicity',
#   'of',
#   'life',
#   'gothic',
#   'quarter',
#   'barcelona'],
#  ['barcelona',
#   'bnwofourworld',
#   'bnwphotografare',
#   'catalonia',
#   'catalunya',
#   'igeurope'],
#  ['architecturephotography',
#   'architecture',
#   'barcelona',
#   'catalunya',
#   'igeurope',
#   'streetphotography'],
#  ['taking',
#   'in',
#   'barcelona',
#   'w',
#   'our',
#   'beautiful',
#   'family',
#   'gothic',
#   'quarter',
#   'barcelona'],
#  ['this',
#   'low',
#   'rider',
#   'little',
#   'boy',
#   'of',
#   'my',
#   'good',
#   'mate',
#   'adriencrasnault',
#   'action',
#   'bike',
#   'kid',
#   'lifestyle'],
#  ['escorpora',
#   'cabracho',
#   'scorpionfish',
#   'forn',
#   'horno',
#   'vegetables',
#   'healthyfood',
#   'sweetpotato',
#   'moniato'],
#  ['have', 'no', 'fear', 'of', 'perfection', "you'll", 'never', 'reach'],
#  ['late',
#   'night',
#   'walk',
#   'w',
#   'my',
#   'mollythabumting',
#   'magical',
#   'exp',
#   'gothic'],
#  ['quoteoftheday',
#   'justbethankful',
#   'livingbcn',
#   'lovingbcn',
#   'en',
#   'gothic',
#   'quarter',
#   'barcelona'],
#  ['started',
#   'the',
#   'day',
#   'at',
#   'churrería',
#   'laietana',
#   'for',
#   'churros',
#   'con',
#   'chocolate',
#   'vacation',
#   'howdidigetsolucky'],
#  ['res',
#   'millor',
#   'que',
#   'una',
#   'bona',
#   'migdiada',
#   'desprès',
#   'de',
#   'dinar',
#   'nothing',
#   'better',
#   'to',
#   'sleep',
#   'after',
#   'lunch'],
#  ['barri',
#   'gòtic',
#   'happpysunday',
#   'barrigotic',
#   'barcelona',
#   'weekendtrip',
#   'architecture',
#   'en'],
#  ['barcelona',
#   'spain',
#   'collette',
#   'cooking',
#   'culinary',
#   'school',
#   'funtimes',
#   'gothic',
#   'quarter',
#   'barcelona'],
#  ['returning',
#   'to',
#   'berlin',
#   'has',
#   'been',
#   'bittersweet',
#   'barcelona',
#   'is',
#   'such',
#   'a',
#   'magical',
#   'city',
#   'full',
#   'of',
#   'so',
#   'many',
#   'warm'],
#  ['this',
#   'was',
#   'our',
#   'turkey',
#   'day',
#   'meal',
#   'spain',
#   'grayboys',
#   'honeymoon',
#   'vacationmode',
#   'gobblegobblemf',
#   'la'],
#  ['some',
#   'cakes',
#   'look',
#   'like',
#   'pop',
#   'art',
#   'cake',
#   'popart',
#   'pop',
#   'art',
#   'food',
#   'foodie',
#   'foodgram',
#   'foodiegram'],
#  ['okey',
#   'drinking',
#   'a',
#   'san',
#   'miguel',
#   'by',
#   'carlsbergukcorp',
#   'taller',
#   'de',
#   'tapas',
#   'photo'],
#  ['tapaaaaaaas', 'sagardi', 'bcn', 'gotic', 'gruposagardi', 'in', 'barcelona'],
#  ['just',
#   'arrived',
#   'from',
#   'bravafabrics',
#   'blackfriday',
#   'shopping',
#   'barcelona',
#   'cycling',
#   'crec',
#   'coworking'],
#  ['drinking',
#   'a',
#   'grimbergen',
#   'blanche',
#   'by',
#   'kronenbourgsas',
#   'minyam',
#   'photo'],
#  ['saturday',
#   'back',
#   'to',
#   'bocacocktaillounge',
#   'from',
#   'till',
#   'late',
#   'see',
#   'you',
#   'around',
#   'en',
#   'boca',
#   'cocktail'],
#  ['remembering',
#   'warmer',
#   'days',
#   'a',
#   'month',
#   'ago',
#   'boowinter',
#   'wehateyou',
#   'flags',
#   'communitycenter',
#   'footballclub',
#   'morning',
#   'catwalk'],
#  ["i'm",
#   'over',
#   'my',
#   'avoidance',
#   'of',
#   'the',
#   'cold',
#   'in',
#   'the',
#   'mornings',
#   'halo',
#   'angelcat',
#   'sunrise',
#   'catwalk',
#   'gatosconcorrea'],
#  ['i',
#   'found',
#   'a',
#   'box',
#   'to',
#   'sit',
#   'on',
#   'in',
#   'the',
#   'bushes',
#   'catsandboxes',
#   'barrio',
#   'catwalk',
#   'barcelona',
#   'bethelona',
#   'barcelonacat'],
#  ['home',
#   'caturday',
#   'neighbourhood',
#   'sunshine',
#   'autumn',
#   'barcelona',
#   'bethelona',
#   'barcelonacat',
#   'gatobarcelonés'],
#  ['i',
#   'do',
#   'work',
#   'as',
#   'well',
#   'sometimes',
#   "that's",
#   'me',
#   'presenting',
#   'some',
#   'slides',
#   'at',
#   'the',
#   'sitecore',
#   'user',
#   'group'],
#  ["it's",
#   'time',
#   'to',
#   'love',
#   'berdieamor',
#   'love',
#   'sparklingwine',
#   'en',
#   'born',
#   'voraz'],
#  ['·pla',
#   'de',
#   'la',
#   'garsa·patatas',
#   'mini',
#   'papas',
#   'guays',
#   'y',
#   'chips',
#   'caseras',
#   'salsas',
#   'ajonesa',
#   'y',
#   'oil',
#   'especiat'],
#  ['goodmorning',
#   'from',
#   'barcelonaspain',
#   'barcelona',
#   'barcelonaspain',
#   'hubby',
#   'hubbytime'],
#  ['know',
#   'the',
#   'rules',
#   'well',
#   'so',
#   'you',
#   'can',
#   'break',
#   'them',
#   'efficiently',
#   'restaurant',
#   'cheeso',
#   'hotel',
#   'melia'],
#  ['after',
#   'a',
#   'whole',
#   'day',
#   'of',
#   'coaching',
#   'i',
#   'feel',
#   'tired',
#   'but',
#   'happy',
#   'ilovemyjob',
#   'barcelona',
#   'trainer',
#   'coach'],
#  ['carla',
#   'x',
#   'massimo',
#   'dutti',
#   'here',
#   'my',
#   'experience',
#   'at',
#   'the',
#   'massimodutti',
#   'new',
#   'store',
#   'in',
#   'portal',
#   'del',
#   'angel'],
#  ['last',
#   'day',
#   'in',
#   'barcelona',
#   'getting',
#   'some',
#   'sun',
#   'some',
#   'tapas',
#   'and',
#   'sangria',
#   'oh',
#   'and',
#   "i'll",
#   'take',
#   'it',
#   'outside'],
#  ['throwback',
#   'to',
#   'when',
#   'all',
#   'i',
#   'needed',
#   'to',
#   'worry',
#   'about',
#   'was',
#   'making',
#   'sure',
#   'my',
#   'hands',
#   'were',
#   'steady',
#   'for',
#   'night'],
#  ['forder',
#   'sport',
#   'arena',
#   'converted',
#   'into',
#   'a',
#   'shopping',
#   'mall',
#   'arenas',
#   'de',
#   'barcelona'],
#  ['the',
#   'arenas',
#   'de',
#   'barcelona',
#   'is',
#   'a',
#   'former',
#   'bullring',
#   'turned',
#   'commercial',
#   'complex',
#   'near',
#   'the',
#   'plaça',
#   "d'espanya"],
#  ['if',
#   'you',
#   'got',
#   'a',
#   'good',
#   'boy',
#   'bill',
#   'cause',
#   "there's",
#   'a',
#   'lot',
#   'of'],
#  ['the',
#   'proper',
#   'way',
#   'to',
#   'navigate',
#   'a',
#   'traffic',
#   'circle',
#   'grayboys',
#   'honeymoon',
#   'spain'],
#  ['sevillanos',
#   'en',
#   'barça',
#   'i',
#   'ironically',
#   'probably',
#   'learned',
#   'more',
#   'andaluz',
#   'than',
#   'catalán',
#   'in',
#   'barcelona',
#   'en'],
#  ['movie', 'timejusticeleague', 'jhaifátakesbarcelona', 'en', 'arenas', 'de'],
#  ['barcelona',
#   'from',
#   'above',
#   'and',
#   'on',
#   'the',
#   'beach',
#   'travel',
#   'spain',
#   'barcelona',
#   'wanderlust',
#   'seetheworld'],
#  ['seven',
#   'days',
#   'seven',
#   'black',
#   'and',
#   'white',
#   'photos',
#   'no',
#   'people',
#   'or',
#   'explanations',
#   'franzibroetchen',
#   'barcelona'],
#  ['long',
#   'retired',
#   'bull',
#   'fighting',
#   'arena',
#   'converted',
#   'into',
#   'a',
#   'shopping',
#   'center',
#   'barcelona',
#   'arenasdebarcelona'],
#  ['total',
#   'abandon',
#   'a',
#   'girl',
#   'swings',
#   'as',
#   'high',
#   'as',
#   'she',
#   'can',
#   'eyes',
#   'closed',
#   'not',
#   'a',
#   'care',
#   'in',
#   'the',
#   'world',
#   'nor'],
#  ['com',
#   "t'haig",
#   'de',
#   'dir',
#   'que',
#   'no',
#   "m'agrada",
#   'que',
#   'em',
#   'banys',
#   'how',
#   'can',
#   'i',
#   'say',
#   'that',
#   'i',
#   'hate',
#   'the',
#   'bath',
#   'sky'],
#  ['this',
#   'is',
#   'where',
#   'we',
#   'part',
#   'ways',
#   'as',
#   'i',
#   'was',
#   'thinking',
#   'about',
#   'the',
#   'things',
#   'for',
#   'which',
#   'i',
#   'am',
#   'grateful',
#   'during'],
#  ['quite',
#   'possibly',
#   'the',
#   'best',
#   'croissant',
#   'pastries',
#   'in',
#   'all',
#   'the',
#   'land',
#   'breakfast',
#   'sunday',
#   'barcelona'],
#  ['when',
#   'dedication',
#   'love',
#   'is',
#   'put',
#   'in',
#   'the',
#   'kitchen',
#   'gastronomy',
#   'takes',
#   'another',
#   'level',
#   'disfrutarbcn',
#   'with'],
#  ['monday',
#   'th',
#   'november',
#   'loco',
#   'lunes',
#   'opium',
#   'barcelonaparty',
#   'info'],
#  ['black', 'label', 'time', 'at', 'cdlcbarcelona', 'in', 'barcelona'],
#  ['dance', 'baby', 'dance', 'at', 'opiumbarcelona', 'in', 'barcelona'],
#  ['friday',
#   'th',
#   'november',
#   'look',
#   'at',
#   'me',
#   'opium',
#   'barcelonaparty',
#   'info'],
#  ['me',
#   'trying',
#   'to',
#   'figure',
#   'out',
#   'why',
#   'i',
#   'went',
#   'to',
#   'a',
#   'bar',
#   'made',
#   'out',
#   'of',
#   'ice',
#   'in',
#   'the',
#   'middle',
#   'of',
#   'november'],
#  ['on',
#   'thursdays',
#   'cdlcbarcelona',
#   'cdlcbarcelona',
#   'thursday',
#   'housemusic',
#   'partynight',
#   'barcelonanights'],
#  ['celebrity',
#   'gettogether',
#   'circa',
#   'from',
#   'left',
#   'to',
#   'right',
#   'future',
#   'pitchfork',
#   'chief',
#   'editor',
#   'xander'],
#  ['saxattacking',
#   'shokobcn',
#   'with',
#   'my',
#   'pal',
#   'tonistorella',
#   'on',
#   'deks',
#   'as',
#   'u',
#   'can',
#   'see',
#   "we're",
#   'working',
#   'hard'],
#  ['for', 'sale', 'bedroom', 'apartment', 'barcelona'],
#  ['i',
#   'was',
#   'just',
#   'outside',
#   'of',
#   'barcelona',
#   'hiking',
#   'in',
#   'the',
#   'foothills',
#   'of',
#   'mount',
#   'tibidabo',
#   'lapedrera'],
#  ['another',
#   'of',
#   'gaudí',
#   'la',
#   'pedrera',
#   'lapedrera',
#   'gaudí',
#   'spain',
#   'architectureporn',
#   'casamilà'],
#  ['gaudi',
#   'created',
#   'catenary',
#   'arches',
#   'such',
#   'as',
#   'these',
#   'which',
#   'hold',
#   'up',
#   'the',
#   'magnificent',
#   'rooftop',
#   'of',
#   'casa'],
#  ['warmest',
#   'of',
#   'goodbyes',
#   'to',
#   'barcelona',
#   'day',
#   'from',
#   'the',
#   'fabulously',
#   'weird',
#   'rooftop',
#   'of',
#   'casa',
#   'milà',
#   'aka',
#   'la'],
#  ['gaudi',
#   'barcelona',
#   'catalonia',
#   'spain',
#   'espana',
#   'nyphotographer',
#   'hansimages',
#   'la',
#   'pedreracasa',
#   'milà'],
#  ['barcelona', 'spain', 'weekendgetaway', 'la', 'pedreracasa', 'milà'],
#  ['just', 'posted', 'a', 'photo', 'la', 'pedreracasa', 'milà'],
#  ['benvolguts',
#   'reis',
#   'macs',
#   "d'orient",
#   'no',
#   'insistiu',
#   'no',
#   'el',
#   'vull',
#   'marmell',
#   'tesla',
#   'great',
#   'la'],
#  ['one',
#   'last',
#   'selfie',
#   'barcelona',
#   'theuncommonselfieofcatymogo',
#   "gaudí's",
#   'la',
#   'pedrera',
#   'casa',
#   'milà'],
#  ["servants'",
#   'quarters',
#   'obviously',
#   'lapedrera',
#   'gaudi',
#   'la',
#   'pedreracasa',
#   'milà'],
#  ['ornament', 'brings', 'joy', 'la', 'pedreracasa', 'milà'],
#  ['architecture',
#   'without',
#   'limits',
#   'in',
#   'one',
#   'word',
#   'gaudí',
#   'la',
#   'pedreracasa',
#   'milà'],
#  ['new',
#   'and',
#   'innovative',
#   'ways',
#   'to',
#   'do',
#   'business',
#   'at',
#   'business',
#   'mindsets',
#   'la',
#   'innovation',
#   'kitchen',
#   'de'],
#  ['así',
#   'fue',
#   'nuestro',
#   'trendslab',
#   'interdependence',
#   'la',
#   'innovation',
#   'kitchen',
#   'de',
#   'designthinkers',
#   'group'],
#  ['barcelona',
#   'sensefiltres',
#   'fotoscel',
#   'igersbcn',
#   'monday',
#   'en',
#   'maria',
#   'cristina',
#   'station'],
#  ['abirradero',
#   'drinking',
#   'an',
#   'amb',
#   'malt',
#   "d'arròs",
#   'by',
#   'segadors',
#   'del',
#   'delta',
#   'at',
#   'abirradero',
#   'photo'],
#  ['new',
#   'update',
#   'for',
#   'almostaherogame',
#   'is',
#   'out',
#   'i',
#   'did',
#   'this',
#   'illustration',
#   'for',
#   'one',
#   'of',
#   'our',
#   'game',
#   'modes'],
#  ['morning',
#   'everyone',
#   'hartonohosea',
#   'h',
#   'photography',
#   'h',
#   'travel',
#   'h',
#   'travelography',
#   'barcelona',
#   'spain',
#   'nh'],
#  ['barcelona',
#   'plaza',
#   'de',
#   'españa',
#   'usk',
#   'urbansketchers',
#   'en',
#   'plaza',
#   'de',
#   'españa',
#   'barcelona'],
#  ['pretty', 'bite', 'bartickets', 'meatlessmonday', 'tickets', 'tapas', 'bar'],
#  ['the',
#   'm',
#   'e',
#   'c',
#   'c',
#   'a',
#   'of',
#   'tapas',
#   'this',
#   "one's",
#   'for',
#   'you',
#   'amandaasun',
#   'ticketstapasbar',
#   'tapas',
#   'juneatsworld'],
#  ['insider',
#   'tips',
#   'on',
#   'tickets',
#   'bar',
#   'by',
#   'foodieling',
#   'in',
#   'travel',
#   'with',
#   'ling',
#   'ticketsbar',
#   'barcelona'],
#  ['beat',
#   'my',
#   'best',
#   'today',
#   "it's",
#   'not',
#   'much',
#   'but',
#   'very',
#   'happy',
#   'running',
#   'runner',
#   'runningman',
#   'runnerslife'],
#  ['escapada',
#   'a',
#   'la',
#   'zona',
#   'centro',
#   'friends',
#   'ave',
#   'chucuchudeltren',
#   'en',
#   'ave',
#   'barcelona',
#   'madrid'],
#  ['above', 'the', 'clouds', 'en', 'montserrat'],
#  ['spidermiranda',
#   'sensorex',
#   'fujifilm',
#   'c',
#   'filmisnotdead',
#   'filmphotography',
#   'filmcommunity'],
#  ['family', 'reunited', 'on', 'a', 'great', 'dinner', 'thanks', 'for'],
#  ['having',
#   'best',
#   'dinner',
#   'ever',
#   'with',
#   'mates',
#   'antonioilivebarcelona'],
#  ['catch', 'it', 'ferozbcn', 'happy'],
#  ['family',
#   'reunited',
#   'happy',
#   'birthday',
#   'emiliojoserv',
#   "you're",
#   'the',
#   'best',
#   'and'],
#  ['life', 'is', 'also', 'like', 'this', 'game', 'i', 'a', 'always'],
#  ['vamos',
#   'a',
#   'comer',
#   'pizza',
#   'tomassopizza',
#   'bcn',
#   'lunch',
#   'office',
#   'newyorkpizza',
#   'tomasso',
#   'new',
#   'york',
#   'pizza'],
#  ['crees',
#   'que',
#   'tengo',
#   'la',
#   'x',
#   'de',
#   'x',
#   'factor',
#   'global',
#   'cantante',
#   'vocalista',
#   'do',
#   'you',
#   'think',
#   'have',
#   'i',
#   'the',
#   'x',
#   'of'],
#  ['blue',
#   'skies',
#   'and',
#   'sunshine',
#   'in',
#   'barcelona',
#   'the',
#   'gates',
#   'hotel',
#   'barcelona'],
#  ['cure', 'betty', "ford's", 'in', 'barcelona'],
#  ['last',
#   'tuesday',
#   'hydeclub',
#   'honored',
#   'to',
#   'play',
#   'leocostarelli',
#   'anniversary',
#   'with',
#   'my',
#   'pal',
#   'xordee',
#   'on',
#   'deks'],
#  ['stayingaliveworkout',
#   'training',
#   'fit',
#   'neversettle',
#   'spoonie',
#   'lifestyle',
#   'sport',
#   'women'],
#  ['obeyyourbodybcn',
#   'obeyyourbody',
#   'family',
#   'prechristmas',
#   'hydeclub',
#   'hyde',
#   'club'],
#  ['breakfast', 'restaurant', 'els', 'barrils'],
#  ['aprovecha',
#   'los',
#   'blackfridays',
#   'toyotateams',
#   'toyotaesp',
#   'clubracc',
#   'thebarcelonist',
#   'en',
#   'toyota',
#   'teams',
#   'motor'],
#  ['sunday',
#   'funday',
#   'wishing',
#   'a',
#   'could',
#   'skate',
#   'like',
#   'a',
#   'pro',
#   'iceskating',
#   'ice',
#   'winter',
#   'fun'],
#  ['time',
#   'to',
#   'recharge',
#   'and',
#   'get',
#   'changed',
#   'and',
#   'grab',
#   'a',
#   'towel',
#   'metro',
#   'arc',
#   'de',
#   'triomf',
#   'tmbbarcelona',
#   'in',
#   'barcelona'],
#  ['winter', 'where', 'en', 'black', 'and', 'white'],
#  ['wide',
#   'churchill',
#   'for',
#   'sunday',
#   'afternoon',
#   'at',
#   'the',
#   'plaza',
#   'habano',
#   'puro',
#   'cigar',
#   'romeoyjulieta'],
#  ['get',
#   'up',
#   'work',
#   '[enjoy]',
#   'sleep',
#   'repeat',
#   'workroutine',
#   'upc',
#   'facultatdematematiques'],
#  ['hotel',
#   'barcelone',
#   'morning',
#   'love',
#   'paisible',
#   'à',
#   'hotel',
#   'boutique',
#   'hostemplo'],
#  ['christine',
#   'the',
#   'benefit',
#   'concert',
#   'nov',
#   'was',
#   'a',
#   'wrap',
#   'dreams',
#   'come',
#   'true',
#   'if',
#   'you',
#   'work',
#   'hard',
#   'for',
#   'it',
#   'mine',
#   'came'],
#  ['last', 'night', 'mkmalarkey', 'en', 'bikini'],
#  ['new',
#   'post',
#   'on',
#   'my',
#   'blogriskandwinautumn',
#   'love',
#   'happy',
#   'girl',
#   'cute'],
#  ['i',
#   'like',
#   'soo',
#   'much',
#   'this',
#   'kind',
#   'of',
#   'breakfastselvamicroclub',
#   'poblenou',
#   'am',
#   'till',
#   'late',
#   'en',
#   'selva'],
#  ['two',
#   'pears',
#   'watercolor',
#   'winsorandnewton',
#   'contemporaryart',
#   'art',
#   'i',
#   'col',
#   'lec',
#   'claudia',
#   'vives',
#   'fierro'],
#  ['moments', 'en', 'hotel', 'granvía'],
#  ['nektriacreandofuturodefiniendomisionyvisionvaloresgranequipoinnovaciontechnologypersona'],
#  ['kids', 'on', 'the', 'stage', 'tedxhoritzoschool'],
#  ['tagsforlikes',
#   'tagsforlikesapp',
#   'tflers',
#   'tweegram',
#   'photooftheday',
#   'amazing',
#   'building'],
#  ['hoy',
#   'os',
#   'echare',
#   'de',
#   'menos',
#   'black',
#   'friday',
#   'is',
#   'here',
#   'bf',
#   'blackfriday',
#   'blackfridayparty'],
#  ['yesterday',
#   'we',
#   'went',
#   'to',
#   'the',
#   'set',
#   'where',
#   'they',
#   'film',
#   'the',
#   'tv',
#   'program',
#   'we',
#   'used',
#   'to',
#   'watch',
#   'when',
#   'we',
#   'were',
#   'kids'],
#  ['listen',
#   'to',
#   'mr',
#   'murray',
#   'vía',
#   'esquire',
#   'livethelifeyoulove',
#   'tuesday',
#   'billysays'],
#  ['love',
#   'uobarcelona',
#   'barcelona',
#   'urbanstyle',
#   'colorventures',
#   'creativedesign',
#   'photooftheday'],
#  ['double', 'trouble', 'en', 'urban', 'outfitters', 'barcelona'],
#  ['baby', 'i', 'know', 'you', 'better', 'en', 'teatre', 'grec'],
#  ['ruins', 'still', 'in', 'use', 'today', 'teatre', 'grec'],
#  ['sundays', 'hat', 'sunglasses', 'en', 'parc', 'del', 'laberint', "d'horta"],
#  ['el',
#   'laberinto',
#   'del',
#   'fauno',
#   'el',
#   'perfume',
#   'dreams',
#   'are',
#   'real',
#   'perfume',
#   'panslabyrinth',
#   'laberintodehorta'],
#  ['be',
#   'proud',
#   'of',
#   'yourself',
#   'for',
#   'how',
#   'far',
#   'you',
#   'have',
#   'come',
#   'and',
#   'never',
#   'stop',
#   'pushing',
#   'to',
#   'be',
#   'the',
#   'best',
#   'you',
#   'can'],
#  ['hidden',
#   'places',
#   'park',
#   'laberynth',
#   'green',
#   'stairs',
#   'symetry',
#   'walking',
#   'travel',
#   'trip',
#   'hiddenplace'],
#  ['día',
#   'fotos',
#   'blanco',
#   'y',
#   'negro',
#   'de',
#   'mi',
#   'vida',
#   'blackandwhite',
#   'snail',
#   'stilllife',
#   'walking',
#   'somewhere'],
#  ['have',
#   'i',
#   'shown',
#   'you',
#   'my',
#   'cat',
#   'yet',
#   'the',
#   'most',
#   'tired',
#   'moments',
#   'i',
#   'am',
#   'are',
#   'also',
#   'the',
#   'moments',
#   'which',
#   'i',
#   'am'],
#  ['artederua',
#   'artecallejero',
#   'barcelona',
#   'graffiti',
#   'igeurope',
#   'streetart',
#   'streetphotography'],
#  ['barcelona',
#   'catalonia',
#   'igeurope',
#   'pelalibertacaodepresospoliticos',
#   'streetphotography',
#   'tweetgram'],
#  ['artederua',
#   'artecallejero',
#   'barcelona',
#   'catalonia',
#   'graffiti',
#   'graffitiart',
#   'igeurope',
#   'streetart'],
#  ['the',
#   'one',
#   'who',
#   'destroys',
#   'her',
#   'own',
#   "band's",
#   'merch',
#   'by',
#   'nestropic',
#   'barri'],
#  ['khaleesi',
#   'catlover',
#   'love',
#   'sleepykitten',
#   'beauty',
#   'en',
#   'barri',
#   'de',
#   'gracia'],
#  ['architecturephotography',
#   'architecture',
#   'bnwofourworld',
#   'bnwphotografare',
#   'barcelona',
#   'catalunya'],
#  ['autumnwinter',
#   'will',
#   'feature',
#   'rich',
#   'materials',
#   'and',
#   'gemstone',
#   'colors',
#   'including',
#   'textiles',
#   'on',
#   'a'],
#  ['morning',
#   'light',
#   'at',
#   'espacioenblancoestudio',
#   'homestudio',
#   'interiordesign',
#   'en',
#   'espacioenblanco'],
#  ['na',
#   'ja',
#   'baden',
#   'im',
#   'stock',
#   'hat',
#   'schon',
#   'was',
#   'hotel',
#   'barcelona',
#   'princess',
#   'bcnprincess'],
#  ['beautiful',
#   'day',
#   'and',
#   'night',
#   'view',
#   'from',
#   'the',
#   'rd',
#   'floor',
#   'hotel',
#   'barcelona',
#   'princess'],
#  ['disfrutar',
#   'barcelona',
#   'multi',
#   'spherical',
#   'tatin',
#   'of',
#   'foie',
#   'gras',
#   'and',
#   'corn',
#   'love',
#   'the',
#   'sweetness',
#   'of'],
#  ['visit',
#   'masterclassmasterprotocolblanquerna',
#   'publicaffairs',
#   'growing',
#   'learning'],
#  ['years',
#   'after',
#   'my',
#   'last',
#   'visit',
#   'to',
#   'the',
#   'most',
#   'unique',
#   'church',
#   'in',
#   'the',
#   'world',
#   "there's",
#   'something',
#   'new',
#   'will'],
#  ['definitely',
#   'one',
#   'of',
#   'the',
#   'most',
#   'unusual',
#   'basilicas',
#   "i've",
#   'seen',
#   'in',
#   'my',
#   'travels',
#   'the',
#   'architecture',
#   'is',
#   'like'],
#  ['the',
#   'captivating',
#   'cathedral',
#   'of',
#   'barcelona',
#   'glad',
#   'i',
#   'got',
#   'to',
#   'see',
#   'it',
#   'barcelona',
#   'segradafamilia'],
#  ['in',
#   'the',
#   'presence',
#   'of',
#   'greatness',
#   'gaudi',
#   'sagradafamilia',
#   'barcelona',
#   'sagrada',
#   'familia',
#   'metropolitana'],
#  ['taller',
#   'aniversario',
#   'scrapbook',
#   'inspiration',
#   'texture',
#   'craft',
#   'elements',
#   'mixedmedia',
#   'collage'],
#  ['it',
#   'started',
#   'with',
#   'a',
#   'little',
#   'flower',
#   'on',
#   'the',
#   'wall',
#   'barri',
#   'de',
#   'gracia',
#   'barcelona'],
#  ['it',
#   'started',
#   'with',
#   'a',
#   'little',
#   'flower',
#   'on',
#   'the',
#   'wall',
#   'barri',
#   'de',
#   'gracia',
#   'barcelona'],
#  ['we',
#   'may',
#   'have',
#   'overshot',
#   'the',
#   'target',
#   'when',
#   'we',
#   'ordered',
#   'the',
#   'paella',
#   'barri',
#   'de',
#   'gracia',
#   'barcelona'],
#  ['barcelona',
#   'catalunya',
#   'graffitiart',
#   'graffiti',
#   'igeurope',
#   'strretphotography',
#   'tweetgram'],
#  ['cigar',
#   'and',
#   'coffee',
#   'after',
#   'doing',
#   'groceries',
#   'cigar',
#   'puro',
#   'robusto',
#   'vegafina',
#   'nicaragua',
#   'coffee'],
#  ['just',
#   'posted',
#   'a',
#   'photo',
#   'zelinda',
#   'milano',
#   'decoración',
#   'floral',
#   'y',
#   'de',
#   'interior'],
#  ['frisbeefun',
#   'beachvolley',
#   'sailboats',
#   'are',
#   'out',
#   'to',
#   'enjoy',
#   'another',
#   'beautifulday',
#   'of',
#   'sunnywinter',
#   'in'],
#  ['canframis',
#   'miquistepsart',
#   'artgallery',
#   'artcatalà',
#   'catalanart',
#   'fundacióvilacasas',
#   'painting'],
#  ['barcelona', 'reflection', 'en', 'parc', 'de', 'les', 'tres', 'xemeneies'],
#  ['insider',
#   'tips',
#   'on',
#   'tickets',
#   'bar',
#   'by',
#   'foodieling',
#   'in',
#   'travel',
#   'with',
#   'ling',
#   'ticketsbar',
#   'barcelona'],
#  ['dam',
#   'that',
#   'was',
#   'a',
#   'big',
#   'hill',
#   'park',
#   'güell',
#   'in',
#   'barcelona'],
#  ['lifeisgood',
#   'because',
#   'friendship',
#   'is',
#   'build',
#   'one',
#   'wine',
#   'glass',
#   'of',
#   'wine'],
#  ['happiness', 'tribute', 'to', 'legend', 'mgranollers', 'fun', 'friends'],
#  ['sisters',
#   'resting',
#   'after',
#   'a',
#   'rainy',
#   "night's",
#   'visit',
#   'to',
#   "gaudi's",
#   'la',
#   'pedrera',
#   'casa',
#   'mila',
#   'in',
#   'barcelona'],
#  ['wdc',
#   'bcn',
#   'happy',
#   'to',
#   'share',
#   'one',
#   'or',
#   'two',
#   'cañitas',
#   'with',
#   'these',
#   'lovely'],
#  ['keeponwiththekeepingon', 'lasagradafamilia', 'myspanishexperience'],
#  ['high',
#   'af',
#   'ak',
#   'and',
#   'lemon',
#   'hash',
#   'starting',
#   'my',
#   'journey',
#   'in'],
#  ['y',
#   'en',
#   'otoño',
#   'barcelona',
#   'sagradafamilia',
#   'friday',
#   'instalike',
#   'instagood',
#   'bcn',
#   'spain',
#   'en'],
#  ['listenning',
#   'to',
#   'mwcbarcelona',
#   'and',
#   'their',
#   'experience',
#   'in',
#   'mobile',
#   'with',
#   'our',
#   'gmdb',
#   'students',
#   'from'],
#  ['natural', 'and', 'tasty', 'food', 'ikea', 'hospitalet'],
#  ['lighting',
#   'lovers',
#   'love',
#   'heart',
#   'street',
#   'barcelona',
#   'art',
#   'light',
#   'picoftheday',
#   'streetart',
#   'à',
#   'les',
#   'corts'],
#  ["it's",
#   'nice',
#   'to',
#   'meet',
#   'different',
#   'people',
#   'from',
#   'around',
#   'the',
#   'world',
#   'and',
#   'share',
#   'your',
#   'life',
#   'stories',
#   'when',
#   'you'],
#  ['happy',
#   'to',
#   'meet',
#   'you',
#   'my',
#   'friend',
#   'daniclos',
#   "i'm",
#   'so',
#   'proud',
#   'of',
#   'you',
#   'for',
#   'your'],
#  ['empezamos',
#   'con',
#   'un',
#   'buen',
#   'vermouth',
#   'por',
#   'barcelonaviaje',
#   'por',
#   'el',
#   'modernismofonda'],
#  ['this',
#   'great',
#   'join',
#   'venture',
#   'and',
#   'friendship',
#   'gold',
#   'worth',
#   'working',
#   'is',
#   'also'],
#  ['jnunyez',
#   'dynamic',
#   'pricing',
#   'powered',
#   'by',
#   'block',
#   'chain',
#   'no',
#   'doubt'],
#  ['barcelona',
#   'bnwofourworld',
#   'bnwphotografare',
#   'catalunya',
#   'catalonia',
#   'igeurope'],
#  ['barcelona',
#   'bnwofourworld',
#   'bnwphotografare',
#   'catalunya',
#   'catalonia',
#   'igeurope'],
#  ['barcelona',
#   'bnwofourworld',
#   'bnwphotografare',
#   'catalunya',
#   'catalonia',
#   'igeurope'],
#  ['barcelona',
#   'bnwofourworld',
#   'bnwphotografare',
#   'catalunya',
#   'catalonia',
#   'igeurope'],
#  ['live',
#   'in',
#   'the',
#   'moment',
#   'and',
#   'seize',
#   'the',
#   'day',
#   'carpethatfuckingdiem',
#   'carpe',
#   'diem',
#   'cdlc'],
#  ['wine',
#   'and',
#   'tapas',
#   'love',
#   'babeface',
#   'barcelona',
#   'wineteeth',
#   'theuncommonselfieofcatymogo',
#   'sagardi',
#   'bcn'],
#  ['tapas',
#   'are',
#   'officially',
#   'the',
#   'best',
#   'thing',
#   'ever',
#   'petition',
#   'to',
#   'bring',
#   'tapas',
#   'to',
#   'asbury',
#   'k',
#   'sagardi',
#   'bcn'],
#  ['at', 'consum', 'basic', 'in', 'barcelona'],
#  ['barcelona',
#   'is',
#   'simply',
#   'awesome',
#   'techno',
#   'deeptechno',
#   'house',
#   'deephouse',
#   'dj',
#   'producer',
#   'skater'],
#  ['with',
#   'fish',
#   'chips',
#   'drinking',
#   'a',
#   'zlist',
#   'by',
#   'garagebeerco',
#   'at',
#   'garagebeerco',
#   'photo'],
#  ['best',
#   'freaking',
#   'guitar',
#   'store',
#   'in',
#   'europe',
#   'fanaticguitars',
#   'spain',
#   'barcelona',
#   'guitar',
#   'fanatic',
#   'guitars'],
#  ['the', 'back', 'side', 'basílica', 'de', 'la', 'sagrada', 'família'],
#  ['i',
#   'joined',
#   'a',
#   'free',
#   'gaudi',
#   'walking',
#   'tour',
#   'in',
#   'barcelona',
#   'and',
#   'we',
#   'ended',
#   'it',
#   'at',
#   'basilica',
#   'de',
#   'la',
#   'sagrada'],
#  ['catedral',
#   'sagrada',
#   'familia',
#   'en',
#   'sagrada',
#   'familia',
#   'metropolitana',
#   'di',
#   'barcellona'],
#  ['i',
#   "didn't",
#   'manage',
#   'to',
#   'get',
#   'my',
#   'bookings',
#   'in',
#   'for',
#   'el',
#   'cellar',
#   'de',
#   'can',
#   'roca',
#   "it's",
#   'an',
#   'month',
#   'waitlist'],
#  ['h',
#   'mcfitclot',
#   'que',
#   'empiece',
#   'el',
#   'díamcfites',
#   'mcfit',
#   'fitness',
#   'fitnessmotivation',
#   'motivation'],
#  ['buenos',
#   'días',
#   'journalism',
#   'journalist',
#   'girl',
#   'woman',
#   'elmundodeportivo',
#   'fomentmartinenc'],
#  ['good',
#   'vibes',
#   'welcome',
#   'with',
#   'tupelu',
#   'design',
#   'socialmedia',
#   'branding',
#   'video',
#   'sales'],
#  ['bcn',
#   'urbansketchersbcn',
#   'draft',
#   'drawing',
#   'art',
#   'illustration',
#   'artist',
#   'sketchbook',
#   'pencil',
#   'artwork'],
#  ['nights', 'en', 'pacha', 'club', 'barcelona'],
#  ['a',
#   'cheeky',
#   'selfyvideo',
#   'of',
#   'me',
#   'on',
#   'top',
#   'of',
#   'montserrat',
#   'in',
#   'it',
#   'was',
#   'truly',
#   'a',
#   'good'],
#  ['a',
#   'cheeky',
#   'selfyvideo',
#   'of',
#   'me',
#   'on',
#   'top',
#   'of',
#   'montserrat',
#   'in',
#   'it',
#   'was',
#   'truly',
#   'a',
#   'good'],
#  ['tbt', 'to', 'barcelona', 'shot', 'by', 'rumala', 'travel'],
#  ['la',
#   'llegenda',
#   'continua',
#   'tirantlojaume',
#   'aroun',
#   'the',
#   'world',
#   'a',
#   'climbat',
#   'nature',
#   'climbing'],
# ...
#   'bordo',
#   'de',
#   'la',
#   'compañia'],
#  ['the',
#   'more',
#   'often',
#   'we',
#   'see',
#   'the',
#   'things',
#   'around',
#   'us',
#   'even',
#   'the',
#   'beautiful',
#   'and',
#   'wonderful',
#   'things',
#   'the',
#   'more'],
#  ['free',
#   'is',
#   'always',
#   'good',
#   'tapas',
#   'amusebouche',
#   'barcelona',
#   'eat',
#   'eeeeeats',
#   'eater',
#   'foodporn'],
#  ['happyhalloween', 'sweetdreams', 'buah'],
#  ['això',
#   'és',
#   'una',
#   'sabata',
#   'graffiti',
#   'pintada',
#   'art',
#   'arturbà',
#   'urbanart',
#   'gothic',
#   'quarter',
#   'barcelona'],
#  ['happyhalloween', 'en'],
#  ['mi',
#   'nuevo',
#   'mando',
#   'a',
#   'distanciastartrek',
#   'discovery',
#   'en',
#   'poblenou'],
#  ['photo', 'by', 'bertlivephoto', 'selected', 'by'],
#  ['finally',
#   'made',
#   'it',
#   'in',
#   'the',
#   'early',
#   'morning',
#   'after',
#   'dancing',
#   'the',
#   'night',
#   'away',
#   'turns',
#   'out',
#   'a',
#   'new',
#   'friend',
#   'lives'],
#  ['shadow',
#   'of',
#   'timelast',
#   'day',
#   'of',
#   'b',
#   'w',
#   'days',
#   'challenge',
#   'no',
#   'people',
#   'no',
#   'explanation',
#   'thanks'],
#  ['one',
#   'of',
#   'my',
#   'favourite',
#   'views',
#   'in',
#   'barcelona',
#   'where',
#   'is',
#   'this',
#   'place',
#   'for',
#   'you',
#   'to',
#   'sit',
#   'for'],
#  ['casamilàcasamilaknown',
#   'as',
#   'lapedreralapedreragaudibarcelonamodernisme',
#   'a',
#   'reference',
#   'to',
#   'its'],
#  ['y',
#   'si',
#   'ya',
#   'nivel',
#   'toma',
#   'ya',
#   'pokemongo',
#   'pokemon',
#   'new',
#   '',
#   'nuevo',
#   'halloween',
#   'duskull',
#   'shiny'],
#  ['modelo',
#   'clásica',
#   'en',
#   'stock',
#   'lafabriquedecarreauxciment',
#   'flores',
#   'handmade',
#   'pinarmiro'],
#  ['la',
#   'sagrada',
#   'familiahdr',
#   'nikon',
#   'photography',
#   'travellingram',
#   'barcelona',
#   'travel',
#   'en',
#   'basílica',
#   'de',
#   'la'],
#  ['sagrada',
#   'familia',
#   'barcelona',
#   'holiday',
#   'sunshine',
#   'spain',
#   'home',
#   'sagradafamilia',
#   'gaudi',
#   'weekend'],
#  ['bcn',
#   'baecelona',
#   'catalonia',
#   'europe',
#   'culture',
#   'beauty',
#   'architecture',
#   'morning',
#   '',
#   'en',
#   'basílica',
#   'de',
#   'la'],
#  ['a',
#   'love',
#   'untold',
#   'sagradafamilia',
#   'barcelona',
#   'spain',
#   'español',
#   'europe',
#   'vacation',
#   'basílica',
#   'de',
#   'la'],
#  ['women',
#   'pelirroja',
#   'redhair',
#   'ginger',
#   'hairstreet',
#   'style',
#   'hairporn',
#   'curly',
#   'hairstyle',
#   'curlyhair'],
#  ['when',
#   'barcelona',
#   'totally',
#   'feels',
#   'like',
#   'paris',
#   'metro',
#   'barna',
#   'catalunya',
#   'españa',
#   'catalonia',
#   'spain'],
#  ['barcelona',
#   'rooftop',
#   'rooftopview',
#   'instaview',
#   'wow',
#   'awesome',
#   'amazing',
#   'gorgeous',
#   'spain',
#   'españa'],
#  ['waiting',
#   'for',
#   'puigdemont',
#   'will',
#   'he',
#   'come',
#   'or',
#   'not',
#   'palau',
#   'de',
#   'la',
#   'generalitat',
#   'de',
#   'catalunya'],
#  ['one',
#   'more',
#   'pic',
#   'of',
#   'my',
#   'first',
#   'day',
#   'in',
#   'barcelona',
#   'magical',
#   'lapedrera',
#   'gaudi',
#   'barna',
#   'catalunya'],
#  ['and',
#   'i',
#   'can',
#   'taste',
#   'it',
#   "it's",
#   'my',
#   'sweet',
#   'beginning',
#   'andreeaurbiina',
#   'mossèn',
#   'costa',
#   'i',
#   'llobera',
#   'gardens'],
#  ['catch',
#   'me',
#   'this',
#   'saturday',
#   'cdlcbarcelona',
#   'ready',
#   'for',
#   'a',
#   'magical',
#   'night',
#   'en',
#   'cdlc',
#   'barcelona'],
#  ['disfrutar',
#   'disfrutarbcn',
#   'which',
#   'means',
#   "'enjoy'",
#   'in',
#   'english',
#   'is',
#   'brought',
#   'to',
#   'us',
#   'by',
#   'chefs',
#   'who',
#   'worked'],
#  ['i',
#   'like',
#   'to',
#   'watch',
#   'over',
#   'the',
#   'high',
#   'wall',
#   'catonaledge',
#   'hospital',
#   'moon',
#   'graffiti',
#   'gato',
#   'gatosiberiano',
#   'siberiancat'],
#  ['step', 'by', 'step', 'en', 'la', 'pedreracasa', 'milà'],
#  ['drinking',
#   'an',
#   'estrella',
#   'galicia',
#   'by',
#   'mundohr',
#   'at',
#   'pulperiagudina'],
#  ['the',
#   'day',
#   'has',
#   'arrived',
#   "i've",
#   'opened',
#   'an',
#   'instagram',
#   'account',
#   'first',
#   'pic',
#   'last',
#   'night',
#   'jack',
#   'shots',
#   'and'],
#  ['dreams',
#   'come',
#   'true',
#   'gracias',
#   'por',
#   'todo',
#   'mcadepe',
#   'en',
#   'fòrum'],
#  ['all',
#   'about',
#   'the',
#   'gaudi',
#   'in',
#   'barcelona',
#   'sagradafamilia',
#   'gaudi',
#   'architecturephotography',
#   'bcn',
#   'barcelona'],
#  ['sunday',
#   'sightseeing',
#   'barcelona',
#   'spain',
#   'entrepreneurlife',
#   'teamevent',
#   'basílica',
#   'de',
#   'la',
#   'sagrada',
#   'família'],
#  ['hi',
#   'tonight',
#   'frightnight',
#   'opiumbarcelona',
#   'halloween',
#   'sunday',
#   'mambo',
#   'mambosession',
#   'terrific',
#   'dj'],
#  ['spanish',
#   'trails',
#   'photography',
#   'barcelona',
#   'nightvision',
#   'night',
#   'trails',
#   'street'],
#  ['if',
#   'you',
#   'kiss',
#   'her',
#   'mind',
#   'her',
#   'body',
#   'will',
#   'follow',
#   'barcelona'],
#  ["we've",
#   'seen',
#   'a',
#   'lot',
#   'of',
#   'churches',
#   'on',
#   'this',
#   'trip',
#   'but',
#   'this',
#   'gaudí',
#   'one',
#   'takes',
#   'the',
#   'cake',
#   'basílica',
#   'de',
#   'la'],
#  ['time',
#   'lapse',
#   'la',
#   'sagrada',
#   'familia',
#   'barcelona',
#   'posting',
#   'time',
#   'lapse',
#   'per',
#   'day',
#   'in',
#   'check'],
#  ["i've",
#   'never',
#   'been',
#   'a',
#   'passenger',
#   'though',
#   'i',
#   'never',
#   'knew',
#   'how',
#   'good',
#   'it',
#   'would'],
#  ['la',
#   'sagrada',
#   'family',
#   'sagrada',
#   'familia',
#   'metropolitana',
#   'di',
#   'barcellona'],
#  ['breathtaking',
#   'interiors',
#   'of',
#   'sagrada',
#   'familia',
#   'takes',
#   'breaths',
#   'away',
#   'asmr'],
#  ['breathtaking',
#   'interiors',
#   'of',
#   'sagrada',
#   'familia',
#   'takes',
#   'breaths',
#   'away',
#   'asmr'],
#  ['thirty',
#   'six',
#   'taps',
#   'and',
#   'nothing',
#   'wrong',
#   'abirradero',
#   'abirradero'],
#  ['alternative',
#   'barcelonathe',
#   'city',
#   'from',
#   'a',
#   'different',
#   'angle',
#   'sustainable',
#   'smart',
#   'cities'],
#  ['el',
#   'cigarrillo',
#   'de',
#   'la',
#   'tarde',
#   'fumar',
#   'es',
#   'malo',
#   'lo',
#   'sé',
#   'en',
#   'gothic',
#   'quarter',
#   'barcelona'],
#  ['in',
#   'remembrance',
#   'of',
#   'spain',
#   'in',
#   'barcelona',
#   'catalanidenpendence',
#   'gothic',
#   'quarter',
#   'barcelona'],
#  ['ready',
#   'to',
#   'move',
#   'pilatesandco',
#   'juaninguiso',
#   'laisabo',
#   'rianasara',
#   'laiavioleta',
#   'flowpilatesalella'],
#  ['filter', 'this', 'susan', 'cocovail', 'beer', 'hall'],
#  ['western',
#   'shirts',
#   'for',
#   'the',
#   'city',
#   'westershirts',
#   'shirtandroses',
#   'vintageshirts',
#   'zimmermanboots'],
#  ['gothicquarter',
#   'by',
#   'night',
#   'anecdotes',
#   'curiosities',
#   'explained',
#   'by',
#   'teguioenbarcelona',
#   'barcelona'],
#  ['learning',
#   'about',
#   'barrigotic',
#   'curiosities',
#   'anecdotes',
#   'with',
#   'teguioenbarcelona',
#   'barcelona'],
#  ['party',
#   'republic',
#   'catalonia',
#   'celebrating',
#   'newcountry',
#   'en',
#   'safari',
#   'disco',
#   'club'],
#  ['barcelona',
#   'wheelchairlife',
#   'wheelchairtravel',
#   'travelgeek',
#   'barcelona',
#   'sagradafamilia'],
#  ['the',
#   'sun',
#   'breaking',
#   'through',
#   'the',
#   'beautiful',
#   'vitrales',
#   'stained',
#   'glass',
#   'in',
#   'the',
#   'basílica',
#   'de',
#   'la',
#   'sagrada'],
#  ['oh',
#   'señor',
#   'gaudi',
#   'i',
#   'love',
#   'your',
#   'work',
#   'in',
#   'progress',
#   'travelgal',
#   'spain',
#   'barcelona',
#   'lasagradafamilia'],
#  ['wellcome',
#   'to',
#   'hell',
#   'saxattacking',
#   'opiumbarcelona',
#   'clubbing',
#   'altosax',
#   'housemusic',
#   'partytime'],
#  ['just',
#   'wanted',
#   'to',
#   'be',
#   'myself',
#   'for',
#   'halloween',
#   'snackszn',
#   'opium',
#   'barcelona'],
#  ['felicidades',
#   'mapartipi',
#   'special',
#   'comission',
#   'portrait',
#   'caricature',
#   'collage',
#   'illustration'],
#  ['a',
#   'summary',
#   'of',
#   "yesterday's",
#   'coverage',
#   'for',
#   'cnn',
#   'noticiascaracol',
#   'and',
#   'other',
#   'latin',
#   'american',
#   'tv',
#   'stations'],
#  ['aquarium',
#   'barcelona',
#   'taurons',
#   'sharks',
#   'nebots',
#   'marti',
#   'vado',
#   'tieta',
#   'annazuferri',
#   "l'aquàrium",
#   'de'],
#  ['the',
#   'best',
#   'club',
#   'ever',
#   'barcelona',
#   'party',
#   'españa',
#   'party',
#   'club',
#   'besttime',
#   'summer',
#   'family'],
#  ['the',
#   'best',
#   'club',
#   'ever',
#   'barcelona',
#   'party',
#   'españa',
#   'party',
#   'club',
#   'besttime',
#   'summer',
#   'family'],
#  ['the',
#   'best',
#   'club',
#   'ever',
#   'barcelona',
#   'party',
#   'españa',
#   'party',
#   'club',
#   'besttime',
#   'family',
#   'brotherstime'],
#  ['hypopressive',
#   'method',
#   'certification',
#   'w',
#   'nestorserra',
#   'and',
#   'raquel',
#   'in',
#   'barcelona',
#   'ludus',
#   'barcelona'],
#  ['first',
#   'sunset',
#   'in',
#   'the',
#   'independent',
#   'republic',
#   'of',
#   'catalonia',
#   'cat',
#   'catalunya',
#   'catalonha'],
#  ['sábados',
#   'de',
#   'socialmediaplanners',
#   'communitymanagement',
#   'consum',
#   'cocacolaesp'],
#  ['when',
#   'someone',
#   'calls',
#   'you',
#   'ugly',
#   'say',
#   'too',
#   'bad',
#   'you',
#   "can't",
#   'photoshop',
#   'your',
#   'ugly',
#   'personality',
#   'taray\x99',
#   'i'],
#  ['ñam', 'ñam', 'ñam', 'marranos', 'pulpo', 'en', 'porvenir'],
#  ['trickortreat', 'halloween', 'creepitreal'],
#  ['just', 'posted', 'a', 'photo', 'montjuïc', 'el', 'xalet'],
#  ['la',
#   'espera',
#   'desespera',
#   'sagradafamilia',
#   'cafe',
#   'history',
#   'en',
#   'basílica',
#   'de',
#   'la',
#   'sagrada',
#   'família'],
#  ['women',
#   'blond',
#   'hairdresser',
#   'hairstyle',
#   'hair',
#   'color',
#   'curly',
#   'salon',
#   'peluqueria',
#   'bcn',
#   'coolhair'],
#  ['tonight',
#   'bocacocktaillounge',
#   'from',
#   'till',
#   'late',
#   'en',
#   'boca',
#   'cocktail',
#   'lounge',
#   'restaurant'],
#  ['citas', 'disponibles', 'blackworknow', 'theartoftattoos'],
#  ['barcelona',
#   'catalan',
#   'supporters',
#   'shouting',
#   'to',
#   'the',
#   'spanish',
#   'press',
#   'reporter',
#   'accused',
#   'to',
#   'not',
#   'reporting'],
#  ['fail',
#   'learn',
#   'succeed',
#   'mermaid',
#   'en',
#   'gothic',
#   'quarter',
#   'barcelona'],
#  ['one',
#   'of',
#   'the',
#   'best',
#   'doom',
#   'shows',
#   'we',
#   'ever',
#   'seen',
#   'we',
#   'were',
#   'so',
#   'proud',
#   'of',
#   'have',
#   'booked',
#   'them',
#   'in',
#   'barcelona',
#   'and'],
#  ['ratasjuri',
#   'well',
#   'we',
#   'will',
#   'never',
#   'return',
#   'to',
#   'tallinn',
#   'on',
#   'holidays',
#   'anymore',
#   'thanks',
#   'ratas'],
#  ['muoy',
#   'bien',
#   'holachica',
#   'barcelona',
#   'weekender',
#   'night',
#   'bar',
#   'oviso'],
#  ['noche',
#   'de',
#   'cine',
#   'cine',
#   'terror',
#   'it',
#   'annabellecreation',
#   'cinelasarenas',
#   'bcn',
#   'españa',
#   'en',
#   'arenas',
#   'de'],
#  ['si',
#   'us',
#   'cau',
#   'una',
#   'llàgrima',
#   'veient',
#   'això',
#   'no',
#   'us',
#   'espanteu',
#   'és',
#   'normal',
#   'a',
#   'mi',
#   "m'ha",
#   'costat',
#   'parar',
#   'de',
#   'plorar'],
#  ['moment', 'històric', 'parliament', 'of', 'catalonia'],
#  ['europarlen', 'julianasange', 'this', 'is', 'the', 'spanish', 'style'],
#  ["i'm",
#   'told',
#   'that',
#   'manu',
#   'chau',
#   'will',
#   'be',
#   'performing',
#   'for',
#   'free',
#   'tonight',
#   'in',
#   'plaça',
#   'catalunya',
#   'visca',
#   'gothic'],
#  ['vegan', 'food', 'tour', 'gothic', 'quarter', 'barcelona'],
#  ['they',
#   'brought',
#   'me',
#   'a',
#   'protest',
#   'in',
#   'barcelona',
#   'streetgenius',
#   'gothic',
#   'quarter',
#   'barcelona'],
#  ['barcelona',
#   'independence',
#   'march',
#   'all',
#   'seems',
#   'good',
#   'natured',
#   'at',
#   'the',
#   'moment'],
#  ['drinking',
#   'a',
#   'blanca',
#   'de',
#   'trigo',
#   'by',
#   'cervezasagra',
#   'sant',
#   'jordi',
#   'hostel',
#   'sagrada',
#   'familia',
#   'photo'],
#  ['all',
#   'the',
#   'spiral',
#   'staircase',
#   'pics',
#   'when',
#   'traveling',
#   'with',
#   'dszeto'],
#  ['half',
#   'moon',
#   'over',
#   'the',
#   'sagrada',
#   'familia',
#   'basílica',
#   'de',
#   'la',
#   'sagrada',
#   'família'],
#  ['so',
#   'you',
#   'just',
#   'gon',
#   'bring',
#   'me',
#   'a',
#   'birthday',
#   'gift',
#   'on',
#   'my',
#   'birthday',
#   'to',
#   'my'],
#  ['i', 'enjoy', 'the'],
#  ['urbanphoto',
#   'ambarito',
#   'friends',
#   'celebration',
#   'viernes',
#   'friday',
#   'living',
#   'fantasia',
#   'en',
#   'ambarito'],
#  ['at', 'consum', 'basic', 'in', 'barcelona'],
#  ['barqin', 'ups', 'ok'],
#  ['barcelona', 'raval', 'twoschmucks', 'en', 'two', 'schmucks'],
#  ['so',
#   'cool',
#   'the',
#   'expo',
#   'by',
#   'socool',
#   'montana',
#   'gallery',
#   'barcelona'],
#  ['hitting',
#   'the',
#   'vibrant',
#   'streets',
#   'of',
#   'barcelona',
#   'spain',
#   'la',
#   'pedreracasa',
#   'milà'],
#  ['kipipphpycdi'],
#  ['barcelona',
#   'got',
#   'it',
#   'right',
#   'open',
#   'space',
#   'c',
#   'coffee',
#   'work',
#   'chill'],
#  ['get',
#   'lost',
#   'and',
#   'discover',
#   'the',
#   'tiny',
#   'little',
#   'streets',
#   'in',
#   "barcelona's",
#   'oldest',
#   'and',
#   'most',
#   'beautiful',
#   'gothic'],
#  ['vu', 'bicing', 'bikes', 'gothic', 'quarter', 'barcelona'],
#  ['la',
#   'declaració',
#   "m'ha",
#   'pillat',
#   'dinant',
#   'mongeta',
#   'tendra',
#   'que',
#   'trist'],
#  ['excellent', 'capture'],
#  ['the',
#   'sagrada',
#   'familia',
#   'is',
#   "gaudí's",
#   'most',
#   'wellknown',
#   'project',
#   'but',
#   'also',
#   'a',
#   'stunning',
#   'architectural'],
#  ['s',
#   'a',
#   'g',
#   'r',
#   'a',
#   'd',
#   'a',
#   'sagradafamilia',
#   'gaudi',
#   'throwbackthursday',
#   'tbt',
#   'vsco',
#   'vscocam',
#   'basílica'],
#  ['bcn', 'teatregoya', 'incendioscandelaserrat', 'formidableclapping'],
#  ["l'aquarium", 'was', 'amazing', "l'aquàrium", 'de', 'barcelona'],
#  ['collar',
#   'onecklace',
#   'blusa',
#   'uniqlo',
#   'tatuajes',
#   'elblogdelupi',
#   'ootd',
#   'look',
#   'uniqlo',
#   'tattoo',
#   'onecklace'],
#  ['ja',
#   'a',
#   'dins',
#   'del',
#   'parlament',
#   'en',
#   'parliament',
#   'of',
#   'catalonia'],
#  ['congratulations',
#   'to',
#   'the',
#   'independent',
#   'republic',
#   'of',
#   'catalonia',
#   'and',
#   'a',
#   'huge',
#   'thank',
#   'you',
#   'to',
#   'my'],
#  ['alley',
#   'oop',
#   'wall',
#   'ride',
#   'in',
#   'barcelona',
#   'with',
#   'the',
#   'rollerblade',
#   'metrobladehydrogenwheels'],
#  ['donuts', 'at', 'the', 'office', 'friday', 'en', 'platja', 'de', 'llevant'],
#  ['cliff', 'top', 'bar', 'with', 'the', 'most'],
#  ['highandfree', 'barcelona', 'gato'],
#  ['segunda',
#   'clase',
#   'de',
#   'babytennis',
#   'del',
#   'peque',
#   'tenis',
#   'meridiana',
#   'match',
#   'ball',
#   'in',
#   'barcelona'],
#  ['manifestación',
#   'en',
#   'barcelona',
#   'en',
#   'frente',
#   'del',
#   'parlament',
#   'no',
#   'a',
#   'la',
#   'independenciamore',
#   'news',
#   'on',
#   'our'],
#  ['los',
#   'mossos',
#   'blindan',
#   'el',
#   'parlamentbarcelona',
#   'catalan',
#   'parliament',
#   'blocked',
#   'off',
#   'by',
#   'policemore',
#   'news',
#   'on'],
#  ['fall',
#   'downmiranda',
#   'sensorex',
#   'kodak',
#   'color',
#   'isofilmisnotdead',
#   'filmphotography',
#   'filmcommunity'],
#  ['sailing', 'barcelona', 'en', 'barcelona', 'forum', 'district'],
#  ['he',
#   'got',
#   'a',
#   'lil',
#   'hat',
#   'pikachu',
#   'blessed',
#   'lifegoals',
#   'pokemon',
#   'pokemongo',
#   'gothic',
#   'quarter',
#   'barcelona'],
#  ['força',
#   'workout',
#   'training',
#   'fit',
#   'neversettle',
#   'spoonie',
#   'lifestyle',
#   'sport',
#   'women',
#   'breathe'],
#  ['diputaciodebarcelona',
#   'bcn',
#   'urbansketchersbcn',
#   'draft',
#   'drawing',
#   'art',
#   'illustration',
#   'artist'],
#  ['antoni',
#   'look',
#   'what',
#   "you've",
#   'done',
#   'barcelona',
#   'sagradafamilia',
#   'bucketlist',
#   'tbtgaudi'],
#  ['incredible',
#   'experience',
#   'last',
#   'night',
#   'thank',
#   'you',
#   'for',
#   'the',
#   'culinary',
#   'journey',
#   'and',
#   'genuine',
#   'hospitality'],
#  ['final',
#   'day',
#   'in',
#   'the',
#   'academy',
#   'cheers',
#   'to',
#   'everyone',
#   'involved',
#   'último',
#   'día',
#   'en',
#   'la',
#   'academia',
#   'salud',
#   'a'],
#  ['when',
#   'you',
#   'want',
#   'to',
#   'take',
#   'in',
#   'every',
#   'moment',
#   'it',
#   'is',
#   'a',
#   'black',
#   'label',
#   'kind',
#   'of',
#   'day',
#   'thrivingandfeelgreat'],
#  ['aixíno'],
#  ['the', 'shopaholic', 'is', 'in', 'the', 'city', 'fashionista'],
#  ['prepping',
#   'for',
#   "tomorrow's",
#   'seminar',
#   'on',
#   'changes',
#   'to',
#   'the',
#   'younglearners',
#   'tests',
#   'for',
#   'see',
#   'you'],
#  ['operacion',
#   'realizada',
#   'contando',
#   'los',
#   'dias',
#   'para',
#   'vakencia',
#   'surgery',
#   'done',
#   'counting',
#   'the',
#   'days',
#   'for'],
#  ['e', 'e', 'p', 'd'],
#  ['manifestación',
#   'en',
#   'barcelona',
#   'en',
#   'frente',
#   'del',
#   'parlament',
#   'no',
#   'a',
#   'la',
#   'independenciamore',
#   'news',
#   'on',
#   'our'],
#  ['legalize',
#   'it',
#   'i',
#   'will',
#   'advertise',
#   'it',
#   '',
#   'barcelona',
#   'association',
#   'weed',
#   'cannabis',
#   'marihuana'],
#  ...]

# %%
# build a word2vec model
w2v_model = gensim.models.Word2Vec(tokenized_documents_no_pooling, min_count=2, size=500)

# %%
# define function to calculate coherence
def calculate_coherence(w2v_model, term_rankings):
    overall_coherence = 0.0
    for topic_index in range(len(term_rankings)):
        # check each pair of terms
        pair_scores = []
        for pair in combinations(term_rankings[topic_index], 2):
            pair_scores.append(w2v_model.similarity(pair[0], pair[1]) )
        # get the mean for all pairs in this topic
        topic_score = sum(pair_scores) / len(pair_scores)
        overall_coherence += topic_score
    # get the mean score across all topics
    return overall_coherence / len(term_rankings)

# %%
# define function to get top terms
def get_descriptor(all_terms, H, topic_index, top):
    # reverse sort the values to sort the indices
    top_indices = np.argsort(H[topic_index,:] )[::-1]
    # now get the terms corresponding to the top-ranked indices
    top_terms = []
    for term_index in top_indices[0:top]:
        top_terms.append(all_terms[term_index])
    return top_terms

# %%
# run functions
k_values = []
coherences = []
for (k,W,H) in topic_models:
    # Get all of the topic descriptors - the term_rankings, based on top 10 terms
    term_rankings = []
    for topic_index in range(k):
        term_rankings.append(get_descriptor(tfidf_feature_names_no_pooling, H, topic_index, 10))
    # Now calculate the coherence based on our Word2vec model
    k_values.append( k )
    coherences.append(calculate_coherence(w2v_model,term_rankings))
    print("K=%02d: Coherence=%.4f" % ( k, coherences[-1] ) )
# Out:
# K=04: Coherence=0.9698
# K=05: Coherence=0.9621
# K=06: Coherence=0.9693
# K=07: Coherence=0.9735
# K=08: Coherence=0.9747
# C:\Users\Sebastian Birk\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).

# %%
# graph settings
plt.style.use("ggplot")
matplotlib.rcParams.update({"font.size": 14})

# %%
# create graph
fig = plt.figure(figsize=(13,7))
# create the line plot
ax = plt.plot( k_values, coherences )
plt.xticks(k_values)
plt.xlabel("Number of Topics")
plt.ylabel("Mean Coherence")
# add the points
plt.scatter( k_values, coherences, s=120)
# find and annotate the maximum point on the plot
ymax = max(coherences)
xpos = coherences.index(ymax)
best_k = k_values[xpos]
plt.annotate( "k=%d" % best_k, xy=(best_k, ymax), xytext=(best_k, ymax), textcoords="offset points", fontsize=16)
plt.savefig("coherence_scores_nmf")
# show the plot
plt.show()

# %%
# select the best number of topics according to tc-w2v coherence measure
k = best_k
# get the model that we generated earlier.
W = topic_models[k-kmin][1]
H = topic_models[k-kmin][2]

# %%
# print the top words for each topic
for topic_index in range(k):
    descriptor = get_descriptor(tfidf_feature_names_no_pooling, H, topic_index, 20)
    str_descriptor = ", ".join( descriptor )
    print("Topic %02d: %s" % ( topic_index+1, str_descriptor ) )
# Out:
# Topic 01: familia, sagrada, la, basilica, inside, ll, construction, beautiful, dance, view, beauty, time, good, antoni, video, incredible, capture, night, familía, years
# Topic 02: gothic, quarter, gothicquarter, art, streets, barcelona, graffiti, street, streetart, lost, travel, night, strolling, today, beautiful, love, life, bcn, favorite, time
# Topic 03: just, ramblas, parc, laberint, video, arenas, aquàrium, platja, avinguda, diagonal, plaza, barceloneta, joan, guell, fundació, miró, llevant, zoo, serras, princess
# Topic 04: basílica, família, sagrada, beautiful, lasagradafamilia, barcelona, la, time, inside, expiatori, place, beauty, temple, church, finished, light, gaudí, looking, look, dream
# Topic 05: sagradafamilia, gaudi, architecture, travel, church, amazing, beautiful, basilica, barcelona, gaudí, catalonia, love, expiatorio, templo, building, holiday, masterpiece, inside, tourist, art
# Topic 06: milà, pedreracasa, casa, pedrera, gaudi, gaudí, lapedrera, history, barcelona, beautiful, casamila, art, photography, weekend, architecture, great, roof, real, rooftop, nature
# Topic 07: beach, city, marbella, barceloneta, love, playa, festival, barcelona, summer, time, beautiful, platja, sun, travel, night, friends, bbf, happy, cruïlla, best
# Topic 08: drinking, photo, cervecita, olgodbeer, rosses, torrades, ipa, rovira, cocovailbh, edgebrewing, craft, cuc, cal, omnipollo, garagebeerco, birrificio, vibrantforest, ale, lambrate, foundersbrewing

# %% [markdown]
# #### Upon inspection, NMF works very well (seems to be more interpretable than the LDA no pooling model). However, the topics are very repetitive and not as clearly interpretable and differentiatable as the topcis detected by the LDA model with hashtag pooling. The problem of repetitions of keywords among different topics complicates the matter.
