# %% [markdown]
# ## References

# %%
# https://markroxor.github.io/gensim/static/notebooks/gensim_news_classification.html
# https://medium.com/square-corner-blog/topic-modeling-optimizing-for-human-interpretability-48a81f6ce0ed

# %% [markdown]
# ## Prepare Notebook

# %%
# import packages
import logging
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt
from gensim import corpora, models
from gensim.models import HdpModel, LsiModel, CoherenceModel

# %%
# log events
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# ## Load Training Corpora and Dictionaries

# %%
# load no pooling corpus
if (os.path.exists("tourism_no_pooling.dict")):
   dictionary_no_pooling = corpora.Dictionary.load('tourism_no_pooling.dict')
   corpus_no_pooling = corpora.MmCorpus('tourism_no_pooling.mm')
   print("Vectorized no pooling corpus loaded!")
else:
   print("Please run preprocessing script first!")

# load user pooling corpus
if (os.path.exists("tourism_user_pooling.dict")):
   dictionary_user_pooling = corpora.Dictionary.load('tourism_user_pooling.dict')
   corpus_user_pooling = corpora.MmCorpus('tourism_user_pooling.mm')
   print("Vectorized user pooling corpus loaded!")
else:
   print("Please run preprocessing script first!")

# load hashtag pooling corpus
if (os.path.exists("tourism_hashtag_pooling.dict")):
   dictionary_hashtag_pooling = corpora.Dictionary.load('tourism_hashtag_pooling.dict')
   corpus_hashtag_pooling = corpora.MmCorpus('tourism_hashtag_pooling.mm')
   print("Vectorized hashtag pooling corpus loaded!")
else:
   print("Please run preprocessing script first!")
# Out:
# 2018-10-02 23:01:11,406 : INFO : loading Dictionary object from tourism_no_pooling.dict
# 2018-10-02 23:01:11,429 : INFO : loaded tourism_no_pooling.dict
# 2018-10-02 23:01:11,438 : INFO : loaded corpus index from tourism_no_pooling.mm.index
# 2018-10-02 23:01:11,442 : INFO : initializing cython corpus reader from tourism_no_pooling.mm
# 2018-10-02 23:01:11,450 : INFO : accepted corpus with 7633 documents, 4790 features, 37016 non-zero entries
# 2018-10-02 23:01:11,456 : INFO : loading Dictionary object from tourism_user_pooling.dict
# 2018-10-02 23:01:11,466 : INFO : loaded tourism_user_pooling.dict
# 2018-10-02 23:01:11,472 : INFO : loaded corpus index from tourism_user_pooling.mm.index
# 2018-10-02 23:01:11,474 : INFO : initializing cython corpus reader from tourism_user_pooling.mm
# 2018-10-02 23:01:11,477 : INFO : accepted corpus with 4424 documents, 3990 features, 30119 non-zero entries
# 2018-10-02 23:01:11,480 : INFO : loading Dictionary object from tourism_hashtag_pooling.dict
# 2018-10-02 23:01:11,490 : INFO : loaded tourism_hashtag_pooling.dict
# 2018-10-02 23:01:11,494 : INFO : loaded corpus index from tourism_hashtag_pooling.mm.index
# 2018-10-02 23:01:11,496 : INFO : initializing cython corpus reader from tourism_hashtag_pooling.mm
# 2018-10-02 23:01:11,500 : INFO : accepted corpus with 6040 documents, 9330 features, 78970 non-zero entries
# Vectorized no pooling corpus loaded!
# Vectorized user pooling corpus loaded!
# Vectorized hashtag pooling corpus loaded!

# %% [markdown]
# ## Load Documents

# %%
# load no pooling documents
with open ('tokenized_documents_no_pooling.p', 'rb') as fp:
    tokenized_documents_no_pooling = pickle.load(fp)

# load user pooling documents
with open('tokenized_documents_user_pooling.p', 'rb') as fp:
    tokenized_documents_user_pooling = pickle.load(fp)

# load hashtag pooling documents
with open('tokenized_documents_hashtag_pooling.p', 'rb') as fp:
    tokenized_documents_hashtag_pooling = pickle.load(fp)

# %% [markdown]
# ## Load LDA Models (Trained in TopicModeling#2 Script)

# %%
# load models
lda_model_no_pooling = models.LdaModel.load('lda_model_no_pooling.model') # 6 topics
lda_model_user_pooling = models.LdaModel.load('lda_model_user_pooling.model') # 7 topics
lda_model_hashtag_pooling = models.LdaModel.load('lda_model_hashtag_pooling.model') # 7 topics
# Out:
# 2018-10-02 23:01:14,748 : INFO : loading LdaModel object from lda_model_no_pooling.model
# 2018-10-02 23:01:14,753 : INFO : loading expElogbeta from lda_model_no_pooling.model.expElogbeta.npy with mmap=None
# 2018-10-02 23:01:14,757 : INFO : setting ignored attribute state to None
# 2018-10-02 23:01:14,759 : INFO : setting ignored attribute dispatcher to None
# 2018-10-02 23:01:14,761 : INFO : setting ignored attribute id2word to None
# 2018-10-02 23:01:14,763 : INFO : loaded lda_model_no_pooling.model
# 2018-10-02 23:01:14,765 : INFO : loading LdaState object from lda_model_no_pooling.model.state
# 2018-10-02 23:01:14,769 : INFO : loaded lda_model_no_pooling.model.state
# 2018-10-02 23:01:14,778 : INFO : loading LdaModel object from lda_model_user_pooling.model
# 2018-10-02 23:01:14,781 : INFO : loading expElogbeta from lda_model_user_pooling.model.expElogbeta.npy with mmap=None
# 2018-10-02 23:01:14,784 : INFO : setting ignored attribute state to None
# 2018-10-02 23:01:14,786 : INFO : setting ignored attribute dispatcher to None
# 2018-10-02 23:01:14,788 : INFO : setting ignored attribute id2word to None
# 2018-10-02 23:01:14,790 : INFO : loaded lda_model_user_pooling.model
# 2018-10-02 23:01:14,792 : INFO : loading LdaState object from lda_model_user_pooling.model.state
# 2018-10-02 23:01:14,796 : INFO : loaded lda_model_user_pooling.model.state
# 2018-10-02 23:01:14,806 : INFO : loading LdaModel object from lda_model_hashtag_pooling.model
# 2018-10-02 23:01:14,809 : INFO : loading expElogbeta from lda_model_hashtag_pooling.model.expElogbeta.npy with mmap=None
# 2018-10-02 23:01:14,813 : INFO : setting ignored attribute state to None
# 2018-10-02 23:01:14,814 : INFO : setting ignored attribute dispatcher to None
# 2018-10-02 23:01:14,817 : INFO : setting ignored attribute id2word to None
# 2018-10-02 23:01:14,819 : INFO : loaded lda_model_hashtag_pooling.model
# 2018-10-02 23:01:14,822 : INFO : loading LdaState object from lda_model_hashtag_pooling.model.state
# 2018-10-02 23:01:14,829 : INFO : loaded lda_model_hashtag_pooling.model.state

# %%
# extract topics with word probabilities
lda_topics_no_pooling = lda_model_no_pooling.show_topics(formatted=False)
lda_topics_user_pooling = lda_model_user_pooling.show_topics(formatted=False)
lda_topics_hashtag_pooling = lda_model_hashtag_pooling.show_topics(formatted=False)

# %% [markdown]
# ## Train HDP Models

# %%
# train HDP models with different pooling methods (similar to LDA in TopicModeling#2 Script)
hdp_model_no_pooling = HdpModel(corpus_no_pooling, dictionary_no_pooling)
hdp_model_user_pooling = HdpModel(corpus_user_pooling, dictionary_user_pooling)
hdp_model_hashtag_pooling = HdpModel(corpus_hashtag_pooling, dictionary_hashtag_pooling)
# Out:
# 2018-10-02 23:01:42,709 : INFO : (0, '0.002*#mar + 0.002*nyc + 0.001*hottie + 0.001*#arquitecturephotography + 0.001*#garycheokinbarcelona + 0.001*avenue + 0.001*#alley + 0.001*passion + 0.001*fabricatele + 0.001*#texture')
# 2018-10-02 23:01:42,715 : INFO : (1, '0.002*hipster + 0.002*said + 0.002*streaming + 0.001*dance + 0.001*#sundayvibes + 0.001*aile + 0.001*watching + 0.001*susan + 0.001*#jlunaphoto + 0.001*benjamin')
# 2018-10-02 23:01:42,725 : INFO : (2, '0.002*fine + 0.002*sagrada + 0.002*#photos + 0.001*#umbrella + 0.001*asian + 0.001*glòries + 0.001*need + 0.001*después + 0.001*mossèn + 0.001*beloved')
# 2018-10-02 23:01:42,733 : INFO : (3, '0.002*#sketching + 0.002*driving + 0.001*vision + 0.001*agbar + 0.001*#basilica + 0.001*#parkguell + 0.001*#god + 0.001*welcome + 0.001*steipete + 0.001*#terrace')
# 2018-10-02 23:01:42,741 : INFO : (4, '0.002*dans + 0.002*di + 0.001*skinny + 0.001*favourite + 0.001*#meeting + 0.001*far + 0.001*sailing + 0.001*lift + 0.001*#ticketsbar + 0.001*#livingbcn')
# 2018-10-02 23:01:42,749 : INFO : (5, '0.002*barceloneta + 0.002*lightforms + 0.002*class + 0.002*laberint + 0.002*update + 0.001*gray + 0.001*#amor + 0.001*pretend + 0.001*appreciation + 0.001*#afterwork')
# 2018-10-02 23:01:42,767 : INFO : (6, '0.002*#architecture + 0.002*member + 0.002*#norwichphotographer + 0.002*#memories + 0.002*cruïlla + 0.001*dont + 0.001*cervecita + 0.001*#curiosities + 0.001*training + 0.001*#clarins')
# 2018-10-02 23:01:42,778 : INFO : (7, '0.002*#lost + 0.002*#escenapoblenou + 0.002*malt + 0.002*humanity + 0.002*petit + 0.002*#dance + 0.002*oficial + 0.001*carlsbergukcorp + 0.001*més + 0.001*motion')
# 2018-10-02 23:01:42,789 : INFO : (8, '0.002*usual + 0.002*#halloweenmakeup + 0.002*#up + 0.001*cabalera + 0.001*bonito + 0.001*center + 0.001*#draft + 0.001*came + 0.001*#gaudissegradafamilia + 0.001*match')
# 2018-10-02 23:01:42,800 : INFO : (9, '0.002*drinking + 0.002*brown + 0.002*cocovailbh + 0.002*monday + 0.001*nd + 0.001*silken + 0.001*jesusisnard + 0.001*posting + 0.001*#morning + 0.001*coming')
# 2018-10-02 23:01:42,816 : INFO : (10, '0.002*#timetosaygoodbye + 0.002*rtebonanova + 0.002*say + 0.002*#lifeisgood + 0.002*tiene + 0.001*handcrafted + 0.001*lunch + 0.001*#photooftheday + 0.001*#rooftopbar + 0.001*tele')
# 2018-10-02 23:01:42,827 : INFO : (11, '0.002*vila + 0.002*duquesa + 0.002*#tacos + 0.002*missed + 0.002*familia + 0.001*#dining + 0.001*listening + 0.001*gallery + 0.001*bona + 0.001*sagrada')
# 2018-10-02 23:01:42,847 : INFO : (12, '0.002*família + 0.002*hat + 0.002*#igersspain + 0.002*entre + 0.001*scandal + 0.001*sagrada + 0.001*quite + 0.001*paddle + 0.001*fail + 0.001*labyrinth')
# 2018-10-02 23:01:42,858 : INFO : (13, '0.002*#illustrator + 0.002*chaos + 0.002*shizzle + 0.002*vulture + 0.002*absolutely + 0.002*aile + 0.001*tv + 0.001*tasting + 0.001*expected + 0.001*#sunrise')
# 2018-10-02 23:01:42,866 : INFO : (14, '0.002*sagrada + 0.002*wild + 0.002*#director + 0.002*intentando + 0.001*tradition + 0.001*afu + 0.001*#popcorn + 0.001*alongside + 0.001*blanco + 0.001*cut')
# 2018-10-02 23:01:42,879 : INFO : (15, '0.002*anyone + 0.002*instalación + 0.002*#referendum + 0.002*#backpack + 0.002*#lapedrera + 0.001*seen + 0.001*#vacation + 0.001*model + 0.001*#concert + 0.001*#bmx')
# 2018-10-02 23:01:42,893 : INFO : (16, '0.002*play + 0.002*sagrada + 0.002*baby + 0.002*familia + 0.002*extraño + 0.001*#vodka + 0.001*remembered + 0.001*dondiablo + 0.001*entrance + 0.001*spotting')
# 2018-10-02 23:01:42,903 : INFO : (17, '0.002*flavor + 0.002*veggie + 0.002*#sea + 0.002*heavy + 0.001*column + 0.001*estadi + 0.001*magic + 0.001*#sundayfunday + 0.001*#endofsummer + 0.001*#slovakboy')
# 2018-10-02 23:01:42,919 : INFO : (18, '0.002*#runner + 0.002*trust + 0.002*nicely + 0.002*#beachlife + 0.002*anyone + 0.002*p + 0.001*mediatic + 0.001*déu + 0.001*#artdirector + 0.001*#cuba')
# 2018-10-02 23:01:42,927 : INFO : (19, '0.001*sagrada + 0.001*lambrate + 0.001*cake + 0.001*bw + 0.001*#partynight + 0.001*#girl + 0.001*news + 0.001*realized + 0.001*excellent + 0.001*høppy')
# 2018-10-02 23:01:43,744 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:43,747 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:43,751 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:43,755 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:43,759 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:43,763 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:43,767 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:43,771 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:43,851 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:43,854 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:43,858 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:43,862 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:43,867 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:43,871 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:43,875 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:43,879 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:43,883 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:44,415 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:44,418 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:44,422 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:44,426 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:45,541 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:46,843 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:48,617 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:48,621 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:48,625 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:48,628 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:48,632 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:48,636 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:48,640 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:48,644 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:48,647 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:48,651 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:48,655 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:48,658 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:48,662 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:48,666 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:48,673 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:48,679 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:49,093 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:51,433 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:51,435 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:51,439 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:51,443 : WARNING : likelihood is decreasing!
# 2018-10-02 23:01:59,128 : INFO : (0, '0.003*recommended + 0.002*#pride + 0.002*#nervo + 0.002*milà + 0.002*insane + 0.002*#basílica + 0.002*time + 0.002*shôko + 0.002*#travellife + 0.002*#goodtimes')
# 2018-10-02 23:01:59,133 : INFO : (1, '0.003*gothic + 0.003*quarter + 0.002*reflection + 0.002*ago + 0.002*quieres + 0.002*#primavera + 0.002*más + 0.002*vall + 0.002*running + 0.001*#tn')
# 2018-10-02 23:01:59,142 : INFO : (2, '0.005*#photodrinking + 0.003*sagrada + 0.003*cervecita + 0.002*#igspain + 0.002*bien + 0.002*aquàrium + 0.002*#exposition + 0.002*understatement + 0.002*#interior + 0.002*#cinema')
# 2018-10-02 23:01:59,151 : INFO : (3, '0.002*restaurante + 0.002*#president + 0.002*wind + 0.002*visitbarcelona + 0.002*reunited + 0.002*bellcaire + 0.002*hundred + 0.001*tried + 0.001*got + 0.001*#amigas')
# 2018-10-02 23:01:59,156 : INFO : (4, '0.007*sagrada + 0.004*familia + 0.003*basílica + 0.003*#sagradafamilia + 0.003*família + 0.002*image + 0.002*foam + 0.002*gaudi + 0.002*positive + 0.002*offer')
# 2018-10-02 23:01:59,163 : INFO : (5, '0.002*estadi + 0.002*#sculpture + 0.002*alcohol + 0.002*independent + 0.002*bcnfashion + 0.002*party + 0.002*#yogi + 0.002*load + 0.002*wing + 0.002*course')
# 2018-10-02 23:01:59,171 : INFO : (6, '0.002*drinking + 0.002*carla + 0.002*familia + 0.002*jt + 0.002*heart + 0.002*walking + 0.002*kicking + 0.001*seat + 0.001*student + 0.001*barcelonacityfm')
# 2018-10-02 23:01:59,184 : INFO : (7, '0.002*bonanova + 0.002*however + 0.002*reunited + 0.002*#ilovebarcelona + 0.002*#tan + 0.002*crime + 0.002*page + 0.002*haraamoros + 0.001*fam + 0.001*rockstar')
# 2018-10-02 23:01:59,196 : INFO : (8, '0.002*#streetphotography + 0.002*#work + 0.002*sagrada + 0.002*#bucketlist + 0.002*happens + 0.002*extend + 0.002*#lit + 0.002*#interior + 0.001*#sketch + 0.001*#thankful')
# 2018-10-02 23:01:59,207 : INFO : (9, '0.002*toca + 0.002*lambratecervesaguineu + 0.002*sacred + 0.002*forward + 0.002*#lovers + 0.002*queen + 0.002*#signs + 0.002*parc + 0.001*complex + 0.001*drinking')
# 2018-10-02 23:01:59,214 : INFO : (10, '0.003*sagrada + 0.002*sake + 0.002*ultimate + 0.002*photographer + 0.002*#great + 0.002*modernist + 0.002*#bcncity + 0.002*sense + 0.002*guillerminabaezabcn + 0.002*fairy')
# 2018-10-02 23:01:59,225 : INFO : (11, '0.002*shop + 0.002*thursday + 0.002*#thursday + 0.002*along + 0.002*#teatregrec + 0.002*cdlcbarcelona + 0.002*palm + 0.002*pure + 0.002*soy + 0.001*velvet')
# 2018-10-02 23:01:59,231 : INFO : (12, '0.003*#tiling + 0.002*chart + 0.002*light + 0.002*olympiquo + 0.002*cheeky + 0.002*paper + 0.002*nicer + 0.001*info + 0.001*party + 0.001*#bondia')
# 2018-10-02 23:01:59,248 : INFO : (13, '0.002*sagrada + 0.002*skinny + 0.001*#mimosa + 0.001*technique + 0.001*selfies + 0.001*chicken + 0.001*laietana + 0.001*sneaker + 0.001*brooklyn + 0.001*#bucketlist')
# 2018-10-02 23:01:59,257 : INFO : (14, '0.002*traín + 0.002*cabaret + 0.002*torre + 0.002*strolling + 0.002*across + 0.002*#lunch + 0.002*#gato + 0.002*calella + 0.002*magazine + 0.002*home')
# 2018-10-02 23:01:59,264 : INFO : (15, '0.002*sagrada + 0.002*coming + 0.002*everywhere + 0.002*price + 0.002*untold + 0.002*#fotos + 0.002*fish + 0.002*block + 0.001*#barceloneta + 0.001*primaverapro')
# 2018-10-02 23:01:59,273 : INFO : (16, '0.003*monkey + 0.002*foto + 0.002*forest + 0.002*llevant + 0.002*resist + 0.002*laietana + 0.002*güell + 0.002*arch + 0.002*#visiting + 0.002*brunch')
# 2018-10-02 23:01:59,282 : INFO : (17, '0.002*#tflers + 0.002*mojitos + 0.002*así + 0.002*personal + 0.002*#sunny + 0.002*ikea + 0.002*#kids + 0.001*dancing + 0.001*roll + 0.001*gym')
# 2018-10-02 23:01:59,290 : INFO : (18, '0.002*hoy + 0.002*reminiscing + 0.002*let + 0.002*#travel + 0.002*european + 0.002*#winelover + 0.002*hotelbarcelona + 0.002*#health + 0.002*#arenas + 0.002*#meeting')
# 2018-10-02 23:01:59,297 : INFO : (19, '0.002*hyde + 0.002*amount + 0.002*sagrada + 0.002*#travel + 0.002*música + 0.002*city + 0.002*wild + 0.002*pro + 0.002*#barcelonaambtu + 0.002*complex')
# 2018-10-02 23:02:03,947 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:03,950 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:03,955 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:04,739 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:04,742 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:06,094 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:06,098 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:06,101 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:06,105 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:06,108 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,273 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,277 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,281 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,285 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,289 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,293 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,297 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,300 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,305 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,310 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,316 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,322 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,325 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,329 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,332 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,337 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,340 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,344 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,348 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,353 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,359 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,362 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,366 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,370 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,373 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,377 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,380 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,384 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,389 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,395 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,398 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,401 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,406 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,409 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,412 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,416 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,420 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,427 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,431 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,434 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,439 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,442 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,445 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,449 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,452 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,455 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,459 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,462 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,465 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,468 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,472 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,475 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,478 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,482 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,488 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,494 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,499 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,504 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,509 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,512 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,515 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,518 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,523 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,527 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,530 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,534 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,539 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,543 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,550 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,555 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,558 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:09,562 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:11,019 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:11,021 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:11,245 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:11,740 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:16,076 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:16,079 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:23,268 : WARNING : likelihood is decreasing!
# 2018-10-02 23:02:26,060 : INFO : (0, '0.020*#sagradafamilia + 0.014*sagrada + 0.011*#travel + 0.010*#gaudi + 0.008*#summer + 0.008*familia + 0.007*#love + 0.006*basílica + 0.006*#photography + 0.005*#friends')
# 2018-10-02 23:02:26,070 : INFO : (1, '0.019*#streetart + 0.014*#graffiti + 0.013*#arteurbano + 0.011*#digerible + 0.008*urbano + 0.008*arte + 0.006*#arteenlacalle + 0.005*tres + 0.005*xemeneies + 0.004*#mural')
# 2018-10-02 23:02:26,086 : INFO : (2, '0.010*#sagradafamilia + 0.009*#architecture + 0.006*sagrada + 0.006*#gaudi + 0.004*#beautiful + 0.004*familia + 0.003*#basilica + 0.003*#travel + 0.002*basílica + 0.002*#antonigaudi')
# 2018-10-02 23:02:26,103 : INFO : (3, '0.012*#art + 0.005*#drawing + 0.003*#illustration + 0.002*gothic + 0.002*#artist + 0.002*quarter + 0.002*#arte + 0.002*#sketch + 0.002*#love + 0.002*#graffiti')
# 2018-10-02 23:02:26,119 : INFO : (4, '0.006*#beach + 0.003*#instagood + 0.002*#summer + 0.002*beach + 0.002*#love + 0.002*#sun + 0.001*oh + 0.001*marbella + 0.001*#aroundtheworld + 0.001*#sea')
# 2018-10-02 23:02:26,140 : INFO : (5, '0.003*#gaudi + 0.001*sagrada + 0.001*#lasagradafamilia + 0.001*#sagradafamilia + 0.001*#tequila + 0.001*#obeyyourbody + 0.001*official + 0.001*#travel + 0.001*basílica + 0.001*#architecture')
# 2018-10-02 23:02:26,157 : INFO : (6, '0.003*#illustration + 0.003*#art + 0.003*#artist + 0.002*#drawing + 0.002*#pencil + 0.002*#artwork + 0.001*#artoftheday + 0.001*#draft + 0.001*#creative + 0.001*#artsy')
# 2018-10-02 23:02:26,176 : INFO : (7, '0.002*#life + 0.001*#music + 0.001*#sol + 0.001*por + 0.001*#europe + 0.001*ramblas + 0.001*#recycleordie + 0.001*#friends + 0.001*#mar + 0.001*#recycleyourself')
# 2018-10-02 23:02:26,191 : INFO : (8, '0.001*#barca + 0.001*viva + 0.001*gargoyle + 0.001*#birhtday + 0.001*#psvitagames + 0.001*#socialmediaplanners + 0.001*#aguarestaurant + 0.001*#laverneda + 0.001*#iulian + 0.001*injection')
# 2018-10-02 23:02:26,204 : INFO : (9, '0.005*#vegan + 0.005*#minimalism + 0.005*#planner + 0.004*#photooftheday + 0.004*#elhartazgodeunpaís + 0.004*#amazing + 0.004*#smile + 0.002*follow + 0.002*#follow + 0.001*#clarins')
# 2018-10-02 23:02:26,224 : INFO : (10, '0.003*#run + 0.002*#amor + 0.002*#amoviajar + 0.002*#love + 0.002*#viajar + 0.002*#sol + 0.002*#feliz + 0.002*#travel + 0.002*#arte + 0.002*#sun')
# 2018-10-02 23:02:26,242 : INFO : (11, '0.004*#sport + 0.004*#women + 0.004*#spoonie + 0.004*#neversettle + 0.004*#lifestyle + 0.004*#training + 0.003*#fit + 0.003*#workout + 0.001*#breathe + 0.001*#colorventures')
# 2018-10-02 23:02:26,259 : INFO : (12, '0.005*#catalonia + 0.003*#repression + 0.003*#escolaramonllull + 0.003*#catalunya + 0.003*#referendum + 0.003*#independencia + 0.002*#travel + 0.001*#vagageneral + 0.001*#generalstrike + 0.001*company')
# 2018-10-02 23:02:26,271 : INFO : (13, '0.002*#streetart + 0.001*#arteurbano + 0.001*#graffiti + 0.001*#digerible + 0.001*#mylifearoundtheworld + 0.001*qué + 0.001*arte + 0.001*#stuntstepshop + 0.001*xemeneies + 0.001*#sprinttothebar')
# 2018-10-02 23:02:26,291 : INFO : (14, '0.008*#endomondo + 0.008*km + 0.007*#endorphins + 0.005*finished + 0.005*running + 0.002*walking + 0.001*cycling + 0.001*recommendation + 0.001*racer + 0.001*exitosurbanos')
# 2018-10-02 23:02:26,312 : INFO : (15, '0.001*#basilicadelasagradafamilia + 0.001*#businessportrait + 0.001*monitoring + 0.001*ecuador + 0.001*#upc + 0.001*listenning + 0.001*cactus + 0.001*poblenou + 0.001*espia + 0.001*#tanqueray')
# 2018-10-02 23:02:26,329 : INFO : (16, '0.001*#vegan + 0.001*#elhartazgodeunpaís + 0.001*#artmontfalcon + 0.001*#urbanphoto + 0.001*#siamensiscrocodile + 0.001*#relio + 0.001*#menlife + 0.001*#trowback + 0.001*#expatlife + 0.001*#untilsunset')
# 2018-10-02 23:02:26,346 : INFO : (17, '0.003*#amazing + 0.002*#sagradafamilia + 0.002*sagrada + 0.001*familia + 0.001*#photooftheday + 0.001*#teampoor + 0.001*#barcelonainspira + 0.001*#climbingup + 0.001*kaleidoscope + 0.001*#beautyrussian')
# 2018-10-02 23:02:26,360 : INFO : (18, '0.001*#powerstation + 0.001*streetart + 0.001*da + 0.001*#shotoniphone + 0.001*#drums + 0.001*paddle + 0.001*#momselfie + 0.001*x#key + 0.001*chip + 0.001*#miami')
# 2018-10-02 23:02:26,376 : INFO : (19, '0.005*#graffiti + 0.004*#artecallejero + 0.004*#artederua + 0.003*#streetart + 0.003*#streetphotography + 0.003*#graffitiart + 0.002*#tweegram + 0.002*#igeurope + 0.001*#barriodegracia + 0.001*#igespana')

# %%
# exctract topics with word probabilities
hdp_topics_no_pooling = hdp_model_no_pooling.show_topics(formatted=False)
hdp_topics_user_pooling = hdp_model_user_pooling.show_topics(formatted=False)
hdp_topics_hashtag_pooling = hdp_model_hashtag_pooling.show_topics(formatted=False)

# %% [markdown]
# ## Train LSI Models

# %%
# train LSI models with similar configurations as LDA models
lsi_model_no_pooling = LsiModel(corpus=corpus_no_pooling, num_topics=6, id2word=dictionary_no_pooling)
lsi_model_user_pooling = LsiModel(corpus=corpus_user_pooling, num_topics=7, id2word=dictionary_user_pooling)
lsi_model_hashtag_pooling = LsiModel(corpus=corpus_hashtag_pooling, num_topics=7, id2word=dictionary_hashtag_pooling)
# Out:
# 2018-10-02 23:02:26,823 : INFO : using serial LSI version on this node
# 2018-10-02 23:02:26,827 : INFO : updating model with new documents
# 2018-10-02 23:02:26,876 : INFO : preparing a new chunk of documents
# 2018-10-02 23:02:26,916 : INFO : using 100 extra samples and 2 power iterations
# 2018-10-02 23:02:26,918 : INFO : 1st phase: constructing (4790, 106) action matrix
# 2018-10-02 23:02:26,979 : INFO : orthonormalizing (4790, 106) action matrix
# 2018-10-02 23:02:27,134 : INFO : 2nd phase: running dense svd on (106, 7633) matrix
# 2018-10-02 23:02:27,247 : INFO : computing the final decomposition
# 2018-10-02 23:02:27,249 : INFO : keeping 6 factors (discarding 64.732% of energy spectrum)
# 2018-10-02 23:02:27,254 : INFO : processed documents up to #7633
# 2018-10-02 23:02:27,257 : INFO : topic #0(48.355): 0.783*"sagrada" + 0.533*"familia" + 0.213*"basílica" + 0.189*"família" + 0.103*"#sagradafamilia" + 0.033*"#gaudi" + 0.032*"beautiful" + 0.027*"gaudi" + 0.024*"inside" + 0.022*"basilica"
# 2018-10-02 23:02:27,259 : INFO : topic #1(28.253): 0.728*"gothic" + 0.676*"quarter" + 0.034*"street" + 0.032*"#art" + 0.028*"#gothicquarter" + 0.028*"#streetart" + 0.025*"#graffiti" + 0.025*"night" + 0.024*"love" + 0.024*"#travel"
# 2018-10-02 23:02:27,262 : INFO : topic #2(25.656): 0.611*"basílica" + -0.555*"familia" + 0.548*"família" + 0.068*"#sagradafamilia" + 0.063*"sagrada" + 0.039*"beautiful" + 0.020*"place" + 0.020*"time" + 0.019*"#catalonia" + 0.018*"#lasagradafamilia"
# 2018-10-02 23:02:27,265 : INFO : topic #3(20.179): -0.898*"#sagradafamilia" + -0.278*"#gaudi" + 0.128*"família" + -0.124*"#travel" + -0.105*"#architecture" + 0.097*"sagrada" + -0.059*"#church" + -0.059*"#summer" + -0.056*"#catalonia" + -0.055*"#basilica"
# 2018-10-02 23:02:27,268 : INFO : topic #4(16.471): 0.424*"#streetart" + 0.358*"drinking" + 0.299*"#arteurbano" + 0.276*"#digerible" + 0.265*"#graffiti" + 0.243*"time" + 0.222*"arte" + 0.220*"urbano" + 0.184*"beach" + 0.162*"tres"
# 2018-10-02 23:02:27,276 : INFO : using serial LSI version on this node
# 2018-10-02 23:02:27,279 : INFO : updating model with new documents
# 2018-10-02 23:02:27,328 : INFO : preparing a new chunk of documents
# 2018-10-02 23:02:27,372 : INFO : using 100 extra samples and 2 power iterations
# 2018-10-02 23:02:27,374 : INFO : 1st phase: constructing (3990, 107) action matrix
# 2018-10-02 23:02:27,422 : INFO : orthonormalizing (3990, 107) action matrix
# 2018-10-02 23:02:27,563 : INFO : 2nd phase: running dense svd on (107, 4424) matrix
# 2018-10-02 23:02:27,640 : INFO : computing the final decomposition
# 2018-10-02 23:02:27,641 : INFO : keeping 7 factors (discarding 50.509% of energy spectrum)
# 2018-10-02 23:02:27,647 : INFO : processed documents up to #4424
# 2018-10-02 23:02:27,651 : INFO : topic #0(84.240): -0.523*"#streetart" + -0.511*"#arteurbano" + -0.404*"arte" + -0.278*"tres" + -0.277*"xemeneies" + -0.274*"#graffiti" + -0.242*"#arteenlacalle" + -0.058*"#instagood" + -0.050*"#artecallejero" + -0.043*"#streetphotography"
# 2018-10-02 23:02:27,653 : INFO : topic #1(65.004): 0.746*"#photodrinking" + 0.506*"cervecita" + 0.271*"drinking" + 0.145*"ross" + 0.145*"torrades" + 0.118*"cal" + 0.106*"ipa" + 0.077*"birrificio" + 0.066*"olgodbeer" + 0.060*"lambrate"
# 2018-10-02 23:02:27,656 : INFO : topic #2(57.917): -0.768*"sagrada" + -0.515*"familia" + -0.213*"basílica" + -0.184*"família" + -0.138*"#sagradafamilia" + -0.084*"gothic" + -0.075*"quarter" + -0.052*"#gaudi" + -0.046*"beautiful" + -0.042*"gaudi"
# 2018-10-02 23:02:27,659 : INFO : topic #3(43.101): 0.442*"#graffiti" + 0.426*"#artecallejero" + 0.369*"#streetphotography" + 0.308*"#catalonia" + 0.251*"#catalunya" + 0.232*"#tweegram" + -0.218*"#arteurbano" + 0.214*"#graffitiart" + -0.179*"arte" + 0.165*"#streetart"
# 2018-10-02 23:02:27,662 : INFO : topic #4(41.794): 0.521*"tip" + 0.520*"insider" + 0.436*"experience" + 0.435*"food" + 0.108*"bar" + 0.105*"ticket" + 0.097*"travel" + 0.095*"dirty" + 0.095*"#ticketsbar" + 0.095*"south"
# 2018-10-02 23:02:27,671 : INFO : using serial LSI version on this node
# 2018-10-02 23:02:27,674 : INFO : updating model with new documents
# 2018-10-02 23:02:27,773 : INFO : preparing a new chunk of documents
# 2018-10-02 23:02:27,846 : INFO : using 100 extra samples and 2 power iterations
# 2018-10-02 23:02:27,851 : INFO : 1st phase: constructing (9330, 107) action matrix
# 2018-10-02 23:02:27,921 : INFO : orthonormalizing (9330, 107) action matrix
# 2018-10-02 23:02:28,195 : INFO : 2nd phase: running dense svd on (107, 6040) matrix
# 2018-10-02 23:02:28,300 : INFO : computing the final decomposition
# 2018-10-02 23:02:28,301 : INFO : keeping 7 factors (discarding 24.646% of energy spectrum)
# 2018-10-02 23:02:28,308 : INFO : processed documents up to #6040
# 2018-10-02 23:02:28,312 : INFO : topic #0(569.920): 0.686*"#sagradafamilia" + 0.417*"sagrada" + 0.255*"#gaudi" + 0.244*"familia" + 0.184*"#travel" + 0.181*"basílica" + 0.114*"#summer" + 0.111*"#architecture" + 0.075*"#catalonia" + 0.075*"#love"
# 2018-10-02 23:02:28,315 : INFO : topic #1(245.858): 0.544*"#streetart" + 0.410*"#graffiti" + 0.304*"#arteurbano" + 0.268*"#digerible" + -0.222*"#sagradafamilia" + 0.199*"urbano" + 0.199*"arte" + 0.156*"#arteenlacalle" + 0.137*"tres" + 0.137*"xemeneies"
# 2018-10-02 23:02:28,318 : INFO : topic #2(204.053): -0.541*"#travel" + 0.435*"#sagradafamilia" + -0.242*"#summer" + -0.215*"#love" + 0.186*"#streetart" + -0.158*"#photography" + 0.157*"#arteurbano" + 0.148*"#digerible" + -0.129*"#beach" + -0.119*"gothic"
# 2018-10-02 23:02:28,321 : INFO : topic #3(150.729): 0.790*"#gaudi" + -0.277*"#summer" + -0.251*"#love" + 0.238*"#architecture" + -0.221*"#sagradafamilia" + -0.112*"#friends" + 0.109*"#lapedrera" + -0.097*"#beach" + -0.092*"#sun" + 0.056*"#casamila"
# 2018-10-02 23:02:28,324 : INFO : topic #4(144.553): -0.691*"#travel" + 0.438*"#summer" + 0.259*"#gaudi" + 0.164*"#love" + 0.161*"#friends" + -0.156*"#sagradafamilia" + 0.119*"#beach" + 0.086*"#architecture" + 0.070*"#catalunya" + -0.064*"#photography"

# %%
# extract topics with word probabilities
lsi_topics_no_pooling = lsi_model_no_pooling.show_topics(formatted=False)
lsi_topics_user_pooling = lsi_model_user_pooling.show_topics(formatted=False)
lsi_topics_hashtag_pooling = lsi_model_hashtag_pooling.show_topics(formatted=False)

# %% [markdown]
# ## Calculate Coherence Values

# %%
# extract top topic words
lsi_topics_no_pooling = [[word for word, prob in topic] for topicid, topic in lsi_topics_no_pooling]
lsi_topics_user_pooling = [[word for word, prob in topic] for topicid, topic in lsi_topics_user_pooling]
lsi_topics_hashtag_pooling = [[word for word, prob in topic] for topicid, topic in lsi_topics_hashtag_pooling]

hdp_topics_no_pooling = [[word for word, prob in topic] for topicid, topic in hdp_topics_no_pooling]
hdp_topics_user_pooling = [[word for word, prob in topic] for topicid, topic in hdp_topics_user_pooling]
hdp_topics_hashtag_pooling = [[word for word, prob in topic] for topicid, topic in hdp_topics_hashtag_pooling]

lda_topics_no_pooling = [[word for word, prob in topic] for topicid, topic in lda_topics_no_pooling]
lda_topics_user_pooling = [[word for word, prob in topic] for topicid, topic in lda_topics_user_pooling]
lda_topics_hashtag_pooling = [[word for word, prob in topic] for topicid, topic in lda_topics_hashtag_pooling]

# %%
# calculate coherences
lsi_no_pooling_coherence = CoherenceModel(topics=lsi_topics_no_pooling, texts=tokenized_documents_no_pooling, dictionary=dictionary_no_pooling, window_size=10).get_coherence()
lsi_user_pooling_coherence = CoherenceModel(topics=lsi_topics_user_pooling, texts=tokenized_documents_user_pooling, dictionary=dictionary_user_pooling, window_size=10).get_coherence()
lsi_hashtag_pooling_coherence = CoherenceModel(topics=lsi_topics_hashtag_pooling, texts=tokenized_documents_hashtag_pooling, dictionary=dictionary_hashtag_pooling, window_size=10).get_coherence()

hdp_no_pooling_coherence = CoherenceModel(topics=hdp_topics_no_pooling, texts=tokenized_documents_no_pooling, dictionary=dictionary_no_pooling, window_size=10).get_coherence()
hdp_user_pooling_coherence = CoherenceModel(topics=hdp_topics_user_pooling, texts=tokenized_documents_user_pooling, dictionary=dictionary_user_pooling, window_size=10).get_coherence()
hdp_hashtag_pooling_coherence = CoherenceModel(topics=hdp_topics_hashtag_pooling, texts=tokenized_documents_hashtag_pooling, dictionary=dictionary_hashtag_pooling, window_size=10).get_coherence()

lda_no_pooling_coherence = CoherenceModel(topics=lda_topics_no_pooling, texts=tokenized_documents_no_pooling, dictionary=dictionary_no_pooling, window_size=10).get_coherence()
lda_user_pooling_coherence = CoherenceModel(topics=lda_topics_user_pooling, texts=tokenized_documents_user_pooling, dictionary=dictionary_user_pooling, window_size=10).get_coherence()
lda_hashtag_pooling_coherence = CoherenceModel(topics=lda_topics_hashtag_pooling, texts=tokenized_documents_hashtag_pooling, dictionary=dictionary_hashtag_pooling, window_size=10).get_coherence()
# Out:
# 2018-10-02 23:02:28,415 : INFO : using ParallelWordOccurrenceAccumulator(processes=3, batch_size=64) to estimate probabilities from sliding windows
# 2018-10-02 23:02:32,921 : INFO : 1 batches submitted to accumulate stats from 64 documents (146 virtual)
# 2018-10-02 23:02:32,924 : INFO : 2 batches submitted to accumulate stats from 128 documents (236 virtual)
# 2018-10-02 23:02:32,928 : INFO : 3 batches submitted to accumulate stats from 192 documents (330 virtual)
# 2018-10-02 23:02:32,932 : INFO : 4 batches submitted to accumulate stats from 256 documents (474 virtual)
# 2018-10-02 23:02:32,936 : INFO : 5 batches submitted to accumulate stats from 320 documents (604 virtual)
# 2018-10-02 23:02:32,941 : INFO : 6 batches submitted to accumulate stats from 384 documents (752 virtual)
# 2018-10-02 23:02:32,945 : INFO : 7 batches submitted to accumulate stats from 448 documents (821 virtual)
# 2018-10-02 23:02:32,951 : INFO : 8 batches submitted to accumulate stats from 512 documents (952 virtual)
# 2018-10-02 23:02:32,955 : INFO : 9 batches submitted to accumulate stats from 576 documents (1075 virtual)
# 2018-10-02 23:02:32,960 : INFO : 10 batches submitted to accumulate stats from 640 documents (1152 virtual)
# 2018-10-02 23:02:32,965 : INFO : 11 batches submitted to accumulate stats from 704 documents (1266 virtual)
# 2018-10-02 23:02:32,972 : INFO : 12 batches submitted to accumulate stats from 768 documents (1394 virtual)
# 2018-10-02 23:02:32,975 : INFO : 13 batches submitted to accumulate stats from 832 documents (1514 virtual)
# 2018-10-02 23:02:32,979 : INFO : 14 batches submitted to accumulate stats from 896 documents (1603 virtual)
# 2018-10-02 23:02:32,987 : INFO : 15 batches submitted to accumulate stats from 960 documents (1703 virtual)
# 2018-10-02 23:02:32,992 : INFO : 16 batches submitted to accumulate stats from 1024 documents (1824 virtual)
# 2018-10-02 23:02:32,999 : INFO : 17 batches submitted to accumulate stats from 1088 documents (1948 virtual)
# 2018-10-02 23:02:33,009 : INFO : 18 batches submitted to accumulate stats from 1152 documents (2063 virtual)
# 2018-10-02 23:02:33,015 : INFO : 19 batches submitted to accumulate stats from 1216 documents (2183 virtual)
# 2018-10-02 23:02:33,024 : INFO : 20 batches submitted to accumulate stats from 1280 documents (2296 virtual)
# 2018-10-02 23:02:33,038 : INFO : 21 batches submitted to accumulate stats from 1344 documents (2387 virtual)
# 2018-10-02 23:02:33,049 : INFO : 22 batches submitted to accumulate stats from 1408 documents (2416 virtual)
# 2018-10-02 23:02:33,060 : INFO : 23 batches submitted to accumulate stats from 1472 documents (2479 virtual)
# 2018-10-02 23:02:33,064 : INFO : 24 batches submitted to accumulate stats from 1536 documents (2538 virtual)
# 2018-10-02 23:02:33,079 : INFO : 25 batches submitted to accumulate stats from 1600 documents (2576 virtual)
# 2018-10-02 23:02:33,085 : INFO : 26 batches submitted to accumulate stats from 1664 documents (2627 virtual)
# 2018-10-02 23:02:33,095 : INFO : 27 batches submitted to accumulate stats from 1728 documents (2683 virtual)
# 2018-10-02 23:02:33,098 : INFO : 28 batches submitted to accumulate stats from 1792 documents (2784 virtual)
# 2018-10-02 23:02:33,102 : INFO : 29 batches submitted to accumulate stats from 1856 documents (2838 virtual)
# 2018-10-02 23:02:33,112 : INFO : 30 batches submitted to accumulate stats from 1920 documents (2939 virtual)
# 2018-10-02 23:02:33,116 : INFO : 31 batches submitted to accumulate stats from 1984 documents (3014 virtual)
# 2018-10-02 23:02:33,131 : INFO : 32 batches submitted to accumulate stats from 2048 documents (3122 virtual)
# 2018-10-02 23:02:33,139 : INFO : 33 batches submitted to accumulate stats from 2112 documents (3223 virtual)
# 2018-10-02 23:02:33,156 : INFO : 34 batches submitted to accumulate stats from 2176 documents (3314 virtual)
# 2018-10-02 23:02:33,166 : INFO : 35 batches submitted to accumulate stats from 2240 documents (3338 virtual)
# 2018-10-02 23:02:33,171 : INFO : 36 batches submitted to accumulate stats from 2304 documents (3433 virtual)
# 2018-10-02 23:02:33,176 : INFO : 37 batches submitted to accumulate stats from 2368 documents (3522 virtual)
# 2018-10-02 23:02:33,180 : INFO : 38 batches submitted to accumulate stats from 2432 documents (3569 virtual)
# 2018-10-02 23:02:33,184 : INFO : 39 batches submitted to accumulate stats from 2496 documents (3580 virtual)
# 2018-10-02 23:02:33,188 : INFO : 40 batches submitted to accumulate stats from 2560 documents (3702 virtual)
# 2018-10-02 23:02:33,193 : INFO : 41 batches submitted to accumulate stats from 2624 documents (3713 virtual)
# 2018-10-02 23:02:33,197 : INFO : 42 batches submitted to accumulate stats from 2688 documents (3823 virtual)
# 2018-10-02 23:02:33,203 : INFO : 43 batches submitted to accumulate stats from 2752 documents (3940 virtual)
# 2018-10-02 23:02:33,223 : INFO : 44 batches submitted to accumulate stats from 2816 documents (4015 virtual)
# 2018-10-02 23:02:33,229 : INFO : 45 batches submitted to accumulate stats from 2880 documents (4067 virtual)
# 2018-10-02 23:02:33,236 : INFO : 46 batches submitted to accumulate stats from 2944 documents (4161 virtual)
# 2018-10-02 23:02:33,239 : INFO : 47 batches submitted to accumulate stats from 3008 documents (4209 virtual)
# 2018-10-02 23:02:33,251 : INFO : 48 batches submitted to accumulate stats from 3072 documents (4312 virtual)
# 2018-10-02 23:02:33,260 : INFO : 49 batches submitted to accumulate stats from 3136 documents (4489 virtual)
# 2018-10-02 23:02:33,269 : INFO : 50 batches submitted to accumulate stats from 3200 documents (4594 virtual)
# 2018-10-02 23:02:33,284 : INFO : 51 batches submitted to accumulate stats from 3264 documents (4662 virtual)
# 2018-10-02 23:02:33,289 : INFO : 52 batches submitted to accumulate stats from 3328 documents (4741 virtual)
# 2018-10-02 23:02:33,292 : INFO : 53 batches submitted to accumulate stats from 3392 documents (4748 virtual)
# 2018-10-02 23:02:33,359 : INFO : 3 accumulators retrieved from output queue
# 2018-10-02 23:02:33,373 : INFO : accumulated word occurrence stats for 8660 virtual documents
# 2018-10-02 23:02:33,525 : INFO : using ParallelWordOccurrenceAccumulator(processes=3, batch_size=64) to estimate probabilities from sliding windows
# 2018-10-02 23:02:38,012 : INFO : 1 batches submitted to accumulate stats from 64 documents (7248 virtual)
# 2018-10-02 23:02:38,015 : INFO : 2 batches submitted to accumulate stats from 128 documents (10518 virtual)
# 2018-10-02 23:02:38,020 : INFO : 3 batches submitted to accumulate stats from 192 documents (12913 virtual)
# 2018-10-02 23:02:38,026 : INFO : 4 batches submitted to accumulate stats from 256 documents (14798 virtual)
# 2018-10-02 23:02:38,030 : INFO : 5 batches submitted to accumulate stats from 320 documents (16367 virtual)
# 2018-10-02 23:02:38,040 : INFO : 6 batches submitted to accumulate stats from 384 documents (17939 virtual)
# 2018-10-02 23:02:38,100 : INFO : 7 batches submitted to accumulate stats from 448 documents (19107 virtual)
# 2018-10-02 23:02:38,110 : INFO : 8 batches submitted to accumulate stats from 512 documents (20185 virtual)
# 2018-10-02 23:02:38,193 : INFO : 9 batches submitted to accumulate stats from 576 documents (21155 virtual)
# 2018-10-02 23:02:38,210 : INFO : 10 batches submitted to accumulate stats from 640 documents (22225 virtual)
# 2018-10-02 23:02:38,270 : INFO : 11 batches submitted to accumulate stats from 704 documents (22826 virtual)
# 2018-10-02 23:02:38,276 : INFO : 12 batches submitted to accumulate stats from 768 documents (23430 virtual)
# 2018-10-02 23:02:38,295 : INFO : 13 batches submitted to accumulate stats from 832 documents (24043 virtual)
# 2018-10-02 23:02:38,318 : INFO : 14 batches submitted to accumulate stats from 896 documents (24491 virtual)
# 2018-10-02 23:02:38,344 : INFO : 15 batches submitted to accumulate stats from 960 documents (24930 virtual)
# 2018-10-02 23:02:38,349 : INFO : 16 batches submitted to accumulate stats from 1024 documents (25401 virtual)
# 2018-10-02 23:02:38,374 : INFO : 17 batches submitted to accumulate stats from 1088 documents (25588 virtual)
# 2018-10-02 23:02:38,381 : INFO : 18 batches submitted to accumulate stats from 1152 documents (25765 virtual)
# 2018-10-02 23:02:38,403 : INFO : 19 batches submitted to accumulate stats from 1216 documents (25885 virtual)
# 2018-10-02 23:02:38,417 : INFO : 20 batches submitted to accumulate stats from 1280 documents (26019 virtual)
# 2018-10-02 23:02:38,435 : INFO : 21 batches submitted to accumulate stats from 1344 documents (26126 virtual)
# 2018-10-02 23:02:38,438 : INFO : 22 batches submitted to accumulate stats from 1408 documents (26272 virtual)
# 2018-10-02 23:02:38,445 : INFO : 23 batches submitted to accumulate stats from 1472 documents (26335 virtual)
# 2018-10-02 23:02:38,452 : INFO : 24 batches submitted to accumulate stats from 1536 documents (26382 virtual)
# 2018-10-02 23:02:38,462 : INFO : 25 batches submitted to accumulate stats from 1600 documents (26443 virtual)
# 2018-10-02 23:02:38,478 : INFO : 26 batches submitted to accumulate stats from 1664 documents (26528 virtual)
# 2018-10-02 23:02:38,486 : INFO : 27 batches submitted to accumulate stats from 1728 documents (26622 virtual)
# 2018-10-02 23:02:38,493 : INFO : 28 batches submitted to accumulate stats from 1792 documents (26701 virtual)
# 2018-10-02 23:02:38,500 : INFO : 29 batches submitted to accumulate stats from 1856 documents (26795 virtual)
# 2018-10-02 23:02:38,510 : INFO : 30 batches submitted to accumulate stats from 1920 documents (26875 virtual)
# 2018-10-02 23:02:38,543 : INFO : 31 batches submitted to accumulate stats from 1984 documents (27005 virtual)
# 2018-10-02 23:02:38,556 : INFO : 32 batches submitted to accumulate stats from 2048 documents (27128 virtual)
# 2018-10-02 23:02:38,561 : INFO : 33 batches submitted to accumulate stats from 2112 documents (27142 virtual)
# 2018-10-02 23:02:38,623 : INFO : 3 accumulators retrieved from output queue
# 2018-10-02 23:02:38,644 : INFO : accumulated word occurrence stats for 28707 virtual documents
# 2018-10-02 23:02:38,874 : INFO : using ParallelWordOccurrenceAccumulator(processes=3, batch_size=64) to estimate probabilities from sliding windows
# 2018-10-02 23:02:43,388 : INFO : 1 batches submitted to accumulate stats from 64 documents (2021 virtual)
# 2018-10-02 23:02:43,391 : INFO : 2 batches submitted to accumulate stats from 128 documents (3773 virtual)
# 2018-10-02 23:02:43,395 : INFO : 3 batches submitted to accumulate stats from 192 documents (4198 virtual)
# 2018-10-02 23:02:43,400 : INFO : 4 batches submitted to accumulate stats from 256 documents (5403 virtual)
# 2018-10-02 23:02:43,404 : INFO : 5 batches submitted to accumulate stats from 320 documents (6186 virtual)
# 2018-10-02 23:02:43,413 : INFO : 6 batches submitted to accumulate stats from 384 documents (7191 virtual)
# 2018-10-02 23:02:43,429 : INFO : 7 batches submitted to accumulate stats from 448 documents (10898 virtual)
# 2018-10-02 23:02:43,439 : INFO : 8 batches submitted to accumulate stats from 512 documents (24058 virtual)
# 2018-10-02 23:02:43,460 : INFO : 9 batches submitted to accumulate stats from 576 documents (25826 virtual)
# 2018-10-02 23:02:43,474 : INFO : 10 batches submitted to accumulate stats from 640 documents (26771 virtual)
# 2018-10-02 23:02:43,486 : INFO : 11 batches submitted to accumulate stats from 704 documents (28678 virtual)
# 2018-10-02 23:02:43,524 : INFO : 12 batches submitted to accumulate stats from 768 documents (30403 virtual)
# 2018-10-02 23:02:43,596 : INFO : 13 batches submitted to accumulate stats from 832 documents (31760 virtual)
# 2018-10-02 23:02:43,657 : INFO : 14 batches submitted to accumulate stats from 896 documents (33435 virtual)
# 2018-10-02 23:02:43,675 : INFO : 15 batches submitted to accumulate stats from 960 documents (35731 virtual)
# 2018-10-02 23:02:43,738 : INFO : 16 batches submitted to accumulate stats from 1024 documents (37395 virtual)
# 2018-10-02 23:02:43,743 : INFO : 17 batches submitted to accumulate stats from 1088 documents (41232 virtual)
# 2018-10-02 23:02:43,793 : INFO : 18 batches submitted to accumulate stats from 1152 documents (43314 virtual)
# 2018-10-02 23:02:43,800 : INFO : 19 batches submitted to accumulate stats from 1216 documents (44958 virtual)
# 2018-10-02 23:02:43,861 : INFO : 20 batches submitted to accumulate stats from 1280 documents (46438 virtual)
# 2018-10-02 23:02:43,897 : INFO : 21 batches submitted to accumulate stats from 1344 documents (47667 virtual)
# 2018-10-02 23:02:43,950 : INFO : 22 batches submitted to accumulate stats from 1408 documents (50242 virtual)
# 2018-10-02 23:02:43,978 : INFO : 23 batches submitted to accumulate stats from 1472 documents (51015 virtual)
# 2018-10-02 23:02:44,015 : INFO : 24 batches submitted to accumulate stats from 1536 documents (52025 virtual)
# 2018-10-02 23:02:44,020 : INFO : 25 batches submitted to accumulate stats from 1600 documents (53042 virtual)
# 2018-10-02 23:02:44,068 : INFO : 26 batches submitted to accumulate stats from 1664 documents (53867 virtual)
# 2018-10-02 23:02:44,086 : INFO : 27 batches submitted to accumulate stats from 1728 documents (57977 virtual)
# 2018-10-02 23:02:44,107 : INFO : 28 batches submitted to accumulate stats from 1792 documents (58898 virtual)
# 2018-10-02 23:02:44,132 : INFO : 29 batches submitted to accumulate stats from 1856 documents (63594 virtual)
# 2018-10-02 23:02:44,176 : INFO : 30 batches submitted to accumulate stats from 1920 documents (67840 virtual)
# 2018-10-02 23:02:44,187 : INFO : 31 batches submitted to accumulate stats from 1984 documents (71646 virtual)
# 2018-10-02 23:02:44,195 : INFO : 32 batches submitted to accumulate stats from 2048 documents (73318 virtual)
# 2018-10-02 23:02:44,241 : INFO : 33 batches submitted to accumulate stats from 2112 documents (76359 virtual)
# 2018-10-02 23:02:44,338 : INFO : 34 batches submitted to accumulate stats from 2176 documents (77762 virtual)
# 2018-10-02 23:02:44,381 : INFO : 35 batches submitted to accumulate stats from 2240 documents (78687 virtual)
# 2018-10-02 23:02:44,397 : INFO : 36 batches submitted to accumulate stats from 2304 documents (78789 virtual)
# 2018-10-02 23:02:44,525 : INFO : 3 accumulators retrieved from output queue
# 2018-10-02 23:02:44,545 : INFO : accumulated word occurrence stats for 80079 virtual documents
# 2018-10-02 23:02:44,709 : INFO : using ParallelWordOccurrenceAccumulator(processes=3, batch_size=64) to estimate probabilities from sliding windows
# 2018-10-02 23:02:49,162 : INFO : 1 batches submitted to accumulate stats from 64 documents (166 virtual)
# 2018-10-02 23:02:49,164 : INFO : 2 batches submitted to accumulate stats from 128 documents (312 virtual)
# 2018-10-02 23:02:49,168 : INFO : 3 batches submitted to accumulate stats from 192 documents (454 virtual)
# 2018-10-02 23:02:49,172 : INFO : 4 batches submitted to accumulate stats from 256 documents (599 virtual)
# 2018-10-02 23:02:49,176 : INFO : 5 batches submitted to accumulate stats from 320 documents (736 virtual)
# 2018-10-02 23:02:49,180 : INFO : 6 batches submitted to accumulate stats from 384 documents (887 virtual)
# 2018-10-02 23:02:49,185 : INFO : 7 batches submitted to accumulate stats from 448 documents (1009 virtual)
# 2018-10-02 23:02:49,190 : INFO : 8 batches submitted to accumulate stats from 512 documents (1123 virtual)
# 2018-10-02 23:02:49,197 : INFO : 9 batches submitted to accumulate stats from 576 documents (1256 virtual)
# 2018-10-02 23:02:49,202 : INFO : 10 batches submitted to accumulate stats from 640 documents (1384 virtual)
# 2018-10-02 23:02:49,209 : INFO : 11 batches submitted to accumulate stats from 704 documents (1482 virtual)
# 2018-10-02 23:02:49,228 : INFO : 12 batches submitted to accumulate stats from 768 documents (1624 virtual)
# 2018-10-02 23:02:49,234 : INFO : 13 batches submitted to accumulate stats from 832 documents (1740 virtual)
# 2018-10-02 23:02:49,237 : INFO : 14 batches submitted to accumulate stats from 896 documents (1867 virtual)
# 2018-10-02 23:02:49,242 : INFO : 15 batches submitted to accumulate stats from 960 documents (1974 virtual)
# 2018-10-02 23:02:49,247 : INFO : 16 batches submitted to accumulate stats from 1024 documents (2107 virtual)
# 2018-10-02 23:02:49,252 : INFO : 17 batches submitted to accumulate stats from 1088 documents (2235 virtual)
# 2018-10-02 23:02:49,256 : INFO : 18 batches submitted to accumulate stats from 1152 documents (2375 virtual)
# 2018-10-02 23:02:49,267 : INFO : 19 batches submitted to accumulate stats from 1216 documents (2469 virtual)
# 2018-10-02 23:02:49,277 : INFO : 20 batches submitted to accumulate stats from 1280 documents (2590 virtual)
# 2018-10-02 23:02:49,284 : INFO : 21 batches submitted to accumulate stats from 1344 documents (2722 virtual)
# 2018-10-02 23:02:49,289 : INFO : 22 batches submitted to accumulate stats from 1408 documents (2839 virtual)
# 2018-10-02 23:02:49,294 : INFO : 23 batches submitted to accumulate stats from 1472 documents (2954 virtual)
# 2018-10-02 23:02:49,299 : INFO : 24 batches submitted to accumulate stats from 1536 documents (3047 virtual)
# 2018-10-02 23:02:49,306 : INFO : 25 batches submitted to accumulate stats from 1600 documents (3155 virtual)
# 2018-10-02 23:02:49,310 : INFO : 26 batches submitted to accumulate stats from 1664 documents (3221 virtual)
# 2018-10-02 23:02:49,314 : INFO : 27 batches submitted to accumulate stats from 1728 documents (3264 virtual)
# 2018-10-02 23:02:49,320 : INFO : 28 batches submitted to accumulate stats from 1792 documents (3368 virtual)
# 2018-10-02 23:02:49,324 : INFO : 29 batches submitted to accumulate stats from 1856 documents (3475 virtual)
# 2018-10-02 23:02:49,328 : INFO : 30 batches submitted to accumulate stats from 1920 documents (3503 virtual)
# 2018-10-02 23:02:49,333 : INFO : 31 batches submitted to accumulate stats from 1984 documents (3541 virtual)
# 2018-10-02 23:02:49,338 : INFO : 32 batches submitted to accumulate stats from 2048 documents (3638 virtual)
# 2018-10-02 23:02:49,342 : INFO : 33 batches submitted to accumulate stats from 2112 documents (3771 virtual)
# 2018-10-02 23:02:49,346 : INFO : 34 batches submitted to accumulate stats from 2176 documents (3830 virtual)
# 2018-10-02 23:02:49,352 : INFO : 35 batches submitted to accumulate stats from 2240 documents (3922 virtual)
# 2018-10-02 23:02:49,357 : INFO : 36 batches submitted to accumulate stats from 2304 documents (4049 virtual)
# 2018-10-02 23:02:49,360 : INFO : 37 batches submitted to accumulate stats from 2368 documents (4131 virtual)
# 2018-10-02 23:02:49,378 : INFO : 38 batches submitted to accumulate stats from 2432 documents (4281 virtual)
# 2018-10-02 23:02:49,383 : INFO : 39 batches submitted to accumulate stats from 2496 documents (4362 virtual)
# 2018-10-02 23:02:49,388 : INFO : 40 batches submitted to accumulate stats from 2560 documents (4463 virtual)
# 2018-10-02 23:02:49,394 : INFO : 41 batches submitted to accumulate stats from 2624 documents (4509 virtual)
# 2018-10-02 23:02:49,401 : INFO : 42 batches submitted to accumulate stats from 2688 documents (4570 virtual)
# 2018-10-02 23:02:49,407 : INFO : 43 batches submitted to accumulate stats from 2752 documents (4678 virtual)
# 2018-10-02 23:02:49,412 : INFO : 44 batches submitted to accumulate stats from 2816 documents (4738 virtual)
# 2018-10-02 23:02:49,416 : INFO : 45 batches submitted to accumulate stats from 2880 documents (4822 virtual)
# 2018-10-02 23:02:49,422 : INFO : 46 batches submitted to accumulate stats from 2944 documents (4879 virtual)
# 2018-10-02 23:02:49,427 : INFO : 47 batches submitted to accumulate stats from 3008 documents (5011 virtual)
# 2018-10-02 23:02:49,434 : INFO : 50 batches submitted to accumulate stats from 3200 documents (5114 virtual)
# 2018-10-02 23:02:49,443 : INFO : 51 batches submitted to accumulate stats from 3264 documents (5223 virtual)
# 2018-10-02 23:02:49,452 : INFO : 52 batches submitted to accumulate stats from 3328 documents (5321 virtual)
# 2018-10-02 23:02:49,460 : INFO : 53 batches submitted to accumulate stats from 3392 documents (5389 virtual)
# 2018-10-02 23:02:49,464 : INFO : 54 batches submitted to accumulate stats from 3456 documents (5468 virtual)
# 2018-10-02 23:02:49,472 : INFO : 55 batches submitted to accumulate stats from 3520 documents (5546 virtual)
# 2018-10-02 23:02:49,478 : INFO : 56 batches submitted to accumulate stats from 3584 documents (5595 virtual)
# 2018-10-02 23:02:49,482 : INFO : 57 batches submitted to accumulate stats from 3648 documents (5619 virtual)
# 2018-10-02 23:02:49,486 : INFO : 58 batches submitted to accumulate stats from 3712 documents (5730 virtual)
# 2018-10-02 23:02:49,492 : INFO : 59 batches submitted to accumulate stats from 3776 documents (5871 virtual)
# 2018-10-02 23:02:49,497 : INFO : 60 batches submitted to accumulate stats from 3840 documents (6010 virtual)
# 2018-10-02 23:02:49,501 : INFO : 61 batches submitted to accumulate stats from 3904 documents (6115 virtual)
# 2018-10-02 23:02:49,505 : INFO : 62 batches submitted to accumulate stats from 3968 documents (6190 virtual)
# 2018-10-02 23:02:49,510 : INFO : 63 batches submitted to accumulate stats from 4032 documents (6268 virtual)
# 2018-10-02 23:02:49,678 : INFO : 3 accumulators retrieved from output queue
# 2018-10-02 23:02:49,754 : INFO : accumulated word occurrence stats for 10926 virtual documents
# 2018-10-02 23:02:51,091 : INFO : using ParallelWordOccurrenceAccumulator(processes=3, batch_size=64) to estimate probabilities from sliding windows
# 2018-10-02 23:02:55,683 : INFO : 1 batches submitted to accumulate stats from 64 documents (6725 virtual)
# 2018-10-02 23:02:55,686 : INFO : 2 batches submitted to accumulate stats from 128 documents (9842 virtual)
# 2018-10-02 23:02:55,691 : INFO : 3 batches submitted to accumulate stats from 192 documents (12530 virtual)
# 2018-10-02 23:02:55,696 : INFO : 4 batches submitted to accumulate stats from 256 documents (14631 virtual)
# 2018-10-02 23:02:55,701 : INFO : 5 batches submitted to accumulate stats from 320 documents (16406 virtual)
# 2018-10-02 23:02:55,704 : INFO : 6 batches submitted to accumulate stats from 384 documents (17816 virtual)
# 2018-10-02 23:02:55,768 : INFO : 7 batches submitted to accumulate stats from 448 documents (19364 virtual)
# 2018-10-02 23:02:55,818 : INFO : 8 batches submitted to accumulate stats from 512 documents (20616 virtual)
# 2018-10-02 23:02:55,856 : INFO : 9 batches submitted to accumulate stats from 576 documents (21978 virtual)
# 2018-10-02 23:02:55,898 : INFO : 10 batches submitted to accumulate stats from 640 documents (23009 virtual)
# 2018-10-02 23:02:55,903 : INFO : 11 batches submitted to accumulate stats from 704 documents (23990 virtual)
# 2018-10-02 23:02:55,921 : INFO : 12 batches submitted to accumulate stats from 768 documents (24865 virtual)
# 2018-10-02 23:02:55,966 : INFO : 13 batches submitted to accumulate stats from 832 documents (25829 virtual)
# 2018-10-02 23:02:55,975 : INFO : 14 batches submitted to accumulate stats from 896 documents (26678 virtual)
# 2018-10-02 23:02:55,987 : INFO : 15 batches submitted to accumulate stats from 960 documents (27214 virtual)
# 2018-10-02 23:02:56,011 : INFO : 16 batches submitted to accumulate stats from 1024 documents (27723 virtual)
# 2018-10-02 23:02:56,023 : INFO : 17 batches submitted to accumulate stats from 1088 documents (28311 virtual)
# 2018-10-02 23:02:56,043 : INFO : 18 batches submitted to accumulate stats from 1152 documents (28848 virtual)
# 2018-10-02 23:02:56,078 : INFO : 19 batches submitted to accumulate stats from 1216 documents (29295 virtual)
# 2018-10-02 23:02:56,084 : INFO : 20 batches submitted to accumulate stats from 1280 documents (29811 virtual)
# 2018-10-02 23:02:56,087 : INFO : 21 batches submitted to accumulate stats from 1344 documents (30243 virtual)
# 2018-10-02 23:02:56,120 : INFO : 22 batches submitted to accumulate stats from 1408 documents (30781 virtual)
# 2018-10-02 23:02:56,126 : INFO : 23 batches submitted to accumulate stats from 1472 documents (30966 virtual)
# 2018-10-02 23:02:56,138 : INFO : 24 batches submitted to accumulate stats from 1536 documents (31083 virtual)
# 2018-10-02 23:02:56,145 : INFO : 25 batches submitted to accumulate stats from 1600 documents (31226 virtual)
# 2018-10-02 23:02:56,164 : INFO : 26 batches submitted to accumulate stats from 1664 documents (31338 virtual)
# 2018-10-02 23:02:56,180 : INFO : 27 batches submitted to accumulate stats from 1728 documents (31494 virtual)
# 2018-10-02 23:02:56,184 : INFO : 28 batches submitted to accumulate stats from 1792 documents (31606 virtual)
# 2018-10-02 23:02:56,190 : INFO : 29 batches submitted to accumulate stats from 1856 documents (31762 virtual)
# 2018-10-02 23:02:56,193 : INFO : 30 batches submitted to accumulate stats from 1920 documents (31848 virtual)
# 2018-10-02 23:02:56,198 : INFO : 31 batches submitted to accumulate stats from 1984 documents (31944 virtual)
# 2018-10-02 23:02:56,206 : INFO : 32 batches submitted to accumulate stats from 2048 documents (31975 virtual)
# 2018-10-02 23:02:56,220 : INFO : 33 batches submitted to accumulate stats from 2112 documents (31987 virtual)
# 2018-10-02 23:02:56,225 : INFO : 34 batches submitted to accumulate stats from 2176 documents (32094 virtual)
# 2018-10-02 23:02:56,229 : INFO : 35 batches submitted to accumulate stats from 2240 documents (32200 virtual)
# 2018-10-02 23:02:56,241 : INFO : 36 batches submitted to accumulate stats from 2304 documents (32331 virtual)
# 2018-10-02 23:02:56,257 : INFO : 37 batches submitted to accumulate stats from 2368 documents (32414 virtual)
# 2018-10-02 23:02:56,261 : INFO : 38 batches submitted to accumulate stats from 2432 documents (32490 virtual)
# 2018-10-02 23:02:56,268 : INFO : 39 batches submitted to accumulate stats from 2496 documents (32559 virtual)
# 2018-10-02 23:02:56,275 : INFO : 40 batches submitted to accumulate stats from 2560 documents (32664 virtual)
# 2018-10-02 23:02:56,279 : INFO : 41 batches submitted to accumulate stats from 2624 documents (32790 virtual)
# 2018-10-02 23:02:56,302 : INFO : 42 batches submitted to accumulate stats from 2688 documents (32880 virtual)
# 2018-10-02 23:02:56,312 : INFO : 43 batches submitted to accumulate stats from 2752 documents (33014 virtual)
# 2018-10-02 23:02:56,320 : INFO : 44 batches submitted to accumulate stats from 2816 documents (33102 virtual)
# 2018-10-02 23:02:56,327 : INFO : 45 batches submitted to accumulate stats from 2880 documents (33180 virtual)
# 2018-10-02 23:02:56,368 : INFO : 3 accumulators retrieved from output queue
# 2018-10-02 23:02:56,427 : INFO : accumulated word occurrence stats for 35403 virtual documents
# 2018-10-02 23:02:57,746 : INFO : using ParallelWordOccurrenceAccumulator(processes=3, batch_size=64) to estimate probabilities from sliding windows
# 2018-10-02 23:03:02,210 : INFO : 1 batches submitted to accumulate stats from 64 documents (2018 virtual)
# 2018-10-02 23:03:02,213 : INFO : 2 batches submitted to accumulate stats from 128 documents (2565 virtual)
# 2018-10-02 23:03:02,217 : INFO : 3 batches submitted to accumulate stats from 192 documents (3639 virtual)
# 2018-10-02 23:03:02,221 : INFO : 4 batches submitted to accumulate stats from 256 documents (4196 virtual)
# 2018-10-02 23:03:02,225 : INFO : 5 batches submitted to accumulate stats from 320 documents (4749 virtual)
# 2018-10-02 23:03:02,231 : INFO : 6 batches submitted to accumulate stats from 384 documents (5847 virtual)
# 2018-10-02 23:03:02,251 : INFO : 7 batches submitted to accumulate stats from 448 documents (6311 virtual)
# 2018-10-02 23:03:02,288 : INFO : 8 batches submitted to accumulate stats from 512 documents (6936 virtual)
# 2018-10-02 23:03:02,292 : INFO : 9 batches submitted to accumulate stats from 576 documents (7684 virtual)
# 2018-10-02 23:03:02,298 : INFO : 10 batches submitted to accumulate stats from 640 documents (11190 virtual)
# 2018-10-02 23:03:02,341 : INFO : 11 batches submitted to accumulate stats from 704 documents (11869 virtual)
# 2018-10-02 23:03:02,381 : INFO : 12 batches submitted to accumulate stats from 768 documents (24009 virtual)
# 2018-10-02 23:03:02,386 : INFO : 13 batches submitted to accumulate stats from 832 documents (26558 virtual)
# 2018-10-02 23:03:02,402 : INFO : 14 batches submitted to accumulate stats from 896 documents (27241 virtual)
# 2018-10-02 23:03:02,461 : INFO : 15 batches submitted to accumulate stats from 960 documents (28073 virtual)
# 2018-10-02 23:03:02,467 : INFO : 16 batches submitted to accumulate stats from 1024 documents (29688 virtual)
# 2018-10-02 23:03:02,573 : INFO : 17 batches submitted to accumulate stats from 1088 documents (30767 virtual)
# 2018-10-02 23:03:02,589 : INFO : 18 batches submitted to accumulate stats from 1152 documents (31961 virtual)
# 2018-10-02 23:03:02,619 : INFO : 19 batches submitted to accumulate stats from 1216 documents (32411 virtual)
# 2018-10-02 23:03:02,658 : INFO : 20 batches submitted to accumulate stats from 1280 documents (33844 virtual)
# 2018-10-02 23:03:02,703 : INFO : 21 batches submitted to accumulate stats from 1344 documents (34907 virtual)
# 2018-10-02 23:03:02,708 : INFO : 22 batches submitted to accumulate stats from 1408 documents (36617 virtual)
# 2018-10-02 23:03:02,745 : INFO : 23 batches submitted to accumulate stats from 1472 documents (38171 virtual)
# 2018-10-02 23:03:02,781 : INFO : 24 batches submitted to accumulate stats from 1536 documents (39337 virtual)
# 2018-10-02 23:03:02,829 : INFO : 25 batches submitted to accumulate stats from 1600 documents (41192 virtual)
# 2018-10-02 23:03:02,849 : INFO : 26 batches submitted to accumulate stats from 1664 documents (43840 virtual)
# 2018-10-02 23:03:02,926 : INFO : 27 batches submitted to accumulate stats from 1728 documents (45643 virtual)
# 2018-10-02 23:03:02,933 : INFO : 28 batches submitted to accumulate stats from 1792 documents (46492 virtual)
# 2018-10-02 23:03:02,990 : INFO : 29 batches submitted to accumulate stats from 1856 documents (47928 virtual)
# 2018-10-02 23:03:02,998 : INFO : 30 batches submitted to accumulate stats from 1920 documents (49270 virtual)
# 2018-10-02 23:03:03,035 : INFO : 31 batches submitted to accumulate stats from 1984 documents (50284 virtual)
# 2018-10-02 23:03:03,083 : INFO : 32 batches submitted to accumulate stats from 2048 documents (51463 virtual)
# 2018-10-02 23:03:03,122 : INFO : 33 batches submitted to accumulate stats from 2112 documents (52834 virtual)
# 2018-10-02 23:03:03,134 : INFO : 34 batches submitted to accumulate stats from 2176 documents (54367 virtual)
# 2018-10-02 23:03:03,170 : INFO : 35 batches submitted to accumulate stats from 2240 documents (55074 virtual)
# 2018-10-02 23:03:03,209 : INFO : 36 batches submitted to accumulate stats from 2304 documents (55756 virtual)
# 2018-10-02 23:03:03,217 : INFO : 37 batches submitted to accumulate stats from 2368 documents (56496 virtual)
# 2018-10-02 23:03:03,249 : INFO : 38 batches submitted to accumulate stats from 2432 documents (57348 virtual)
# 2018-10-02 23:03:03,297 : INFO : 39 batches submitted to accumulate stats from 2496 documents (58056 virtual)
# 2018-10-02 23:03:03,308 : INFO : 40 batches submitted to accumulate stats from 2560 documents (61970 virtual)
# 2018-10-02 23:03:03,316 : INFO : 41 batches submitted to accumulate stats from 2624 documents (62837 virtual)
# 2018-10-02 23:03:03,346 : INFO : 42 batches submitted to accumulate stats from 2688 documents (63445 virtual)
# 2018-10-02 23:03:03,381 : INFO : 43 batches submitted to accumulate stats from 2752 documents (67464 virtual)
# 2018-10-02 23:03:03,393 : INFO : 44 batches submitted to accumulate stats from 2816 documents (68608 virtual)
# 2018-10-02 23:03:03,402 : INFO : 45 batches submitted to accumulate stats from 2880 documents (69508 virtual)
# 2018-10-02 23:03:03,441 : INFO : 46 batches submitted to accumulate stats from 2944 documents (74541 virtual)
# 2018-10-02 23:03:03,457 : INFO : 47 batches submitted to accumulate stats from 3008 documents (77357 virtual)
# 2018-10-02 23:03:03,518 : INFO : 48 batches submitted to accumulate stats from 3072 documents (78489 virtual)
# 2018-10-02 23:03:03,601 : INFO : 49 batches submitted to accumulate stats from 3136 documents (81301 virtual)
# 2018-10-02 23:03:03,606 : INFO : 50 batches submitted to accumulate stats from 3200 documents (82409 virtual)
# 2018-10-02 23:03:03,702 : INFO : 51 batches submitted to accumulate stats from 3264 documents (83358 virtual)
# 2018-10-02 23:03:03,736 : INFO : 52 batches submitted to accumulate stats from 3328 documents (84280 virtual)
# 2018-10-02 23:03:03,750 : INFO : 53 batches submitted to accumulate stats from 3392 documents (84993 virtual)
# 2018-10-02 23:03:03,911 : INFO : 3 accumulators retrieved from output queue
# 2018-10-02 23:03:03,977 : INFO : accumulated word occurrence stats for 87041 virtual documents
# 2018-10-02 23:03:05,262 : INFO : using ParallelWordOccurrenceAccumulator(processes=3, batch_size=64) to estimate probabilities from sliding windows
# 2018-10-02 23:03:09,724 : INFO : 1 batches submitted to accumulate stats from 64 documents (140 virtual)
# 2018-10-02 23:03:09,728 : INFO : 2 batches submitted to accumulate stats from 128 documents (275 virtual)
# 2018-10-02 23:03:09,733 : INFO : 3 batches submitted to accumulate stats from 192 documents (384 virtual)
# 2018-10-02 23:03:09,737 : INFO : 4 batches submitted to accumulate stats from 256 documents (542 virtual)
# 2018-10-02 23:03:09,741 : INFO : 5 batches submitted to accumulate stats from 320 documents (704 virtual)
# 2018-10-02 23:03:09,746 : INFO : 6 batches submitted to accumulate stats from 384 documents (855 virtual)
# 2018-10-02 23:03:09,751 : INFO : 7 batches submitted to accumulate stats from 448 documents (1009 virtual)
# 2018-10-02 23:03:09,759 : INFO : 8 batches submitted to accumulate stats from 512 documents (1129 virtual)
# 2018-10-02 23:03:09,764 : INFO : 9 batches submitted to accumulate stats from 576 documents (1282 virtual)
# 2018-10-02 23:03:09,767 : INFO : 10 batches submitted to accumulate stats from 640 documents (1415 virtual)
# 2018-10-02 23:03:09,772 : INFO : 11 batches submitted to accumulate stats from 704 documents (1581 virtual)
# 2018-10-02 23:03:09,780 : INFO : 12 batches submitted to accumulate stats from 768 documents (1669 virtual)
# 2018-10-02 23:03:09,787 : INFO : 13 batches submitted to accumulate stats from 832 documents (1756 virtual)
# 2018-10-02 23:03:09,791 : INFO : 14 batches submitted to accumulate stats from 896 documents (1869 virtual)
# 2018-10-02 23:03:09,796 : INFO : 15 batches submitted to accumulate stats from 960 documents (2024 virtual)
# 2018-10-02 23:03:09,802 : INFO : 16 batches submitted to accumulate stats from 1024 documents (2177 virtual)
# 2018-10-02 23:03:09,806 : INFO : 17 batches submitted to accumulate stats from 1088 documents (2318 virtual)
# 2018-10-02 23:03:09,817 : INFO : 18 batches submitted to accumulate stats from 1152 documents (2455 virtual)
# 2018-10-02 23:03:09,823 : INFO : 19 batches submitted to accumulate stats from 1216 documents (2558 virtual)
# 2018-10-02 23:03:09,827 : INFO : 20 batches submitted to accumulate stats from 1280 documents (2671 virtual)
# 2018-10-02 23:03:09,840 : INFO : 21 batches submitted to accumulate stats from 1344 documents (2826 virtual)
# 2018-10-02 23:03:09,844 : INFO : 22 batches submitted to accumulate stats from 1408 documents (2931 virtual)
# 2018-10-02 23:03:09,854 : INFO : 23 batches submitted to accumulate stats from 1472 documents (3019 virtual)
# 2018-10-02 23:03:09,859 : INFO : 24 batches submitted to accumulate stats from 1536 documents (3150 virtual)
# 2018-10-02 23:03:09,865 : INFO : 25 batches submitted to accumulate stats from 1600 documents (3242 virtual)
# 2018-10-02 23:03:09,882 : INFO : 26 batches submitted to accumulate stats from 1664 documents (3307 virtual)
# 2018-10-02 23:03:09,891 : INFO : 27 batches submitted to accumulate stats from 1728 documents (3355 virtual)
# 2018-10-02 23:03:09,898 : INFO : 28 batches submitted to accumulate stats from 1792 documents (3463 virtual)
# 2018-10-02 23:03:09,909 : INFO : 29 batches submitted to accumulate stats from 1856 documents (3525 virtual)
# 2018-10-02 23:03:09,915 : INFO : 30 batches submitted to accumulate stats from 1920 documents (3592 virtual)
# 2018-10-02 23:03:09,932 : INFO : 31 batches submitted to accumulate stats from 1984 documents (3640 virtual)
# 2018-10-02 23:03:09,953 : INFO : 32 batches submitted to accumulate stats from 2048 documents (3691 virtual)
# 2018-10-02 23:03:09,972 : INFO : 33 batches submitted to accumulate stats from 2112 documents (3788 virtual)
# 2018-10-02 23:03:09,977 : INFO : 34 batches submitted to accumulate stats from 2176 documents (3884 virtual)
# 2018-10-02 23:03:09,982 : INFO : 35 batches submitted to accumulate stats from 2240 documents (3940 virtual)
# 2018-10-02 23:03:09,986 : INFO : 36 batches submitted to accumulate stats from 2304 documents (4062 virtual)
# 2018-10-02 23:03:09,999 : INFO : 37 batches submitted to accumulate stats from 2368 documents (4146 virtual)
# 2018-10-02 23:03:10,032 : INFO : 38 batches submitted to accumulate stats from 2432 documents (4256 virtual)
# 2018-10-02 23:03:10,036 : INFO : 39 batches submitted to accumulate stats from 2496 documents (4357 virtual)
# 2018-10-02 23:03:10,046 : INFO : 40 batches submitted to accumulate stats from 2560 documents (4468 virtual)
# 2018-10-02 23:03:10,049 : INFO : 41 batches submitted to accumulate stats from 2624 documents (4551 virtual)
# 2018-10-02 23:03:10,053 : INFO : 42 batches submitted to accumulate stats from 2688 documents (4727 virtual)
# 2018-10-02 23:03:10,058 : INFO : 43 batches submitted to accumulate stats from 2752 documents (4776 virtual)
# 2018-10-02 23:03:10,062 : INFO : 44 batches submitted to accumulate stats from 2816 documents (4865 virtual)
# 2018-10-02 23:03:10,066 : INFO : 45 batches submitted to accumulate stats from 2880 documents (4931 virtual)
# 2018-10-02 23:03:10,070 : INFO : 46 batches submitted to accumulate stats from 2944 documents (4986 virtual)
# 2018-10-02 23:03:10,073 : INFO : 47 batches submitted to accumulate stats from 3008 documents (5061 virtual)
# 2018-10-02 23:03:10,077 : INFO : 48 batches submitted to accumulate stats from 3072 documents (5084 virtual)
# 2018-10-02 23:03:10,082 : INFO : 49 batches submitted to accumulate stats from 3136 documents (5177 virtual)
# 2018-10-02 23:03:10,094 : INFO : 50 batches submitted to accumulate stats from 3200 documents (5257 virtual)
# 2018-10-02 23:03:10,110 : INFO : 52 batches submitted to accumulate stats from 3328 documents (5330 virtual)
# 2018-10-02 23:03:10,129 : INFO : 53 batches submitted to accumulate stats from 3392 documents (5442 virtual)
# 2018-10-02 23:03:10,146 : INFO : 54 batches submitted to accumulate stats from 3456 documents (5562 virtual)
# 2018-10-02 23:03:10,151 : INFO : 55 batches submitted to accumulate stats from 3520 documents (5616 virtual)
# 2018-10-02 23:03:10,156 : INFO : 56 batches submitted to accumulate stats from 3584 documents (5673 virtual)
# 2018-10-02 23:03:10,206 : INFO : 57 batches submitted to accumulate stats from 3648 documents (5738 virtual)
# 2018-10-02 23:03:10,209 : INFO : 58 batches submitted to accumulate stats from 3712 documents (5827 virtual)
# 2018-10-02 23:03:10,213 : INFO : 59 batches submitted to accumulate stats from 3776 documents (5872 virtual)
# 2018-10-02 23:03:10,217 : INFO : 60 batches submitted to accumulate stats from 3840 documents (5915 virtual)
# 2018-10-02 23:03:10,229 : INFO : 61 batches submitted to accumulate stats from 3904 documents (5968 virtual)
# 2018-10-02 23:03:10,237 : INFO : 62 batches submitted to accumulate stats from 3968 documents (6086 virtual)
# 2018-10-02 23:03:10,240 : INFO : 63 batches submitted to accumulate stats from 4032 documents (6243 virtual)
# 2018-10-02 23:03:10,250 : INFO : 64 batches submitted to accumulate stats from 4096 documents (6303 virtual)
# 2018-10-02 23:03:10,259 : INFO : 65 batches submitted to accumulate stats from 4160 documents (6420 virtual)
# 2018-10-02 23:03:10,281 : INFO : 66 batches submitted to accumulate stats from 4224 documents (6492 virtual)
# 2018-10-02 23:03:10,289 : INFO : 67 batches submitted to accumulate stats from 4288 documents (6590 virtual)
# 2018-10-02 23:03:10,295 : INFO : 68 batches submitted to accumulate stats from 4352 documents (6626 virtual)
# 2018-10-02 23:03:10,410 : INFO : 3 accumulators retrieved from output queue
# 2018-10-02 23:03:10,431 : INFO : accumulated word occurrence stats for 11687 virtual documents
# 2018-10-02 23:03:10,688 : INFO : using ParallelWordOccurrenceAccumulator(processes=3, batch_size=64) to estimate probabilities from sliding windows
# 2018-10-02 23:03:15,259 : INFO : 1 batches submitted to accumulate stats from 64 documents (6849 virtual)
# 2018-10-02 23:03:15,262 : INFO : 2 batches submitted to accumulate stats from 128 documents (9988 virtual)
# 2018-10-02 23:03:15,267 : INFO : 3 batches submitted to accumulate stats from 192 documents (12696 virtual)
# 2018-10-02 23:03:15,273 : INFO : 4 batches submitted to accumulate stats from 256 documents (14876 virtual)
# 2018-10-02 23:03:15,277 : INFO : 5 batches submitted to accumulate stats from 320 documents (16372 virtual)
# 2018-10-02 23:03:15,283 : INFO : 6 batches submitted to accumulate stats from 384 documents (17944 virtual)
# 2018-10-02 23:03:15,344 : INFO : 7 batches submitted to accumulate stats from 448 documents (19283 virtual)
# 2018-10-02 23:03:15,361 : INFO : 8 batches submitted to accumulate stats from 512 documents (20466 virtual)
# 2018-10-02 23:03:15,419 : INFO : 9 batches submitted to accumulate stats from 576 documents (21750 virtual)
# 2018-10-02 23:03:15,423 : INFO : 10 batches submitted to accumulate stats from 640 documents (22796 virtual)
# 2018-10-02 23:03:15,427 : INFO : 11 batches submitted to accumulate stats from 704 documents (23806 virtual)
# 2018-10-02 23:03:15,480 : INFO : 12 batches submitted to accumulate stats from 768 documents (24733 virtual)
# 2018-10-02 23:03:15,484 : INFO : 13 batches submitted to accumulate stats from 832 documents (25670 virtual)
# 2018-10-02 23:03:15,498 : INFO : 14 batches submitted to accumulate stats from 896 documents (26511 virtual)
# 2018-10-02 23:03:15,539 : INFO : 15 batches submitted to accumulate stats from 960 documents (27043 virtual)
# 2018-10-02 23:03:15,542 : INFO : 16 batches submitted to accumulate stats from 1024 documents (27604 virtual)
# 2018-10-02 23:03:15,555 : INFO : 17 batches submitted to accumulate stats from 1088 documents (28239 virtual)
# 2018-10-02 23:03:15,591 : INFO : 18 batches submitted to accumulate stats from 1152 documents (28760 virtual)
# 2018-10-02 23:03:15,598 : INFO : 19 batches submitted to accumulate stats from 1216 documents (29201 virtual)
# 2018-10-02 23:03:15,611 : INFO : 20 batches submitted to accumulate stats from 1280 documents (29708 virtual)
# 2018-10-02 23:03:15,637 : INFO : 21 batches submitted to accumulate stats from 1344 documents (30135 virtual)
# 2018-10-02 23:03:15,648 : INFO : 22 batches submitted to accumulate stats from 1408 documents (30607 virtual)
# 2018-10-02 23:03:15,661 : INFO : 23 batches submitted to accumulate stats from 1472 documents (30841 virtual)
# 2018-10-02 23:03:15,678 : INFO : 24 batches submitted to accumulate stats from 1536 documents (30974 virtual)
# 2018-10-02 23:03:15,682 : INFO : 25 batches submitted to accumulate stats from 1600 documents (31129 virtual)
# 2018-10-02 23:03:15,713 : INFO : 26 batches submitted to accumulate stats from 1664 documents (31261 virtual)
# 2018-10-02 23:03:15,724 : INFO : 27 batches submitted to accumulate stats from 1728 documents (31424 virtual)
# 2018-10-02 23:03:15,734 : INFO : 28 batches submitted to accumulate stats from 1792 documents (31540 virtual)
# 2018-10-02 23:03:15,743 : INFO : 29 batches submitted to accumulate stats from 1856 documents (31706 virtual)
# 2018-10-02 23:03:15,758 : INFO : 30 batches submitted to accumulate stats from 1920 documents (31802 virtual)
# 2018-10-02 23:03:15,762 : INFO : 31 batches submitted to accumulate stats from 1984 documents (31926 virtual)
# 2018-10-02 23:03:15,781 : INFO : 32 batches submitted to accumulate stats from 2048 documents (31979 virtual)
# 2018-10-02 23:03:15,791 : INFO : 33 batches submitted to accumulate stats from 2112 documents (32012 virtual)
# 2018-10-02 23:03:15,811 : INFO : 34 batches submitted to accumulate stats from 2176 documents (32085 virtual)
# 2018-10-02 23:03:15,816 : INFO : 35 batches submitted to accumulate stats from 2240 documents (32211 virtual)
# 2018-10-02 23:03:15,819 : INFO : 36 batches submitted to accumulate stats from 2304 documents (32324 virtual)
# 2018-10-02 23:03:15,832 : INFO : 37 batches submitted to accumulate stats from 2368 documents (32410 virtual)
# 2018-10-02 23:03:15,836 : INFO : 38 batches submitted to accumulate stats from 2432 documents (32492 virtual)
# 2018-10-02 23:03:15,838 : INFO : 39 batches submitted to accumulate stats from 2496 documents (32552 virtual)
# 2018-10-02 23:03:15,853 : INFO : 40 batches submitted to accumulate stats from 2560 documents (32631 virtual)
# 2018-10-02 23:03:15,864 : INFO : 41 batches submitted to accumulate stats from 2624 documents (32772 virtual)
# 2018-10-02 23:03:15,867 : INFO : 42 batches submitted to accumulate stats from 2688 documents (32841 virtual)
# 2018-10-02 23:03:15,879 : INFO : 43 batches submitted to accumulate stats from 2752 documents (32943 virtual)
# 2018-10-02 23:03:15,903 : INFO : 44 batches submitted to accumulate stats from 2816 documents (33076 virtual)
# 2018-10-02 23:03:15,914 : INFO : 45 batches submitted to accumulate stats from 2880 documents (33155 virtual)
# 2018-10-02 23:03:15,922 : INFO : 46 batches submitted to accumulate stats from 2944 documents (33260 virtual)
# 2018-10-02 23:03:15,973 : INFO : 3 accumulators retrieved from output queue
# 2018-10-02 23:03:15,997 : INFO : accumulated word occurrence stats for 35520 virtual documents
# 2018-10-02 23:03:16,182 : INFO : using ParallelWordOccurrenceAccumulator(processes=3, batch_size=64) to estimate probabilities from sliding windows
# 2018-10-02 23:03:20,618 : INFO : 1 batches submitted to accumulate stats from 64 documents (2018 virtual)
# 2018-10-02 23:03:20,621 : INFO : 2 batches submitted to accumulate stats from 128 documents (3466 virtual)
# 2018-10-02 23:03:20,625 : INFO : 3 batches submitted to accumulate stats from 192 documents (4053 virtual)
# 2018-10-02 23:03:20,629 : INFO : 4 batches submitted to accumulate stats from 256 documents (4707 virtual)
# 2018-10-02 23:03:20,633 : INFO : 5 batches submitted to accumulate stats from 320 documents (5774 virtual)
# 2018-10-02 23:03:20,676 : INFO : 6 batches submitted to accumulate stats from 384 documents (6512 virtual)
# 2018-10-02 23:03:20,686 : INFO : 7 batches submitted to accumulate stats from 448 documents (7087 virtual)
# 2018-10-02 23:03:20,693 : INFO : 8 batches submitted to accumulate stats from 512 documents (10932 virtual)
# 2018-10-02 23:03:20,704 : INFO : 9 batches submitted to accumulate stats from 576 documents (22741 virtual)
# 2018-10-02 23:03:20,708 : INFO : 10 batches submitted to accumulate stats from 640 documents (25614 virtual)
# 2018-10-02 23:03:20,714 : INFO : 11 batches submitted to accumulate stats from 704 documents (26660 virtual)
# 2018-10-02 23:03:20,720 : INFO : 12 batches submitted to accumulate stats from 768 documents (27669 virtual)
# 2018-10-02 23:03:20,749 : INFO : 13 batches submitted to accumulate stats from 832 documents (29730 virtual)
# 2018-10-02 23:03:20,843 : INFO : 14 batches submitted to accumulate stats from 896 documents (31326 virtual)
# 2018-10-02 23:03:20,866 : INFO : 15 batches submitted to accumulate stats from 960 documents (32143 virtual)
# 2018-10-02 23:03:20,901 : INFO : 16 batches submitted to accumulate stats from 1024 documents (33887 virtual)
# 2018-10-02 23:03:20,919 : INFO : 17 batches submitted to accumulate stats from 1088 documents (35462 virtual)
# 2018-10-02 23:03:20,989 : INFO : 18 batches submitted to accumulate stats from 1152 documents (37193 virtual)
# 2018-10-02 23:03:20,993 : INFO : 19 batches submitted to accumulate stats from 1216 documents (39475 virtual)
# 2018-10-02 23:03:21,021 : INFO : 20 batches submitted to accumulate stats from 1280 documents (42512 virtual)
# 2018-10-02 23:03:21,068 : INFO : 21 batches submitted to accumulate stats from 1344 documents (44653 virtual)
# 2018-10-02 23:03:21,100 : INFO : 22 batches submitted to accumulate stats from 1408 documents (46029 virtual)
# 2018-10-02 23:03:21,128 : INFO : 23 batches submitted to accumulate stats from 1472 documents (47737 virtual)
# 2018-10-02 23:03:21,160 : INFO : 24 batches submitted to accumulate stats from 1536 documents (48374 virtual)
# 2018-10-02 23:03:21,210 : INFO : 25 batches submitted to accumulate stats from 1600 documents (49767 virtual)
# 2018-10-02 23:03:21,245 : INFO : 26 batches submitted to accumulate stats from 1664 documents (52147 virtual)
# 2018-10-02 23:03:21,265 : INFO : 27 batches submitted to accumulate stats from 1728 documents (52900 virtual)
# 2018-10-02 23:03:21,269 : INFO : 28 batches submitted to accumulate stats from 1792 documents (54007 virtual)
# 2018-10-02 23:03:21,305 : INFO : 29 batches submitted to accumulate stats from 1856 documents (54820 virtual)
# 2018-10-02 23:03:21,309 : INFO : 30 batches submitted to accumulate stats from 1920 documents (55506 virtual)
# 2018-10-02 23:03:21,334 : INFO : 31 batches submitted to accumulate stats from 1984 documents (59528 virtual)
# 2018-10-02 23:03:21,348 : INFO : 32 batches submitted to accumulate stats from 2048 documents (60664 virtual)
# 2018-10-02 23:03:21,386 : INFO : 33 batches submitted to accumulate stats from 2112 documents (61410 virtual)
# 2018-10-02 23:03:21,397 : INFO : 34 batches submitted to accumulate stats from 2176 documents (65954 virtual)
# 2018-10-02 23:03:21,427 : INFO : 35 batches submitted to accumulate stats from 2240 documents (66810 virtual)
# 2018-10-02 23:03:21,433 : INFO : 36 batches submitted to accumulate stats from 2304 documents (72229 virtual)
# 2018-10-02 23:03:21,480 : INFO : 37 batches submitted to accumulate stats from 2368 documents (74968 virtual)
# 2018-10-02 23:03:21,496 : INFO : 38 batches submitted to accumulate stats from 2432 documents (76188 virtual)
# 2018-10-02 23:03:21,534 : INFO : 39 batches submitted to accumulate stats from 2496 documents (79222 virtual)
# 2018-10-02 23:03:21,554 : INFO : 40 batches submitted to accumulate stats from 2560 documents (80386 virtual)
# 2018-10-02 23:03:21,648 : INFO : 41 batches submitted to accumulate stats from 2624 documents (81473 virtual)
# 2018-10-02 23:03:21,672 : INFO : 42 batches submitted to accumulate stats from 2688 documents (81788 virtual)
# 2018-10-02 23:03:21,820 : INFO : 3 accumulators retrieved from output queue
# 2018-10-02 23:03:21,840 : INFO : accumulated word occurrence stats for 83197 virtual documents

# %%
# define function to plot a graph to compare coherence scores
def evaluate_bar_graph(coherences, indices):
    """
    Function to plot bar graph.
    
    coherences: list of coherence values
    indices: Indices to be used to mark bars. Length of this and coherences should be equal.
    """
    assert len(coherences) == len(indices)
    n = len(coherences)
    x = np.arange(n)
    plt.bar(x, coherences, width=0.2, tick_label=indices, align='center')
    plt.xlabel('Models')
    plt.ylabel('Coherence Value')

# %%
# compare coherence scores
evaluate_bar_graph([lsi_no_pooling_coherence, lsi_user_pooling_coherence, lsi_hashtag_pooling_coherence,
                    hdp_no_pooling_coherence, hdp_user_pooling_coherence, hdp_hashtag_pooling_coherence,
                    lda_no_pooling_coherence, lda_user_pooling_coherence, lda_hashtag_pooling_coherence],
                   ['LSI1', 'LSI2', 'LSI3', 'HDP1', 'HDP2',
                    'HDP3', 'LDA1', 'LDA2', 'LDA3'])
plt.show()

# %% [markdown]
# #### The HDP models have the best coherence scores but the topics are way too granular on inspection. In fact, the LDA achieves similar coherence scores if the number of topics is increased. But to ensure human interpretability, the number of topics is restricted to a lower number. In addition, the HDP models are very unstable on retraining.

# %% [markdown]
# ## Comparison of the LDA4 model and LSI2 model

# %%
# show topics of lsi Model
for i in range(5):
    print(lsi_model_user_pooling.show_topic(i))
    print()

# %%
# show topics of lda model
_ = lda_model_optimized.print_topics()

# %% [markdown]
# #### Although the LSI model has a better coherence score, the topics of the lda model seem to make more sense. It also has some other advantages such as its probabilistic foundation. The lda model will thus be used to analyze the topic distribution over the districts.
